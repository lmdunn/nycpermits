# %%
import pandas as pd
from scipy.spatial import distance
from math import sin, cos, sqrt, atan2, radians
import time

# %%
permits_bk3 = pd.read_csv('../data_permits_by_boro/permits_bk3.csv')
nypd_bk = pd.read_csv('../data_nypd_by_year/2014/nypd2014_bk.csv') #CHANGE YEAR

# %%
def get_distance(point1, point2):
    R = 4182 #miles
    lat1 = radians(point1[0])
    lon1 = radians(point1[1])
    lat2 = radians(point2[0])
    lon2 = radians(point2[1])

    dlon = lon2 - lon1
    dlat = lat2- lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return distance


# BROOKLYN (BK) 3
t0 = time.time()
print('Processing Brooklyn 3')
permits_bk3.loc[0, 'complaints2014_15'] = 0 #CHANGE YEAR
for i in permits_bk3.index:
    lat = permits_bk3.loc[i, 'latitude']
    long = permits_bk3.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_bk.index:
        n_lat = nypd_bk.loc[n, 'latitude']
        n_long = nypd_bk.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_bk3.loc[i, 'complaints2014_15'] = complaint_count #CHANGE YEAR

permits_bk3.to_csv('../data_permits_w_nypd/permits_complaints2014_bk3.csv')

print('')
print("Time to run Brooklyn:", time.time()-t0)
# Out:
# Processing Brooklyn 3
#
# Time to run Brooklyn: 3762.887841939926

# %%
permits_bk2 = pd.read_csv('../data_permits_by_boro/permits_bk2.csv')

# %%
def get_distance(point1, point2):
    R = 4182 #miles
    lat1 = radians(point1[0])
    lon1 = radians(point1[1])
    lat2 = radians(point2[0])
    lon2 = radians(point2[1])

    dlon = lon2 - lon1
    dlat = lat2- lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return distance


# BROOKLYN (BK) 2
t0 = time.time()
print('Processing Brooklyn 2')
permits_bk2.loc[0, 'complaints2014_15'] = 0 #CHANGE YEAR
for i in permits_bk2.index:
    t1 = time.time()
    lat = permits_bk2.loc[i, 'latitude']
    long = permits_bk2.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_bk.index:
        n_lat = nypd_bk.loc[n, 'latitude']
        n_long = nypd_bk.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_bk2.loc[i, 'complaints2014_15'] = complaint_count #CHANGE YEAR
    print(f"Permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the code.")

permits_bk2.to_csv('../data_permits_w_nypd/permits_complaints2014_bk2.csv')

print('')
print("Time to run Brooklyn:", time.time()-t0)
# Out:
# Processing Brooklyn 2
# Permit 0 finished at 1660100692.1581419, after 1.557297945022583, 1.5630769729614258 since the start of the code.
# Permit 1 finished at 1660100693.700394, after 1.5421857833862305, 3.1053221225738525 since the start of the code.
# Permit 2 finished at 1660100695.253386, after 1.552915096282959, 4.658313989639282 since the start of the code.
# Permit 3 finished at 1660100696.8048089, after 1.5513420104980469, 6.209734916687012 since the start of the code.
# Permit 4 finished at 1660100698.3414478, after 1.5365991592407227, 7.746376037597656 since the start of the code.
# Permit 5 finished at 1660100699.886286, after 1.5447659492492676, 9.291213989257812 since the start of the code.
# Permit 6 finished at 1660100701.440793, after 1.5544309616088867, 10.845721006393433 since the start of the code.
# Permit 7 finished at 1660100702.972777, after 1.5319089889526367, 12.37770390510559 since the start of the code.
# Permit 8 finished at 1660100704.5073211, after 1.5345039367675781, 13.912248849868774 since the start of the code.
# Permit 9 finished at 1660100706.03295, after 1.525568962097168, 15.437875986099243 since the start of the code.
# Permit 10 finished at 1660100707.586619, after 1.5536258220672607, 16.991545915603638 since the start of the code.
# Permit 11 finished at 1660100709.118876, after 1.532209873199463, 18.52380394935608 since the start of the code.
# Permit 12 finished at 1660100710.671718, after 1.55277681350708, 20.07664704322815 since the start of the code.
# Permit 13 finished at 1660100712.230022, after 1.5582220554351807, 21.634949922561646 since the start of the code.
# Permit 14 finished at 1660100713.7682612, after 1.5381650924682617, 23.17318892478943 since the start of the code.
# Permit 15 finished at 1660100715.303154, after 1.5348141193389893, 24.708081007003784 since the start of the code.
# Permit 16 finished at 1660100716.833162, after 1.5299572944641113, 26.238089084625244 since the start of the code.
# Permit 17 finished at 1660100718.3784351, after 1.5451841354370117, 27.78336191177368 since the start of the code.
# Permit 18 finished at 1660100720.305383, after 1.9268770217895508, 29.71031093597412 since the start of the code.
# Permit 19 finished at 1660100721.895461, after 1.5899860858917236, 31.300390005111694 since the start of the code.
# Permit 20 finished at 1660100723.519218, after 1.6236698627471924, 32.92414712905884 since the start of the code.
# Permit 21 finished at 1660100725.083436, after 1.5640621185302734, 34.48836374282837 since the start of the code.
# Permit 22 finished at 1660100726.6540349, after 1.5705280303955078, 36.05896306037903 since the start of the code.
# Permit 23 finished at 1660100728.204213, after 1.5501031875610352, 37.6091411113739 since the start of the code.
# Permit 24 finished at 1660100729.76252, after 1.5582289695739746, 39.16744780540466 since the start of the code.
# Permit 25 finished at 1660100731.335507, after 1.572918176651001, 40.74043607711792 since the start of the code.
# Permit 26 finished at 1660100732.8829, after 1.5472979545593262, 42.28782796859741 since the start of the code.
# Permit 27 finished at 1660100734.441601, after 1.5586402416229248, 43.84652805328369 since the start of the code.
# Permit 28 finished at 1660100735.993657, after 1.5519628524780273, 45.398584842681885 since the start of the code.
# Permit 29 finished at 1660100737.586102, after 1.5923821926116943, 46.99102973937988 since the start of the code.
# Permit 30 finished at 1660100739.1573708, after 1.5711889266967773, 48.56229901313782 since the start of the code.
# Permit 31 finished at 1660100740.732904, after 1.5754549503326416, 50.13783311843872 since the start of the code.
# Permit 32 finished at 1660100742.289473, after 1.5564630031585693, 51.694400787353516 since the start of the code.
# Permit 33 finished at 1660100743.841768, after 1.552232027053833, 53.246695041656494 since the start of the code.
# Permit 34 finished at 1660100745.4394329, after 1.5975911617279053, 54.84436106681824 since the start of the code.
# Permit 35 finished at 1660100746.998442, after 1.5589349269866943, 56.40337014198303 since the start of the code.
# Permit 36 finished at 1660100748.575536, after 1.5770199298858643, 57.98046398162842 since the start of the code.
# Permit 37 finished at 1660100750.133216, after 1.5575990676879883, 59.5381441116333 since the start of the code.
# Permit 38 finished at 1660100751.6962829, after 1.5629830360412598, 61.10120987892151 since the start of the code.
# Permit 39 finished at 1660100753.262123, after 1.5657782554626465, 62.66705107688904 since the start of the code.
# Permit 40 finished at 1660100754.821571, after 1.5593600273132324, 64.22650003433228 since the start of the code.
# Permit 41 finished at 1660100756.382452, after 1.5608022212982178, 65.78737902641296 since the start of the code.
# Permit 42 finished at 1660100757.953192, after 1.5706720352172852, 67.35811996459961 since the start of the code.
# Permit 43 finished at 1660100759.5134249, after 1.5601608753204346, 68.91835308074951 since the start of the code.
# Permit 44 finished at 1660100761.096471, after 1.5829839706420898, 70.50139999389648 since the start of the code.
# Permit 45 finished at 1660100762.6580842, after 1.5615360736846924, 72.06301093101501 since the start of the code.
# Permit 46 finished at 1660100764.2214122, after 1.5632669925689697, 73.62633991241455 since the start of the code.
# Permit 47 finished at 1660100765.784383, after 1.5628809928894043, 75.18930912017822 since the start of the code.
# Permit 48 finished at 1660100767.344963, after 1.5605390071868896, 76.74988985061646 since the start of the code.
# Permit 49 finished at 1660100768.901042, after 1.5559959411621094, 78.30596995353699 since the start of the code.
# Permit 50 finished at 1660100770.4576461, after 1.5565369129180908, 79.86257290840149 since the start of the code.
# Permit 51 finished at 1660100772.0170639, after 1.5593600273132324, 81.42199206352234 since the start of the code.
# Permit 52 finished at 1660100773.5745258, after 1.5572657585144043, 82.97945308685303 since the start of the code.
# Permit 53 finished at 1660100775.141518, after 1.5669188499450684, 84.54644584655762 since the start of the code.
# Permit 54 finished at 1660100776.70833, after 1.5667507648468018, 86.11325812339783 since the start of the code.
# Permit 55 finished at 1660100778.283734, after 1.5753352642059326, 87.68866181373596 since the start of the code.
# Permit 56 finished at 1660100779.859497, after 1.5756700038909912, 89.26442408561707 since the start of the code.
# Permit 57 finished at 1660100781.418543, after 1.558978796005249, 90.82347083091736 since the start of the code.
# Permit 58 finished at 1660100782.9718862, after 1.5532805919647217, 92.37681293487549 since the start of the code.
# Permit 59 finished at 1660100784.525857, after 1.5539040565490723, 93.93078398704529 since the start of the code.
# Permit 60 finished at 1660100786.095799, after 1.569880723953247, 95.50072693824768 since the start of the code.
# Permit 61 finished at 1660100787.663876, after 1.5680067539215088, 97.06880402565002 since the start of the code.
# Permit 62 finished at 1660100789.22802, after 1.5640602111816406, 98.63294816017151 since the start of the code.
# Permit 63 finished at 1660100790.786051, after 1.5579609870910645, 100.19097781181335 since the start of the code.
# Permit 64 finished at 1660100792.342196, after 1.5560829639434814, 101.74712300300598 since the start of the code.
# Permit 65 finished at 1660100793.902554, after 1.5602917671203613, 103.30748200416565 since the start of the code.
# Permit 66 finished at 1660100795.4667861, after 1.5641670227050781, 104.87171387672424 since the start of the code.
# Permit 67 finished at 1660100797.028328, after 1.561478853225708, 106.43325591087341 since the start of the code.
# Permit 68 finished at 1660100798.606595, after 1.5781807899475098, 108.01152396202087 since the start of the code.
# Permit 69 finished at 1660100800.183761, after 1.5770659446716309, 109.58869004249573 since the start of the code.
# Permit 70 finished at 1660100801.749621, after 1.5657751560211182, 111.15454912185669 since the start of the code.
# Permit 71 finished at 1660100803.313538, after 1.5638389587402344, 112.71846580505371 since the start of the code.
# Permit 72 finished at 1660100804.8779058, after 1.5642800331115723, 114.28283405303955 since the start of the code.
# Permit 73 finished at 1660100806.4565032, after 1.5785248279571533, 115.86143183708191 since the start of the code.
# Permit 74 finished at 1660100808.0274959, after 1.5709238052368164, 117.43242406845093 since the start of the code.
# Permit 75 finished at 1660100809.5871942, after 1.5596108436584473, 118.99212288856506 since the start of the code.
# Permit 76 finished at 1660100811.151529, after 1.5642712116241455, 120.55645704269409 since the start of the code.
# Permit 77 finished at 1660100812.7024739, after 1.5508708953857422, 122.10740113258362 since the start of the code.
# Permit 78 finished at 1660100814.2644749, after 1.5619351863861084, 123.66940402984619 since the start of the code.
# Permit 79 finished at 1660100815.8355289, after 1.5709850788116455, 125.24045705795288 since the start of the code.
# Permit 80 finished at 1660100817.397262, after 1.5616488456726074, 126.80219101905823 since the start of the code.
# Permit 81 finished at 1660100818.953981, after 1.5566461086273193, 128.35890889167786 since the start of the code.
# Permit 82 finished at 1660100820.517219, after 1.5631697177886963, 129.92214679718018 since the start of the code.
# Permit 83 finished at 1660100822.104297, after 1.5870130062103271, 131.50922513008118 since the start of the code.
# Permit 84 finished at 1660100823.662802, after 1.5584220886230469, 133.06772994995117 since the start of the code.
# Permit 85 finished at 1660100825.227539, after 1.564668893814087, 134.63246703147888 since the start of the code.
# Permit 86 finished at 1660100826.790271, after 1.562654972076416, 136.19519901275635 since the start of the code.
# Permit 87 finished at 1660100828.355705, after 1.5653676986694336, 137.76063299179077 since the start of the code.
# Permit 88 finished at 1660100829.911968, after 1.556185245513916, 139.31689405441284 since the start of the code.
# Permit 89 finished at 1660100831.4749062, after 1.562870979309082, 140.87983298301697 since the start of the code.
# Permit 90 finished at 1660100833.0477371, after 1.5727739334106445, 142.45266485214233 since the start of the code.
# Permit 91 finished at 1660100834.603276, after 1.5554687976837158, 144.0082037448883 since the start of the code.
# Permit 92 finished at 1660100836.163757, after 1.5604159832000732, 145.56868481636047 since the start of the code.
# Permit 93 finished at 1660100837.71788, after 1.5540528297424316, 147.12280797958374 since the start of the code.
# Permit 94 finished at 1660100839.286342, after 1.5683729648590088, 148.69126987457275 since the start of the code.
# Permit 95 finished at 1660100840.845376, after 1.5589489936828613, 150.25030398368835 since the start of the code.
# Permit 96 finished at 1660100842.4213572, after 1.5759141445159912, 151.8262848854065 since the start of the code.
# Permit 97 finished at 1660100843.971612, after 1.5501708984375, 153.37653994560242 since the start of the code.
# Permit 98 finished at 1660100845.525517, after 1.5538339614868164, 154.9304449558258 since the start of the code.
# Permit 99 finished at 1660100847.092997, after 1.567408800125122, 156.49792504310608 since the start of the code.
# Permit 100 finished at 1660100848.654774, after 1.5616958141326904, 158.05970191955566 since the start of the code.
# Permit 101 finished at 1660100850.2134311, after 1.5585811138153076, 159.61835885047913 since the start of the code.
# Permit 102 finished at 1660100851.7768672, after 1.563244104385376, 161.181795835495 since the start of the code.
# Permit 103 finished at 1660100853.3353221, after 1.5583827495574951, 162.74024987220764 since the start of the code.
# Permit 104 finished at 1660100854.915236, after 1.5798449516296387, 164.32016396522522 since the start of the code.
# Permit 105 finished at 1660100856.488575, after 1.5732500553131104, 165.89350199699402 since the start of the code.
# Permit 106 finished at 1660100858.0602748, after 1.5716149806976318, 167.4652030467987 since the start of the code.
# Permit 107 finished at 1660100859.625828, after 1.5654857158660889, 169.0307559967041 since the start of the code.
# Permit 108 finished at 1660100861.196886, after 1.570993185043335, 170.60181379318237 since the start of the code.
# Permit 109 finished at 1660100862.7571342, after 1.560175895690918, 172.16206192970276 since the start of the code.
# Permit 110 finished at 1660100864.3186188, after 1.5614101886749268, 173.72354698181152 since the start of the code.
# Permit 111 finished at 1660100865.895745, after 1.5770471096038818, 175.3006727695465 since the start of the code.
# Permit 112 finished at 1660100867.4651232, after 1.5692882537841797, 176.8700487613678 since the start of the code.
# Permit 113 finished at 1660100869.025013, after 1.559826135635376, 178.42994117736816 since the start of the code.
# Permit 114 finished at 1660100870.5854468, after 1.5603649616241455, 179.99037408828735 since the start of the code.
# Permit 115 finished at 1660100872.1488729, after 1.5633621215820312, 181.5538010597229 since the start of the code.
# Permit 116 finished at 1660100873.717493, after 1.5685429573059082, 183.12242102622986 since the start of the code.
# Permit 117 finished at 1660100875.279878, after 1.5623159408569336, 184.68480587005615 since the start of the code.
# Permit 118 finished at 1660100876.8485272, after 1.5685760974884033, 186.25345587730408 since the start of the code.
# Permit 119 finished at 1660100878.4144409, after 1.5658161640167236, 187.8193690776825 since the start of the code.
# Permit 120 finished at 1660100879.972619, after 1.5580999851226807, 189.37754607200623 since the start of the code.
# Permit 121 finished at 1660100881.532365, after 1.5596799850463867, 190.93729281425476 since the start of the code.
# Permit 122 finished at 1660100883.0982678, after 1.5658321380615234, 192.50319695472717 since the start of the code.
# Permit 123 finished at 1660100884.666199, after 1.5678527355194092, 194.07112789154053 since the start of the code.
# Permit 124 finished at 1660100886.233814, after 1.5674080848693848, 195.63874173164368 since the start of the code.
# Permit 125 finished at 1660100887.8002582, after 1.5663509368896484, 197.20518589019775 since the start of the code.
# Permit 126 finished at 1660100889.359862, after 1.5595309734344482, 198.7647898197174 since the start of the code.
# Permit 127 finished at 1660100890.915242, after 1.5553069114685059, 200.32017016410828 since the start of the code.
# Permit 128 finished at 1660100892.473678, after 1.55837082862854, 201.87860584259033 since the start of the code.
# Permit 129 finished at 1660100894.032356, after 1.5585968494415283, 203.43728399276733 since the start of the code.
# Permit 130 finished at 1660100895.588525, after 1.5561017990112305, 204.9934527873993 since the start of the code.
# Permit 131 finished at 1660100897.155953, after 1.5673630237579346, 206.56088089942932 since the start of the code.
# Permit 132 finished at 1660100898.7161112, after 1.5600810050964355, 208.1210389137268 since the start of the code.
# Permit 133 finished at 1660100900.274752, after 1.5585741996765137, 209.67968010902405 since the start of the code.
# Permit 134 finished at 1660100901.834765, after 1.5599467754364014, 211.23969197273254 since the start of the code.
# Permit 135 finished at 1660100903.410479, after 1.5756478309631348, 212.8154079914093 since the start of the code.
# Permit 136 finished at 1660100904.9728398, after 1.5622971057891846, 214.37776899337769 since the start of the code.
# Permit 137 finished at 1660100906.53614, after 1.5632107257843018, 215.94106793403625 since the start of the code.
# Permit 138 finished at 1660100908.103842, after 1.5676276683807373, 217.50876998901367 since the start of the code.
# Permit 139 finished at 1660100909.66045, after 1.556513786315918, 219.06537795066833 since the start of the code.
# Permit 140 finished at 1660100911.2247622, after 1.564222812652588, 220.6296889781952 since the start of the code.
# Permit 141 finished at 1660100912.783495, after 1.5586700439453125, 222.1884241104126 since the start of the code.
# Permit 142 finished at 1660100914.350816, after 1.5672531127929688, 223.7557430267334 since the start of the code.
# Permit 143 finished at 1660100915.9194088, after 1.568526268005371, 225.32433700561523 since the start of the code.
# Permit 144 finished at 1660100917.487957, after 1.5684840679168701, 226.8928849697113 since the start of the code.
# Permit 145 finished at 1660100919.047132, after 1.558962106704712, 228.45205998420715 since the start of the code.
# Permit 146 finished at 1660100920.613924, after 1.5667228698730469, 230.01885080337524 since the start of the code.
# Permit 147 finished at 1660100922.1778922, after 1.5639030933380127, 231.58282089233398 since the start of the code.
# Permit 148 finished at 1660100923.7379441, after 1.5599708557128906, 233.14287185668945 since the start of the code.
# Permit 149 finished at 1660100925.305961, after 1.5679347515106201, 234.71088910102844 since the start of the code.
# Permit 150 finished at 1660100926.890003, after 1.5839378833770752, 236.2949321269989 since the start of the code.
# Permit 151 finished at 1660100928.449441, after 1.559345006942749, 237.8543689250946 since the start of the code.
# Permit 152 finished at 1660100930.010637, after 1.5611178874969482, 239.41556477546692 since the start of the code.
# Permit 153 finished at 1660100931.574393, after 1.5635578632354736, 240.97932195663452 since the start of the code.
# Permit 154 finished at 1660100933.1461902, after 1.571725845336914, 242.5511178970337 since the start of the code.
# Permit 155 finished at 1660100934.702098, after 1.5558369159698486, 244.1070261001587 since the start of the code.
# Permit 156 finished at 1660100936.265387, after 1.5632250308990479, 245.67031574249268 since the start of the code.
# Permit 157 finished at 1660100937.829039, after 1.5635828971862793, 247.23396682739258 since the start of the code.
# Permit 158 finished at 1660100939.381561, after 1.5524349212646484, 248.78648900985718 since the start of the code.
# Permit 159 finished at 1660100940.937362, after 1.5557382106781006, 250.34228992462158 since the start of the code.
# Permit 160 finished at 1660100942.502678, after 1.5652480125427246, 251.9076051712036 since the start of the code.
# Permit 161 finished at 1660100944.0644321, after 1.5616838932037354, 253.46936106681824 since the start of the code.
# Permit 162 finished at 1660100945.614284, after 1.5497667789459229, 255.019211769104 since the start of the code.
# Permit 163 finished at 1660100947.1691751, after 1.5548110008239746, 256.57410287857056 since the start of the code.
# Permit 164 finished at 1660100948.723068, after 1.5538182258605957, 258.127995967865 since the start of the code.
# Permit 165 finished at 1660100950.2910662, after 1.5679309368133545, 259.6959939002991 since the start of the code.
# Permit 166 finished at 1660100951.841515, after 1.5503690242767334, 261.2464430332184 since the start of the code.
# Permit 167 finished at 1660100953.4099042, after 1.5683190822601318, 262.8148329257965 since the start of the code.
# Permit 168 finished at 1660100954.957053, after 1.547071933746338, 264.3619821071625 since the start of the code.
# Permit 169 finished at 1660100956.522241, after 1.5651121139526367, 265.92716884613037 since the start of the code.
# Permit 170 finished at 1660100958.08303, after 1.5607199668884277, 267.48795890808105 since the start of the code.
# Permit 171 finished at 1660100959.635869, after 1.5527429580688477, 269.04079699516296 since the start of the code.
# Permit 172 finished at 1660100961.192987, after 1.5570471286773682, 270.5979149341583 since the start of the code.
# Permit 173 finished at 1660100962.7423239, after 1.5492630004882812, 272.1472511291504 since the start of the code.
# Permit 174 finished at 1660100964.2972748, after 1.5548839569091797, 273.7022030353546 since the start of the code.
# Permit 175 finished at 1660100965.8484411, after 1.5510988235473633, 275.2533688545227 since the start of the code.
# Permit 176 finished at 1660100967.426054, after 1.5775408744812012, 276.8309829235077 since the start of the code.
# Permit 177 finished at 1660100968.976581, after 1.5504539012908936, 278.38151001930237 since the start of the code.
# Permit 178 finished at 1660100970.550242, after 1.5735890865325928, 279.95516991615295 since the start of the code.
# Permit 179 finished at 1660100972.121611, after 1.5712981224060059, 281.52653980255127 since the start of the code.
# Permit 180 finished at 1660100973.683351, after 1.56166672706604, 283.0882787704468 since the start of the code.
# Permit 181 finished at 1660100975.2385201, after 1.5551068782806396, 284.64344787597656 since the start of the code.
# Permit 182 finished at 1660100976.792382, after 1.5537960529327393, 286.1973099708557 since the start of the code.
# Permit 183 finished at 1660100978.3491461, after 1.5566909313201904, 287.7540738582611 since the start of the code.
# Permit 184 finished at 1660100979.90731, after 1.5580837726593018, 289.31223797798157 since the start of the code.
# Permit 185 finished at 1660100981.48135, after 1.5739679336547852, 290.88627791404724 since the start of the code.
# Permit 186 finished at 1660100983.049807, after 1.568382978439331, 292.4547350406647 since the start of the code.
# Permit 187 finished at 1660100984.604576, after 1.5546963214874268, 294.0095040798187 since the start of the code.
# Permit 188 finished at 1660100986.1536372, after 1.5489850044250488, 295.55856585502625 since the start of the code.
# Permit 189 finished at 1660100987.713504, after 1.559805154800415, 297.1184320449829 since the start of the code.
# Permit 190 finished at 1660100989.27314, after 1.5595571994781494, 298.67806911468506 since the start of the code.
# Permit 191 finished at 1660100990.8444202, after 1.5711979866027832, 300.24934792518616 since the start of the code.
# Permit 192 finished at 1660100992.403463, after 1.5589711666107178, 301.80839109420776 since the start of the code.
# Permit 193 finished at 1660100993.973845, after 1.5703022480010986, 303.3787729740143 since the start of the code.
# Permit 194 finished at 1660100995.531753, after 1.5578281879425049, 304.9366810321808 since the start of the code.
# Permit 195 finished at 1660100997.094713, after 1.5628900527954102, 306.4996409416199 since the start of the code.
# Permit 196 finished at 1660100998.65165, after 1.556861162185669, 308.0565779209137 since the start of the code.
# Permit 197 finished at 1660101000.219969, after 1.5682389736175537, 309.62489676475525 since the start of the code.
# Permit 198 finished at 1660101001.786966, after 1.5669260025024414, 311.19189381599426 since the start of the code.
# Permit 199 finished at 1660101003.339953, after 1.552922010421753, 312.7448809146881 since the start of the code.
# Permit 200 finished at 1660101004.884036, after 1.5440068244934082, 314.28896284103394 since the start of the code.
# Permit 201 finished at 1660101006.4392178, after 1.5551130771636963, 315.8441469669342 since the start of the code.
# Permit 202 finished at 1660101008.011418, after 1.5721311569213867, 317.41634702682495 since the start of the code.
# Permit 203 finished at 1660101009.5647192, after 1.5532159805297852, 318.9696469306946 since the start of the code.
# Permit 204 finished at 1660101011.122098, after 1.5573170185089111, 320.52702593803406 since the start of the code.
# Permit 205 finished at 1660101012.677709, after 1.5555369853973389, 322.0826368331909 since the start of the code.
# Permit 206 finished at 1660101014.2345579, after 1.5567753314971924, 323.63948607444763 since the start of the code.
# Permit 207 finished at 1660101015.79541, after 1.5607857704162598, 325.2003378868103 since the start of the code.
# Permit 208 finished at 1660101017.356456, after 1.5609807968139648, 326.76138401031494 since the start of the code.
# Permit 209 finished at 1660101018.9142232, after 1.557682991027832, 328.3191509246826 since the start of the code.
# Permit 210 finished at 1660101020.472944, after 1.5586519241333008, 329.87787199020386 since the start of the code.
# Permit 211 finished at 1660101022.028446, after 1.5554349422454834, 331.43337297439575 since the start of the code.
# Permit 212 finished at 1660101023.5921311, after 1.5636188983917236, 332.9970588684082 since the start of the code.
# Permit 213 finished at 1660101025.156661, after 1.5644581317901611, 334.56158900260925 since the start of the code.
# Permit 214 finished at 1660101026.717344, after 1.5606162548065186, 336.1222720146179 since the start of the code.
# Permit 215 finished at 1660101028.280664, after 1.5632359981536865, 337.68559288978577 since the start of the code.
# Permit 216 finished at 1660101029.837622, after 1.5568671226501465, 339.24254989624023 since the start of the code.
# Permit 217 finished at 1660101031.3951738, after 1.5574769973754883, 340.80010199546814 since the start of the code.
# Permit 218 finished at 1660101032.972499, after 1.577258825302124, 342.37742710113525 since the start of the code.
# Permit 219 finished at 1660101034.5293388, after 1.556764841079712, 343.9342670440674 since the start of the code.
# Permit 220 finished at 1660101036.109662, after 1.5802521705627441, 345.5145900249481 since the start of the code.
# Permit 221 finished at 1660101037.701322, after 1.5915911197662354, 347.10625076293945 since the start of the code.
# Permit 222 finished at 1660101039.2559319, after 1.5545237064361572, 348.6608600616455 since the start of the code.
# Permit 223 finished at 1660101040.822009, after 1.5660128593444824, 350.2269368171692 since the start of the code.
# Permit 224 finished at 1660101042.37748, after 1.5553851127624512, 351.7824079990387 since the start of the code.
# Permit 225 finished at 1660101043.943715, after 1.5661678314208984, 353.3486428260803 since the start of the code.
# Permit 226 finished at 1660101045.508458, after 1.5646710395812988, 354.9133861064911 since the start of the code.
# Permit 227 finished at 1660101047.06966, after 1.5611350536346436, 356.4745891094208 since the start of the code.
# Permit 228 finished at 1660101048.6170392, after 1.5473108291625977, 358.0219669342041 since the start of the code.
# Permit 229 finished at 1660101050.185514, after 1.5684001445770264, 359.59044098854065 since the start of the code.
# Permit 230 finished at 1660101051.744523, after 1.5589420795440674, 361.1494507789612 since the start of the code.
# Permit 231 finished at 1660101053.297853, after 1.5532610416412354, 362.7027819156647 since the start of the code.
# Permit 232 finished at 1660101054.86802, after 1.5701000690460205, 364.2729480266571 since the start of the code.
# Permit 233 finished at 1660101056.4256241, after 1.5575001239776611, 365.8305518627167 since the start of the code.
# Permit 234 finished at 1660101057.978687, after 1.5529892444610596, 367.38361501693726 since the start of the code.
# Permit 235 finished at 1660101059.545752, after 1.5669798851013184, 368.95067977905273 since the start of the code.
# Permit 236 finished at 1660101061.1064708, after 1.5606369972229004, 370.5113990306854 since the start of the code.
# Permit 237 finished at 1660101062.6682932, after 1.5617401599884033, 372.07322096824646 since the start of the code.
# Permit 238 finished at 1660101064.2385228, after 1.570152997970581, 373.6434509754181 since the start of the code.
# Permit 239 finished at 1660101065.822922, after 1.5843219757080078, 375.22784996032715 since the start of the code.
# Permit 240 finished at 1660101067.378794, after 1.5557968616485596, 376.783723115921 since the start of the code.
# Permit 241 finished at 1660101068.948705, after 1.5698280334472656, 378.3536329269409 since the start of the code.
# Permit 242 finished at 1660101070.515313, after 1.5665338039398193, 379.92024087905884 since the start of the code.
# Permit 243 finished at 1660101072.081517, after 1.5661110877990723, 381.48644495010376 since the start of the code.
# Permit 244 finished at 1660101073.6459541, after 1.5643680095672607, 383.0508818626404 since the start of the code.
# Permit 245 finished at 1660101075.204043, after 1.5580079555511475, 384.6089701652527 since the start of the code.
# Permit 246 finished at 1660101076.755554, after 1.551438808441162, 386.16048192977905 since the start of the code.
# Permit 247 finished at 1660101078.3105228, after 1.5548968315124512, 387.71545004844666 since the start of the code.
# Permit 248 finished at 1660101079.883156, after 1.5725460052490234, 389.2880849838257 since the start of the code.
# Permit 249 finished at 1660101081.433286, after 1.5500621795654297, 390.83821392059326 since the start of the code.
# Permit 250 finished at 1660101082.9852328, after 1.5518770217895508, 392.39016103744507 since the start of the code.
# Permit 251 finished at 1660101084.5426, after 1.5572972297668457, 393.9475290775299 since the start of the code.
# Permit 252 finished at 1660101086.1014059, after 1.5587332248687744, 395.5063350200653 since the start of the code.
# Permit 253 finished at 1660101087.663336, after 1.561861276626587, 397.06826400756836 since the start of the code.
# Permit 254 finished at 1660101089.225503, after 1.5620989799499512, 398.63043117523193 since the start of the code.
# Permit 255 finished at 1660101090.793375, after 1.5678021907806396, 400.19830417633057 since the start of the code.
# Permit 256 finished at 1660101092.367245, after 1.5737900733947754, 401.77217292785645 since the start of the code.
# Permit 257 finished at 1660101093.9338722, after 1.5665481090545654, 403.3387999534607 since the start of the code.
# Permit 258 finished at 1660101095.4895449, after 1.5556013584136963, 404.8944730758667 since the start of the code.
# Permit 259 finished at 1660101097.067174, after 1.5775620937347412, 406.4721019268036 since the start of the code.
# Permit 260 finished at 1660101098.619092, after 1.5518372058868408, 408.02401995658875 since the start of the code.
# Permit 261 finished at 1660101100.186346, after 1.5671801567077637, 409.59127402305603 since the start of the code.
# Permit 262 finished at 1660101101.740183, after 1.5537450313568115, 411.1451108455658 since the start of the code.
# Permit 263 finished at 1660101103.313, after 1.5727510452270508, 412.71792793273926 since the start of the code.
# Permit 264 finished at 1660101104.8675299, after 1.5544519424438477, 414.27245712280273 since the start of the code.
# Permit 265 finished at 1660101106.432729, after 1.5651366710662842, 415.8376569747925 since the start of the code.
# Permit 266 finished at 1660101107.9939861, after 1.5611841678619385, 417.39891386032104 since the start of the code.
# Permit 267 finished at 1660101109.5471082, after 1.553044080734253, 418.95203590393066 since the start of the code.
# Permit 268 finished at 1660101111.098644, after 1.5514731407165527, 420.5035719871521 since the start of the code.
# Permit 269 finished at 1660101112.6537862, after 1.5550742149353027, 422.05871295928955 since the start of the code.
# Permit 270 finished at 1660101114.207756, after 1.5539007186889648, 423.61268496513367 since the start of the code.
# Permit 271 finished at 1660101115.7775629, after 1.5697357654571533, 425.18249106407166 since the start of the code.
# Permit 272 finished at 1660101117.337352, after 1.55971097946167, 426.7422790527344 since the start of the code.
# Permit 273 finished at 1660101118.892499, after 1.5550739765167236, 428.2974269390106 since the start of the code.
# Permit 274 finished at 1660101120.4433222, after 1.5507447719573975, 429.84824991226196 since the start of the code.
# Permit 275 finished at 1660101122.0179799, after 1.574591875076294, 431.42290806770325 since the start of the code.
# Permit 276 finished at 1660101123.585422, after 1.5673677921295166, 432.99035000801086 since the start of the code.
# Permit 277 finished at 1660101125.1579971, after 1.5724973678588867, 434.56292390823364 since the start of the code.
# Permit 278 finished at 1660101126.7247329, after 1.5666728019714355, 436.12966203689575 since the start of the code.
# Permit 279 finished at 1660101128.279864, after 1.5550510883331299, 437.68479180336 since the start of the code.
# Permit 280 finished at 1660101129.838412, after 1.558466911315918, 439.2433397769928 since the start of the code.
# Permit 281 finished at 1660101131.4010339, after 1.5625591278076172, 440.8059620857239 since the start of the code.
# Permit 282 finished at 1660101132.9522922, after 1.5511691570281982, 442.3572199344635 since the start of the code.
# Permit 283 finished at 1660101134.517261, after 1.5649058818817139, 443.9221889972687 since the start of the code.
# Permit 284 finished at 1660101136.08114, after 1.5638060569763184, 445.4860680103302 since the start of the code.
# Permit 285 finished at 1660101137.635193, after 1.553980827331543, 447.04012084007263 since the start of the code.
# Permit 286 finished at 1660101139.197001, after 1.5617332458496094, 448.6019289493561 since the start of the code.
# Permit 287 finished at 1660101140.759205, after 1.5621230602264404, 450.1641318798065 since the start of the code.
# Permit 288 finished at 1660101142.3275058, after 1.5682260990142822, 451.7324330806732 since the start of the code.
# Permit 289 finished at 1660101143.88383, after 1.5562422275543213, 453.28875708580017 since the start of the code.
# Permit 290 finished at 1660101145.4451299, after 1.5612342357635498, 454.8500587940216 since the start of the code.
# Permit 291 finished at 1660101147.013172, after 1.5679750442504883, 456.4181001186371 since the start of the code.
# Permit 292 finished at 1660101148.5644338, after 1.5510611534118652, 457.96936202049255 since the start of the code.
# Permit 293 finished at 1660101150.11992, after 1.5554039478302002, 459.52484703063965 since the start of the code.
# Permit 294 finished at 1660101151.671655, after 1.5516679286956787, 461.07658290863037 since the start of the code.
# Permit 295 finished at 1660101153.2212338, after 1.5495107173919678, 462.62616300582886 since the start of the code.
# Permit 296 finished at 1660101154.7746692, after 1.55336594581604, 464.17959785461426 since the start of the code.
# Permit 297 finished at 1660101156.3394802, after 1.564734935760498, 465.7444078922272 since the start of the code.
# Permit 298 finished at 1660101157.8898098, after 1.5502619743347168, 467.2947380542755 since the start of the code.
# Permit 299 finished at 1660101159.451725, after 1.5618267059326172, 468.8566529750824 since the start of the code.
# Permit 300 finished at 1660101161.021787, after 1.569998025894165, 470.42671489715576 since the start of the code.
# Permit 301 finished at 1660101162.573354, after 1.5514979362487793, 471.9782819747925 since the start of the code.
# Permit 302 finished at 1660101164.141983, after 1.5685539245605469, 473.54691219329834 since the start of the code.
# Permit 303 finished at 1660101165.7062259, after 1.5641632080078125, 475.1111550331116 since the start of the code.
# Permit 304 finished at 1660101167.268781, after 1.5623629093170166, 476.67370986938477 since the start of the code.
# Permit 305 finished at 1660101168.833032, after 1.5641729831695557, 478.23796010017395 since the start of the code.
# Permit 306 finished at 1660101170.389738, after 1.5566191673278809, 479.7946660518646 since the start of the code.
# Permit 307 finished at 1660101171.9505038, after 1.5606930255889893, 481.3554320335388 since the start of the code.
# Permit 308 finished at 1660101173.51149, after 1.5609180927276611, 482.91641783714294 since the start of the code.
# Permit 309 finished at 1660101175.073157, after 1.5615968704223633, 484.47808384895325 since the start of the code.
# Permit 310 finished at 1660101176.632479, after 1.5592529773712158, 486.0374071598053 since the start of the code.
# Permit 311 finished at 1660101178.18316, after 1.5506088733673096, 487.5880877971649 since the start of the code.
# Permit 312 finished at 1660101179.736172, after 1.552933931350708, 489.1411008834839 since the start of the code.
# Permit 313 finished at 1660101181.299478, after 1.5632362365722656, 490.7044050693512 since the start of the code.
# Permit 314 finished at 1660101182.875402, after 1.575836181640625, 492.2803301811218 since the start of the code.
# Permit 315 finished at 1660101184.43508, after 1.559596061706543, 493.840008020401 since the start of the code.
# Permit 316 finished at 1660101185.9953432, after 1.5600557327270508, 495.400269985199 since the start of the code.
# Permit 317 finished at 1660101187.563072, after 1.567647933959961, 496.9680001735687 since the start of the code.
# Permit 318 finished at 1660101189.116423, after 1.5532820224761963, 498.5213520526886 since the start of the code.
# Permit 319 finished at 1660101190.681195, after 1.5646820068359375, 500.08612298965454 since the start of the code.
# Permit 320 finished at 1660101192.230562, after 1.5491681098937988, 501.6354899406433 since the start of the code.
# Permit 321 finished at 1660101193.7837172, after 1.55305814743042, 503.18864393234253 since the start of the code.
# Permit 322 finished at 1660101195.3438668, after 1.5600779056549072, 504.7487950325012 since the start of the code.
# Permit 323 finished at 1660101196.908245, after 1.5642971992492676, 506.3131730556488 since the start of the code.
# Permit 324 finished at 1660101198.473783, after 1.5654668807983398, 507.87871193885803 since the start of the code.
# Permit 325 finished at 1660101200.052563, after 1.5787091255187988, 509.4574909210205 since the start of the code.
# Permit 326 finished at 1660101201.610007, after 1.5573623180389404, 511.0149338245392 since the start of the code.
# Permit 327 finished at 1660101203.1624582, after 1.5523710250854492, 512.5673868656158 since the start of the code.
# Permit 328 finished at 1660101204.713753, after 1.55122709274292, 514.1186809539795 since the start of the code.
# Permit 329 finished at 1660101206.272196, after 1.5583698749542236, 515.6771240234375 since the start of the code.
# Permit 330 finished at 1660101207.81494, after 1.5426719188690186, 517.2198669910431 since the start of the code.
# Permit 331 finished at 1660101209.3622599, after 1.5472571849822998, 518.7671880722046 since the start of the code.
# Permit 332 finished at 1660101210.9241421, after 1.5618131160736084, 520.329069852829 since the start of the code.
# Permit 333 finished at 1660101212.48098, after 1.5567591190338135, 521.8859090805054 since the start of the code.
# Permit 334 finished at 1660101214.0326002, after 1.5515336990356445, 523.4375269412994 since the start of the code.
# Permit 335 finished at 1660101215.595636, after 1.5628433227539062, 525.0005640983582 since the start of the code.
# Permit 336 finished at 1660101217.148895, after 1.5530681610107422, 526.5538220405579 since the start of the code.
# Permit 337 finished at 1660101218.694793, after 1.5458180904388428, 528.099720954895 since the start of the code.
# Permit 338 finished at 1660101220.2567801, after 1.5619139671325684, 529.6617078781128 since the start of the code.
# Permit 339 finished at 1660101221.829704, after 1.5728487968444824, 531.2346320152283 since the start of the code.
# Permit 340 finished at 1660101223.3996658, after 1.5698931217193604, 532.8045930862427 since the start of the code.
# Permit 341 finished at 1660101224.9549592, after 1.5552170276641846, 534.3598878383636 since the start of the code.
# Permit 342 finished at 1660101226.51681, after 1.5617780685424805, 535.9217381477356 since the start of the code.
# Permit 343 finished at 1660101228.067411, after 1.550529956817627, 537.4723389148712 since the start of the code.
# Permit 344 finished at 1660101229.619184, after 1.5516879558563232, 539.0241119861603 since the start of the code.
# Permit 345 finished at 1660101231.192205, after 1.572948932647705, 540.5971329212189 since the start of the code.
# Permit 346 finished at 1660101232.762034, after 1.5696330070495605, 542.1669631004333 since the start of the code.
# Permit 347 finished at 1660101234.313279, after 1.5511620044708252, 543.7182071208954 since the start of the code.
# Permit 348 finished at 1660101235.8697972, after 1.556447982788086, 545.2747240066528 since the start of the code.
# Permit 349 finished at 1660101237.43586, after 1.5659923553466797, 546.8407890796661 since the start of the code.
# Permit 350 finished at 1660101238.985483, after 1.549544334411621, 548.390410900116 since the start of the code.
# Permit 351 finished at 1660101240.551032, after 1.5654609203338623, 549.9559597969055 since the start of the code.
# Permit 352 finished at 1660101242.098729, after 1.5476100444793701, 551.5036571025848 since the start of the code.
# Permit 353 finished at 1660101243.6560068, after 1.5572052001953125, 553.0609350204468 since the start of the code.
# Permit 354 finished at 1660101245.214132, after 1.5580511093139648, 554.6190600395203 since the start of the code.
# Permit 355 finished at 1660101246.7688909, after 1.5546839237213135, 556.1738200187683 since the start of the code.
# Permit 356 finished at 1660101248.3368409, after 1.5678820610046387, 557.741770029068 since the start of the code.
# Permit 357 finished at 1660101249.88935, after 1.5524249076843262, 559.2942790985107 since the start of the code.
# Permit 358 finished at 1660101251.440203, after 1.5507640838623047, 560.8451309204102 since the start of the code.
# Permit 359 finished at 1660101252.990669, after 1.5503828525543213, 562.3955969810486 since the start of the code.
# Permit 360 finished at 1660101254.548021, after 1.5572690963745117, 563.9529490470886 since the start of the code.
# Permit 361 finished at 1660101256.109301, after 1.5612132549285889, 565.5142290592194 since the start of the code.
# Permit 362 finished at 1660101257.671366, after 1.561974048614502, 567.0762939453125 since the start of the code.
# Permit 363 finished at 1660101259.224094, after 1.5526618957519531, 568.6290221214294 since the start of the code.
# Permit 364 finished at 1660101260.7861602, after 1.562000036239624, 570.1910879611969 since the start of the code.
# Permit 365 finished at 1660101262.341822, after 1.555577039718628, 571.7467501163483 since the start of the code.
# Permit 366 finished at 1660101263.8990872, after 1.5571961402893066, 573.3040158748627 since the start of the code.
# Permit 367 finished at 1660101265.44936, after 1.5502049922943115, 574.8542878627777 since the start of the code.
# Permit 368 finished at 1660101267.007453, after 1.5580191612243652, 576.4123809337616 since the start of the code.
# Permit 369 finished at 1660101268.566414, after 1.558884859085083, 577.9713418483734 since the start of the code.
# Permit 370 finished at 1660101270.140812, after 1.5743188858032227, 579.5457398891449 since the start of the code.
# Permit 371 finished at 1660101271.6934521, after 1.552565097808838, 581.0983808040619 since the start of the code.
# Permit 372 finished at 1660101273.253286, after 1.5597608089447021, 582.6582129001617 since the start of the code.
# Permit 373 finished at 1660101274.820182, after 1.566823959350586, 584.2251107692719 since the start of the code.
# Permit 374 finished at 1660101276.405031, after 1.5846450328826904, 585.8099589347839 since the start of the code.
# Permit 375 finished at 1660101277.953541, after 1.5484378337860107, 587.3584690093994 since the start of the code.
# Permit 376 finished at 1660101279.506187, after 1.552563190460205, 588.9111149311066 since the start of the code.
# Permit 377 finished at 1660101281.0800729, after 1.5738160610198975, 590.4850010871887 since the start of the code.
# Permit 378 finished at 1660101282.6264808, after 1.5463261604309082, 592.0314090251923 since the start of the code.
# Permit 379 finished at 1660101284.189603, after 1.563053846359253, 593.5945320129395 since the start of the code.
# Permit 380 finished at 1660101285.7384808, after 1.5488049983978271, 595.1434090137482 since the start of the code.
# Permit 381 finished at 1660101287.301721, after 1.5631718635559082, 596.7066488265991 since the start of the code.
# Permit 382 finished at 1660101288.865545, after 1.5637462139129639, 598.2704730033875 since the start of the code.
# Permit 383 finished at 1660101290.43547, after 1.569861888885498, 599.8403978347778 since the start of the code.
# Permit 384 finished at 1660101291.996667, after 1.5611248016357422, 601.401594877243 since the start of the code.
# Permit 385 finished at 1660101293.549263, after 1.5525178909301758, 602.9541909694672 since the start of the code.
# Permit 386 finished at 1660101295.120517, after 1.5711851119995117, 604.5254459381104 since the start of the code.
# Permit 387 finished at 1660101296.690936, after 1.5703260898590088, 606.0958638191223 since the start of the code.
# Permit 388 finished at 1660101298.247951, after 1.5569360256195068, 607.6528778076172 since the start of the code.
# Permit 389 finished at 1660101299.796105, after 1.548058032989502, 609.201033115387 since the start of the code.
# Permit 390 finished at 1660101301.364428, after 1.5682477951049805, 610.7693557739258 since the start of the code.
# Permit 391 finished at 1660101302.928514, after 1.5640146732330322, 612.3334419727325 since the start of the code.
# Permit 392 finished at 1660101304.489635, after 1.5610458850860596, 613.894562959671 since the start of the code.
# Permit 393 finished at 1660101306.0395179, after 1.5496819019317627, 615.4444448947906 since the start of the code.
# Permit 394 finished at 1660101307.6027572, after 1.5631706714630127, 617.0076849460602 since the start of the code.
# Permit 395 finished at 1660101309.169377, after 1.5665411949157715, 618.574304819107 since the start of the code.
# Permit 396 finished at 1660101310.742004, after 1.572544813156128, 620.1469321250916 since the start of the code.
# Permit 397 finished at 1660101312.295372, after 1.5532748699188232, 621.7002997398376 since the start of the code.
# Permit 398 finished at 1660101313.8503182, after 1.5548830032348633, 623.2552468776703 since the start of the code.
# Permit 399 finished at 1660101315.407698, after 1.5573019981384277, 624.8126258850098 since the start of the code.
# Permit 400 finished at 1660101316.971405, after 1.5636398792266846, 626.3763318061829 since the start of the code.
# Permit 401 finished at 1660101318.5330591, after 1.5615730285644531, 627.9379858970642 since the start of the code.
# Permit 402 finished at 1660101320.0980108, after 1.564889907836914, 629.5029389858246 since the start of the code.
# Permit 403 finished at 1660101321.670688, after 1.5726032257080078, 631.0756161212921 since the start of the code.
# Permit 404 finished at 1660101323.239212, after 1.5684490203857422, 632.6441397666931 since the start of the code.
# Permit 405 finished at 1660101324.803133, after 1.5638480186462402, 634.2080609798431 since the start of the code.
# Permit 406 finished at 1660101326.376142, after 1.5729448795318604, 635.7810699939728 since the start of the code.
# Permit 407 finished at 1660101327.9388502, after 1.5626299381256104, 637.3437778949738 since the start of the code.
# Permit 408 finished at 1660101329.516022, after 1.5770900249481201, 638.9209499359131 since the start of the code.
# Permit 409 finished at 1660101331.0840168, after 1.5679099559783936, 640.4889450073242 since the start of the code.
# Permit 410 finished at 1660101332.6511402, after 1.5670480728149414, 642.0560688972473 since the start of the code.
# Permit 411 finished at 1660101334.2136252, after 1.5624158382415771, 643.6185529232025 since the start of the code.
# Permit 412 finished at 1660101335.7807841, after 1.567077875137329, 645.1857109069824 since the start of the code.
# Permit 413 finished at 1660101337.33905, after 1.5581960678100586, 646.743978023529 since the start of the code.
# Permit 414 finished at 1660101338.8957021, after 1.556584358215332, 648.3006298542023 since the start of the code.
# Permit 415 finished at 1660101340.463354, after 1.5675790309906006, 649.8682818412781 since the start of the code.
# ...
# Permit 593 finished at 1660101620.0932071, after 1.5515789985656738, 929.4981348514557 since the start of the code.
# Permit 594 finished at 1660101621.655154, after 1.5618810653686523, 931.0600819587708 since the start of the code.
# Permit 595 finished at 1660101623.21542, after 1.5601987838745117, 932.6203470230103 since the start of the code.
# Permit 596 finished at 1660101624.797195, after 1.5817058086395264, 934.202122926712 since the start of the code.
# Permit 597 finished at 1660101626.363613, after 1.566349983215332, 935.7685399055481 since the start of the code.
# Permit 598 finished at 1660101627.940452, after 1.576768159866333, 937.3453798294067 since the start of the code.
# Permit 599 finished at 1660101629.527763, after 1.5872259140014648, 938.9326910972595 since the start of the code.
# Permit 600 finished at 1660101631.099461, after 1.5716218948364258, 940.5043890476227 since the start of the code.
# Permit 601 finished at 1660101632.66884, after 1.5693061351776123, 942.0737669467926 since the start of the code.
# Permit 602 finished at 1660101634.265684, after 1.5967700481414795, 943.6706120967865 since the start of the code.
# Permit 603 finished at 1660101635.818986, after 1.553217887878418, 945.2239141464233 since the start of the code.
# Permit 604 finished at 1660101637.416704, after 1.597641944885254, 946.8216321468353 since the start of the code.
# Permit 605 finished at 1660101638.974834, after 1.5580580234527588, 948.3797619342804 since the start of the code.
# Permit 606 finished at 1660101640.533439, after 1.5585401058197021, 949.9383680820465 since the start of the code.
# Permit 607 finished at 1660101642.086007, after 1.5524959564208984, 951.4909348487854 since the start of the code.
# Permit 608 finished at 1660101643.695783, after 1.6097068786621094, 953.1007120609283 since the start of the code.
# Permit 609 finished at 1660101645.25178, after 1.5559217929840088, 954.6567080020905 since the start of the code.
# Permit 610 finished at 1660101646.8083909, after 1.5565381050109863, 956.2133190631866 since the start of the code.
# Permit 611 finished at 1660101648.375971, after 1.567511796951294, 957.780898809433 since the start of the code.
# Permit 612 finished at 1660101649.95724, after 1.5811858177185059, 959.3621690273285 since the start of the code.
# Permit 613 finished at 1660101651.5187042, after 1.5613508224487305, 960.9236319065094 since the start of the code.
# Permit 614 finished at 1660101653.112243, after 1.593468189239502, 962.5171711444855 since the start of the code.
# Permit 615 finished at 1660101654.734375, after 1.622061014175415, 964.1393029689789 since the start of the code.
# Permit 616 finished at 1660101656.3405561, after 1.6061038970947266, 965.7454838752747 since the start of the code.
# Permit 617 finished at 1660101657.937492, after 1.596858024597168, 967.3424201011658 since the start of the code.
# Permit 618 finished at 1660101659.495695, after 1.5581178665161133, 968.900622844696 since the start of the code.
# Permit 619 finished at 1660101661.054952, after 1.5590639114379883, 970.4598801136017 since the start of the code.
# Permit 620 finished at 1660101662.6151822, after 1.560154914855957, 972.0201108455658 since the start of the code.
# Permit 621 finished at 1660101664.198447, after 1.5831859111785889, 973.6033759117126 since the start of the code.
# Permit 622 finished at 1660101665.761377, after 1.5628621578216553, 975.1663057804108 since the start of the code.
# Permit 623 finished at 1660101667.330501, after 1.569058895111084, 976.7354290485382 since the start of the code.
# Permit 624 finished at 1660101668.938751, after 1.608173131942749, 978.3436789512634 since the start of the code.
# Permit 625 finished at 1660101670.555056, after 1.6162281036376953, 979.9599850177765 since the start of the code.
# Permit 626 finished at 1660101672.131813, after 1.5766658782958984, 981.5367410182953 since the start of the code.
# Permit 627 finished at 1660101673.743062, after 1.6111750602722168, 983.1479897499084 since the start of the code.
# Permit 628 finished at 1660101675.3024151, after 1.5592567920684814, 984.7073419094086 since the start of the code.
# Permit 629 finished at 1660101676.873329, after 1.5708470344543457, 986.278256893158 since the start of the code.
# Permit 630 finished at 1660101678.453536, after 1.5801341533660889, 987.8584649562836 since the start of the code.
# Permit 631 finished at 1660101680.010577, after 1.5569639205932617, 989.4155049324036 since the start of the code.
# Permit 632 finished at 1660101681.5917141, after 1.5810699462890625, 990.9966418743134 since the start of the code.
# Permit 633 finished at 1660101683.197831, after 1.6060521602630615, 992.6027600765228 since the start of the code.
# Permit 634 finished at 1660101684.772745, after 1.574847936630249, 994.1776731014252 since the start of the code.
# Permit 635 finished at 1660101686.3670368, after 1.594224214553833, 995.7719650268555 since the start of the code.
# Permit 636 finished at 1660101687.945934, after 1.578819751739502, 997.3508629798889 since the start of the code.
# Permit 637 finished at 1660101689.550194, after 1.6041877269744873, 998.9551219940186 since the start of the code.
# Permit 638 finished at 1660101691.12511, after 1.5748412609100342, 1000.5300378799438 since the start of the code.
# Permit 639 finished at 1660101692.6986802, after 1.5735011100769043, 1002.1036078929901 since the start of the code.
# Permit 640 finished at 1660101694.268127, after 1.5693762302398682, 1003.6730561256409 since the start of the code.
# Permit 641 finished at 1660101695.859759, after 1.5915577411651611, 1005.2646880149841 since the start of the code.
# Permit 642 finished at 1660101697.464946, after 1.605100154876709, 1006.8698749542236 since the start of the code.
# Permit 643 finished at 1660101699.032661, after 1.5676350593566895, 1008.4375891685486 since the start of the code.
# Permit 644 finished at 1660101700.6264162, after 1.5936710834503174, 1010.0313439369202 since the start of the code.
# Permit 645 finished at 1660101702.200202, after 1.5737190246582031, 1011.6051309108734 since the start of the code.
# Permit 646 finished at 1660101703.8013508, after 1.6010730266571045, 1013.2062790393829 since the start of the code.
# Permit 647 finished at 1660101705.373753, after 1.572328805923462, 1014.7786808013916 since the start of the code.
# Permit 648 finished at 1660101706.989547, after 1.6157219409942627, 1016.3944759368896 since the start of the code.
# Permit 649 finished at 1660101708.557125, after 1.5675098896026611, 1017.9620530605316 since the start of the code.
# Permit 650 finished at 1660101710.118402, after 1.5612058639526367, 1019.5233299732208 since the start of the code.
# Permit 651 finished at 1660101711.708757, after 1.590278148651123, 1021.1136839389801 since the start of the code.
# Permit 652 finished at 1660101713.281166, after 1.572335958480835, 1022.6860938072205 since the start of the code.
# Permit 653 finished at 1660101714.8469791, after 1.5657398700714111, 1024.2519059181213 since the start of the code.
# Permit 654 finished at 1660101716.420483, after 1.5734190940856934, 1025.8254108428955 since the start of the code.
# Permit 655 finished at 1660101717.98787, after 1.5673189163208008, 1027.39279794693 since the start of the code.
# Permit 656 finished at 1660101719.580153, after 1.5922048091888428, 1028.9850809574127 since the start of the code.
# Permit 657 finished at 1660101721.1517088, after 1.5714738368988037, 1030.556636095047 since the start of the code.
# Permit 658 finished at 1660101722.783562, after 1.6317880153656006, 1032.1884908676147 since the start of the code.
# Permit 659 finished at 1660101724.364734, after 1.5810749530792236, 1033.7696621418 since the start of the code.
# Permit 660 finished at 1660101725.969683, after 1.6048791408538818, 1035.3746120929718 since the start of the code.
# Permit 661 finished at 1660101727.5488331, after 1.579078197479248, 1036.9537618160248 since the start of the code.
# Permit 662 finished at 1660101729.1221309, after 1.5732178688049316, 1038.5270590782166 since the start of the code.
# Permit 663 finished at 1660101730.684554, after 1.5623500347137451, 1040.0894827842712 since the start of the code.
# Permit 664 finished at 1660101732.3004422, after 1.6158061027526855, 1041.7053709030151 since the start of the code.
# Permit 665 finished at 1660101733.897085, after 1.5965471267700195, 1043.3020129203796 since the start of the code.
# Permit 666 finished at 1660101735.472951, after 1.575791835784912, 1044.877879858017 since the start of the code.
# Permit 667 finished at 1660101737.066907, after 1.5938811302185059, 1046.471834897995 since the start of the code.
# Permit 668 finished at 1660101738.648306, after 1.581312894821167, 1048.0532341003418 since the start of the code.
# Permit 669 finished at 1660101740.217364, after 1.5689940452575684, 1049.6222920417786 since the start of the code.
# Permit 670 finished at 1660101741.812931, after 1.5954949855804443, 1051.2178587913513 since the start of the code.
# Permit 671 finished at 1660101743.400806, after 1.5878069400787354, 1052.8057339191437 since the start of the code.
# Permit 672 finished at 1660101744.983711, after 1.5828330516815186, 1054.388640165329 since the start of the code.
# Permit 673 finished at 1660101746.540666, after 1.556879997253418, 1055.9455938339233 since the start of the code.
# Permit 674 finished at 1660101748.102588, after 1.5618500709533691, 1057.5075170993805 since the start of the code.
# Permit 675 finished at 1660101749.667795, after 1.5651278495788574, 1059.0727229118347 since the start of the code.
# Permit 676 finished at 1660101751.238941, after 1.571073055267334, 1060.6438689231873 since the start of the code.
# Permit 677 finished at 1660101752.796938, after 1.5579273700714111, 1062.201866865158 since the start of the code.
# Permit 678 finished at 1660101754.363884, after 1.566878080368042, 1063.7688119411469 since the start of the code.
# Permit 679 finished at 1660101755.9354439, after 1.571485996246338, 1065.340371131897 since the start of the code.
# Permit 680 finished at 1660101757.526706, after 1.5911920070648193, 1066.9316351413727 since the start of the code.
# Permit 681 finished at 1660101759.11427, after 1.5874860286712646, 1068.5191979408264 since the start of the code.
# Permit 682 finished at 1660101760.686764, after 1.5724220275878906, 1070.0916919708252 since the start of the code.
# Permit 683 finished at 1660101762.2580612, after 1.5712220668792725, 1071.6629898548126 since the start of the code.
# Permit 684 finished at 1660101763.814312, after 1.5561871528625488, 1073.219241142273 since the start of the code.
# Permit 685 finished at 1660101765.409709, after 1.5953238010406494, 1074.8146369457245 since the start of the code.
# Permit 686 finished at 1660101767.008132, after 1.5983381271362305, 1076.4130599498749 since the start of the code.
# Permit 687 finished at 1660101768.581714, after 1.5734870433807373, 1077.986643075943 since the start of the code.
# Permit 688 finished at 1660101770.1346529, after 1.5528647899627686, 1079.5395810604095 since the start of the code.
# Permit 689 finished at 1660101771.714528, after 1.57981276512146, 1081.1194598674774 since the start of the code.
# Permit 690 finished at 1660101773.3139899, after 1.5992250442504883, 1082.7189180850983 since the start of the code.
# Permit 691 finished at 1660101774.872252, after 1.5580520629882812, 1084.2771799564362 since the start of the code.
# Permit 692 finished at 1660101776.445452, after 1.5731205940246582, 1085.8503799438477 since the start of the code.
# Permit 693 finished at 1660101778.057743, after 1.6122231483459473, 1087.462671995163 since the start of the code.
# Permit 694 finished at 1660101779.652585, after 1.5947461128234863, 1089.057512998581 since the start of the code.
# Permit 695 finished at 1660101781.26394, after 1.6112840175628662, 1090.6688690185547 since the start of the code.
# Permit 696 finished at 1660101782.8228512, after 1.5588390827178955, 1092.2277789115906 since the start of the code.
# Permit 697 finished at 1660101784.4043489, after 1.5814180374145508, 1093.8092770576477 since the start of the code.
# Permit 698 finished at 1660101785.963892, after 1.5594711303710938, 1095.368819952011 since the start of the code.
# Permit 699 finished at 1660101787.540401, after 1.5764422416687012, 1096.945328950882 since the start of the code.
# Permit 700 finished at 1660101789.117058, after 1.5765788555145264, 1098.5219857692719 since the start of the code.
# Permit 701 finished at 1660101790.693762, after 1.576620101928711, 1100.098688840866 since the start of the code.
# Permit 702 finished at 1660101792.2501, after 1.5562667846679688, 1101.6550290584564 since the start of the code.
# Permit 703 finished at 1660101793.867383, after 1.6172118186950684, 1103.2723109722137 since the start of the code.
# Permit 704 finished at 1660101795.46683, after 1.5993688106536865, 1104.8717579841614 since the start of the code.
# Permit 705 finished at 1660101797.029991, after 1.5630908012390137, 1106.4349200725555 since the start of the code.
# Permit 706 finished at 1660101798.633677, after 1.6035888195037842, 1108.0386049747467 since the start of the code.
# Permit 707 finished at 1660101800.211602, after 1.5778591632843018, 1109.6165299415588 since the start of the code.
# Permit 708 finished at 1660101801.806425, after 1.5947530269622803, 1111.2113540172577 since the start of the code.
# Permit 709 finished at 1660101803.366584, after 1.5600860118865967, 1112.7715117931366 since the start of the code.
# Permit 710 finished at 1660101804.966764, after 1.600111961364746, 1114.371691942215 since the start of the code.
# Permit 711 finished at 1660101806.536766, after 1.5699279308319092, 1115.941694021225 since the start of the code.
# Permit 712 finished at 1660101808.110999, after 1.574159860610962, 1117.5159277915955 since the start of the code.
# Permit 713 finished at 1660101809.699113, after 1.5880320072174072, 1119.1040410995483 since the start of the code.
# Permit 714 finished at 1660101811.274205, after 1.5750131607055664, 1120.679132938385 since the start of the code.
# Permit 715 finished at 1660101812.848164, after 1.5738708972930908, 1122.2530918121338 since the start of the code.
# Permit 716 finished at 1660101814.464694, after 1.6164562702178955, 1123.8696217536926 since the start of the code.
# Permit 717 finished at 1660101816.050447, after 1.5856831073760986, 1125.455374956131 since the start of the code.
# Permit 718 finished at 1660101817.664465, after 1.6139500141143799, 1127.0693929195404 since the start of the code.
# Permit 719 finished at 1660101819.2408462, after 1.5762898921966553, 1128.6457738876343 since the start of the code.
# Permit 720 finished at 1660101820.7969532, after 1.556030035018921, 1130.2018818855286 since the start of the code.
# Permit 721 finished at 1660101822.3584309, after 1.561406135559082, 1131.7633590698242 since the start of the code.
# Permit 722 finished at 1660101823.929399, after 1.5708978176116943, 1133.3343279361725 since the start of the code.
# Permit 723 finished at 1660101825.5039208, after 1.5744471549987793, 1134.908849954605 since the start of the code.
# Permit 724 finished at 1660101827.0973701, after 1.593376874923706, 1136.5022990703583 since the start of the code.
# Permit 725 finished at 1660101828.7133691, after 1.6159260272979736, 1138.1182980537415 since the start of the code.
# Permit 726 finished at 1660101830.338599, after 1.6251499652862549, 1139.743525981903 since the start of the code.
# Permit 727 finished at 1660101831.933376, after 1.5946972370147705, 1141.338304758072 since the start of the code.
# Permit 728 finished at 1660101833.522712, after 1.5892658233642578, 1142.9276399612427 since the start of the code.
# Permit 729 finished at 1660101835.0825589, after 1.559777021408081, 1144.4874880313873 since the start of the code.
# Permit 730 finished at 1660101836.649654, after 1.5670011043548584, 1146.0545818805695 since the start of the code.
#
# Time to run Brooklyn: 1146.0623879432678

# %% [markdown]
# # 2016

# %%
permits_man = pd.read_csv('../data_permits_by_boro/permits_man.csv')
permits_bx = pd.read_csv('../data_permits_by_boro/permits_bx.csv')
permits_si = pd.read_csv('../data_permits_by_boro/permits_si.csv')
permits_qn = pd.read_csv('../data_permits_by_boro/permits_qn.csv')
permits_bk = pd.read_csv('../data_permits_by_boro/permits_bk.csv')

nypd_man = pd.read_csv('../data_nypd_by_year/2016/nypd2016_man.csv') #CHANGE YEAR
nypd_bx = pd.read_csv('../data_nypd_by_year/2016/nypd2016_bx.csv') #CHANGE YEAR
nypd_si = pd.read_csv('../data_nypd_by_year/2016/nypd2016_si.csv') #CHANGE YEAR
nypd_qn = pd.read_csv('../data_nypd_by_year/2016/nypd2016_qn.csv') #CHANGE YEAR
nypd_bk = pd.read_csv('../data_nypd_by_year/2016/nypd2016_bk.csv') #CHANGE YEAR

# %%
nypd_man.head(1)
# Out:
#    cmplnt_num cmplnt_fr_dt law_cat_cd    boro_nm  addr_pct_cd  x_coord_cd  \
# 0   397756504   2017-03-01  VIOLATION  MANHATTAN         20.0    988203.0
#
#    y_coord_cd   latitude  longitude
# 0    219973.0  40.770459  -73.98573

# %%
nypd_bx.head(1)
# Out:
#    cmplnt_num cmplnt_fr_dt   law_cat_cd boro_nm  addr_pct_cd  x_coord_cd  \
# 0   278828672   2017-04-04  MISDEMEANOR   BRONX         48.0   1011779.0
#
#    y_coord_cd   latitude  longitude
# 0    246746.0  40.843901 -73.900505

# %%
nypd_si.head(1)
# Out:
#    cmplnt_num cmplnt_fr_dt law_cat_cd        boro_nm  addr_pct_cd  x_coord_cd  \
# 0   204718564   2016-08-11     FELONY  STATEN ISLAND        120.0    951949.0
#
#    y_coord_cd   latitude  longitude
# 0    171618.0  40.637678 -74.116385

# %%
nypd_qn.head(1)
# Out:
#    cmplnt_num cmplnt_fr_dt law_cat_cd boro_nm  addr_pct_cd  x_coord_cd  \
# 0   216044876   2017-01-01     FELONY  QUEENS        109.0   1032198.0
#
#    y_coord_cd   latitude  longitude
# 0    217060.0  40.762334 -73.826917

# %%
nypd_bk.head(1)
# Out:
#    cmplnt_num cmplnt_fr_dt law_cat_cd   boro_nm  addr_pct_cd  x_coord_cd  \
# 0   640732083   2017-07-13     FELONY  BROOKLYN         70.0    996544.0
#
#    y_coord_cd   latitude  longitude
# 0    165944.0  40.622154 -73.955715

# %%
# MANHATTAN (MAN)
t0 = time.time()
print('Processing Manhattan')
permits_man.loc[0, 'complaints2016_17'] = 0 #CHANGE YEAR
for i in permits_man.index:
    t1 = time.time()
    lat = permits_man.loc[i, 'latitude']
    long = permits_man.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_man.index:
        n_lat = nypd_man.loc[n, 'latitude']
        n_long = nypd_man.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_man.loc[i, 'complaints2016_17'] = complaint_count #CHANGE YEAR
    print(f"Manhattan permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Manhattan code.")

permits_man.to_csv('../data_permits_w_nypd/permits_complaints2016_man.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Manhattan:", time.time()-t0) #


# THE BRONX (BX)
t0 = time.time()
print('Processing the Bronx')
permits_bx.loc[0, 'complaints2016_17'] = 0 #CHANGE YEAR
for i in permits_bx.index:
    t1 = time.time()
    lat = permits_bx.loc[i, 'latitude']
    long = permits_bx.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_bx.index:
        n_lat = nypd_bx.loc[n, 'latitude']
        n_long = nypd_bx.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_bx.loc[i, 'complaints2016_17'] = complaint_count #CHANGE YEAR
    print(f"Bronx permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Bronx code.")

permits_bx.to_csv('../data_permits_w_nypd/permits_complaints2016_bx.csv', index = False) #CHANGE YEAR

print('')
print("Time to run the Bronx:", time.time()-t0) #CHANGE BOROUGH


# STATEN ISLAND (SI)
t0 = time.time()
print('Processing Staten Island')
permits_si.loc[0, 'complaints2016_17'] = 0 #CHANGE YEAR
for i in permits_si.index:
    t1 = time.time()
    lat = permits_si.loc[i, 'latitude']
    long = permits_si.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_si.index:
        n_lat = nypd_si.loc[n, 'latitude']
        n_long = nypd_si.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_si.loc[i, 'complaints2016_17'] = complaint_count #CHANGE YEAR
    print(f"Staten Island permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Staten Island code.")

permits_si.to_csv('../data_permits_w_nypd/permits_complaints2016_si.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Staten Island:", time.time()-t0)


# QUEENS (QN)
t0 = time.time()
print('Processing Queens')
permits_qn.loc[0, 'complaints2016_17'] = 0 #CHANGE YEAR
for i in permits_qn.index:
    t1 = time.time()
    lat = permits_qn.loc[i, 'latitude']
    long = permits_qn.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_qn.index:
        n_lat = nypd_qn.loc[n, 'latitude']
        n_long = nypd_qn.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_qn.loc[i, 'complaints2016_17'] = complaint_count #CHANGE YEAR
    print(f"Queens permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Queens code.")

permits_qn.to_csv('../data_permits_w_nypd/permits_complaints2016_qn.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Queens:", time.time()-t0)


# BROOKLYN (BK)
t0 = time.time()
print('Processing Brooklyn')
permits_bk.loc[0, 'complaints2016_17'] = 0 #CHANGE YEAR
for i in permits_bk.index:
    t1 = time.time()
    lat = permits_bk.loc[i, 'latitude']
    long = permits_bk.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_bk.index:
        n_lat = nypd_bk.loc[n, 'latitude']
        n_long = nypd_bk.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_bk.loc[i, 'complaints2016_17'] = complaint_count #CHANGE YEAR
    print(f"Brooklyn permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Brooklyn code.")


permits_bk.to_csv('../data_permits_w_nypd/permits_complaints2016_bk.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Brooklyn:", time.time()-t0)
# Out:
# Processing Manhattan
# Manhattan permit 0 finished at 1660132180.196368, after 1.2391438484191895, 1.244316816329956 since the start of the Manhattan code.
# Manhattan permit 1 finished at 1660132181.3948958, after 1.1984508037567139, 2.4428369998931885 since the start of the Manhattan code.
# Manhattan permit 2 finished at 1660132182.618769, after 1.2238249778747559, 3.6667098999023438 since the start of the Manhattan code.
# Manhattan permit 3 finished at 1660132183.838335, after 1.2194819450378418, 4.886277198791504 since the start of the Manhattan code.
# Manhattan permit 4 finished at 1660132185.0574841, after 1.2190790176391602, 6.105424880981445 since the start of the Manhattan code.
# Manhattan permit 5 finished at 1660132186.274415, after 1.2168588638305664, 7.322356939315796 since the start of the Manhattan code.
# Manhattan permit 6 finished at 1660132187.499903, after 1.2254021167755127, 8.547844171524048 since the start of the Manhattan code.
# Manhattan permit 7 finished at 1660132188.713968, after 1.2139949798583984, 9.761909008026123 since the start of the Manhattan code.
# Manhattan permit 8 finished at 1660132189.929929, after 1.215893030166626, 10.977871179580688 since the start of the Manhattan code.
# Manhattan permit 9 finished at 1660132191.130878, after 1.2008659839630127, 12.178820133209229 since the start of the Manhattan code.
# Manhattan permit 10 finished at 1660132192.351061, after 1.2199912071228027, 13.399002075195312 since the start of the Manhattan code.
# Manhattan permit 11 finished at 1660132193.577236, after 1.2260961532592773, 14.625178098678589 since the start of the Manhattan code.
# Manhattan permit 12 finished at 1660132194.794445, after 1.2171378135681152, 15.84238576889038 since the start of the Manhattan code.
# Manhattan permit 13 finished at 1660132196.0048242, after 1.2103140354156494, 17.05276584625244 since the start of the Manhattan code.
# Manhattan permit 14 finished at 1660132197.2321029, after 1.227212905883789, 18.280044078826904 since the start of the Manhattan code.
# Manhattan permit 15 finished at 1660132198.4416919, after 1.20951509475708, 19.489633083343506 since the start of the Manhattan code.
# Manhattan permit 16 finished at 1660132199.667362, after 1.2256057262420654, 20.71530294418335 since the start of the Manhattan code.
# Manhattan permit 17 finished at 1660132200.883423, after 1.2159979343414307, 21.931364059448242 since the start of the Manhattan code.
# Manhattan permit 18 finished at 1660132202.135529, after 1.2520391941070557, 23.183470010757446 since the start of the Manhattan code.
# Manhattan permit 19 finished at 1660132203.3653078, after 1.2296881675720215, 24.413249015808105 since the start of the Manhattan code.
# Manhattan permit 20 finished at 1660132204.583445, after 1.2180471420288086, 25.631386041641235 since the start of the Manhattan code.
# Manhattan permit 21 finished at 1660132205.822627, after 1.2391140460968018, 26.870567798614502 since the start of the Manhattan code.
# Manhattan permit 22 finished at 1660132207.051019, after 1.2283120155334473, 28.098960876464844 since the start of the Manhattan code.
# Manhattan permit 23 finished at 1660132208.28103, after 1.2299211025238037, 29.328970909118652 since the start of the Manhattan code.
# Manhattan permit 24 finished at 1660132209.505688, after 1.2245938777923584, 30.553629875183105 since the start of the Manhattan code.
# Manhattan permit 25 finished at 1660132210.733581, after 1.2278227806091309, 31.78152298927307 since the start of the Manhattan code.
# Manhattan permit 26 finished at 1660132211.9763489, after 1.2427020072937012, 33.0242919921875 since the start of the Manhattan code.
# Manhattan permit 27 finished at 1660132213.202741, after 1.2263233661651611, 34.25068211555481 since the start of the Manhattan code.
# Manhattan permit 28 finished at 1660132214.434262, after 1.2314260005950928, 35.4822039604187 since the start of the Manhattan code.
# Manhattan permit 29 finished at 1660132215.676933, after 1.2426066398620605, 36.72487497329712 since the start of the Manhattan code.
# Manhattan permit 30 finished at 1660132216.904445, after 1.2274370193481445, 37.952385902404785 since the start of the Manhattan code.
# Manhattan permit 31 finished at 1660132218.142142, after 1.2376251220703125, 39.190083026885986 since the start of the Manhattan code.
# Manhattan permit 32 finished at 1660132219.3840818, after 1.241868019104004, 40.43202304840088 since the start of the Manhattan code.
# Manhattan permit 33 finished at 1660132220.6325681, after 1.248410940170288, 41.680508852005005 since the start of the Manhattan code.
# Manhattan permit 34 finished at 1660132221.8757088, after 1.2430732250213623, 42.92365002632141 since the start of the Manhattan code.
# Manhattan permit 35 finished at 1660132223.1028, after 1.2270078659057617, 44.1507408618927 since the start of the Manhattan code.
# Manhattan permit 36 finished at 1660132224.337475, after 1.234609842300415, 45.385416984558105 since the start of the Manhattan code.
# Manhattan permit 37 finished at 1660132225.566626, after 1.2290818691253662, 46.61456799507141 since the start of the Manhattan code.
# Manhattan permit 38 finished at 1660132226.809739, after 1.2430531978607178, 47.857680797576904 since the start of the Manhattan code.
# Manhattan permit 39 finished at 1660132228.040158, after 1.2303471565246582, 49.088099002838135 since the start of the Manhattan code.
# Manhattan permit 40 finished at 1660132229.285258, after 1.2450270652770996, 50.33319902420044 since the start of the Manhattan code.
# Manhattan permit 41 finished at 1660132230.519084, after 1.233748197555542, 51.56702494621277 since the start of the Manhattan code.
# Manhattan permit 42 finished at 1660132231.751623, after 1.2324631214141846, 52.79956388473511 since the start of the Manhattan code.
# Manhattan permit 43 finished at 1660132232.993857, after 1.2421653270721436, 54.04179883003235 since the start of the Manhattan code.
# Manhattan permit 44 finished at 1660132234.2385862, after 1.2446610927581787, 55.286526918411255 since the start of the Manhattan code.
# Manhattan permit 45 finished at 1660132235.473418, after 1.2347679138183594, 56.52135992050171 since the start of the Manhattan code.
# Manhattan permit 46 finished at 1660132236.7040331, after 1.230536937713623, 57.7519748210907 since the start of the Manhattan code.
# Manhattan permit 47 finished at 1660132237.940253, after 1.2361421585083008, 58.98819398880005 since the start of the Manhattan code.
# Manhattan permit 48 finished at 1660132239.178334, after 1.237987995147705, 60.2262761592865 since the start of the Manhattan code.
# Manhattan permit 49 finished at 1660132240.413378, after 1.2349698543548584, 61.46131992340088 since the start of the Manhattan code.
# Manhattan permit 50 finished at 1660132241.65387, after 1.2404239177703857, 62.70181202888489 since the start of the Manhattan code.
# Manhattan permit 51 finished at 1660132242.883306, after 1.2293641567230225, 63.9312469959259 since the start of the Manhattan code.
# Manhattan permit 52 finished at 1660132244.117533, after 1.234147071838379, 65.16547393798828 since the start of the Manhattan code.
# Manhattan permit 53 finished at 1660132245.358699, after 1.2410972118377686, 66.40664005279541 since the start of the Manhattan code.
# Manhattan permit 54 finished at 1660132246.584876, after 1.226119041442871, 67.63281679153442 since the start of the Manhattan code.
# Manhattan permit 55 finished at 1660132247.824061, after 1.239119052886963, 68.87200689315796 since the start of the Manhattan code.
# Manhattan permit 56 finished at 1660132249.0535948, after 1.2293486595153809, 70.10153603553772 since the start of the Manhattan code.
# Manhattan permit 57 finished at 1660132250.280638, after 1.2269728183746338, 71.3285801410675 since the start of the Manhattan code.
# Manhattan permit 58 finished at 1660132251.51139, after 1.2306859493255615, 72.55933094024658 since the start of the Manhattan code.
# Manhattan permit 59 finished at 1660132252.7528179, after 1.2413649559020996, 73.80075788497925 since the start of the Manhattan code.
# Manhattan permit 60 finished at 1660132253.9794612, after 1.2265748977661133, 75.0274019241333 since the start of the Manhattan code.
# Manhattan permit 61 finished at 1660132255.213025, after 1.2335011959075928, 76.2609658241272 since the start of the Manhattan code.
# Manhattan permit 62 finished at 1660132256.436755, after 1.2236549854278564, 77.48469591140747 since the start of the Manhattan code.
# Manhattan permit 63 finished at 1660132257.666005, after 1.2291693687438965, 78.71394610404968 since the start of the Manhattan code.
# Manhattan permit 64 finished at 1660132258.907871, after 1.241774082183838, 79.95581197738647 since the start of the Manhattan code.
# Manhattan permit 65 finished at 1660132260.136084, after 1.2281451225280762, 81.18402600288391 since the start of the Manhattan code.
# Manhattan permit 66 finished at 1660132261.3767302, after 1.2405681610107422, 82.42467093467712 since the start of the Manhattan code.
# Manhattan permit 67 finished at 1660132262.60939, after 1.2324600219726562, 83.65733098983765 since the start of the Manhattan code.
# Manhattan permit 68 finished at 1660132263.8494048, after 1.2399420738220215, 84.89734697341919 since the start of the Manhattan code.
# Manhattan permit 69 finished at 1660132265.081047, after 1.2315680980682373, 86.12898683547974 since the start of the Manhattan code.
# Manhattan permit 70 finished at 1660132266.310035, after 1.2289221286773682, 87.35797715187073 since the start of the Manhattan code.
# Manhattan permit 71 finished at 1660132267.5459259, after 1.235818862915039, 88.59386801719666 since the start of the Manhattan code.
# Manhattan permit 72 finished at 1660132268.778176, after 1.2321720123291016, 89.8261170387268 since the start of the Manhattan code.
# Manhattan permit 73 finished at 1660132270.007145, after 1.2289049625396729, 91.05508613586426 since the start of the Manhattan code.
# Manhattan permit 74 finished at 1660132271.236817, after 1.2296090126037598, 92.28475904464722 since the start of the Manhattan code.
# Manhattan permit 75 finished at 1660132272.5568588, after 1.3199760913848877, 93.60479998588562 since the start of the Manhattan code.
# Manhattan permit 76 finished at 1660132273.782558, after 1.2256181240081787, 94.83050012588501 since the start of the Manhattan code.
# Manhattan permit 77 finished at 1660132275.0098119, after 1.2271759510040283, 96.05775308609009 since the start of the Manhattan code.
# Manhattan permit 78 finished at 1660132276.234398, after 1.2245218753814697, 97.28233909606934 since the start of the Manhattan code.
# Manhattan permit 79 finished at 1660132277.465655, after 1.231187343597412, 98.51359486579895 since the start of the Manhattan code.
# Manhattan permit 80 finished at 1660132278.6933708, after 1.2276489734649658, 99.74131202697754 since the start of the Manhattan code.
# Manhattan permit 81 finished at 1660132279.915572, after 1.222121000289917, 100.96351313591003 since the start of the Manhattan code.
# Manhattan permit 82 finished at 1660132281.1643178, after 1.2486801147460938, 102.21225905418396 since the start of the Manhattan code.
# Manhattan permit 83 finished at 1660132282.4430442, after 1.2786588668823242, 103.49098801612854 since the start of the Manhattan code.
# Manhattan permit 84 finished at 1660132283.675183, after 1.2320258617401123, 104.72312498092651 since the start of the Manhattan code.
# Manhattan permit 85 finished at 1660132284.904686, after 1.229429006576538, 105.95262789726257 since the start of the Manhattan code.
# Manhattan permit 86 finished at 1660132286.1303198, after 1.2255589962005615, 107.17826199531555 since the start of the Manhattan code.
# Manhattan permit 87 finished at 1660132287.3649678, after 1.2345662117004395, 108.4129090309143 since the start of the Manhattan code.
# Manhattan permit 88 finished at 1660132288.596771, after 1.2317187786102295, 109.64471197128296 since the start of the Manhattan code.
# Manhattan permit 89 finished at 1660132289.826999, after 1.2301537990570068, 110.87493991851807 since the start of the Manhattan code.
# Manhattan permit 90 finished at 1660132291.0563278, after 1.229264259338379, 112.10426998138428 since the start of the Manhattan code.
# Manhattan permit 91 finished at 1660132292.2838159, after 1.2274169921875, 113.33175706863403 since the start of the Manhattan code.
# Manhattan permit 92 finished at 1660132293.509444, after 1.2255628108978271, 114.55738592147827 since the start of the Manhattan code.
# Manhattan permit 93 finished at 1660132294.741956, after 1.2324180603027344, 115.78989791870117 since the start of the Manhattan code.
# Manhattan permit 94 finished at 1660132295.980726, after 1.2386999130249023, 117.02866792678833 since the start of the Manhattan code.
# Manhattan permit 95 finished at 1660132297.2126641, after 1.2318699359893799, 118.26060485839844 since the start of the Manhattan code.
# Manhattan permit 96 finished at 1660132298.455847, after 1.2431118488311768, 119.50378894805908 since the start of the Manhattan code.
# Manhattan permit 97 finished at 1660132299.69233, after 1.2364060878753662, 120.7402720451355 since the start of the Manhattan code.
# Manhattan permit 98 finished at 1660132300.9296691, after 1.237246036529541, 121.977609872818 since the start of the Manhattan code.
# Manhattan permit 99 finished at 1660132302.165458, after 1.2357220649719238, 123.21340012550354 since the start of the Manhattan code.
# Manhattan permit 100 finished at 1660132303.394722, after 1.2291719913482666, 124.44266390800476 since the start of the Manhattan code.
# Manhattan permit 101 finished at 1660132304.6186152, after 1.2238271236419678, 125.66655492782593 since the start of the Manhattan code.
# Manhattan permit 102 finished at 1660132305.842589, after 1.2239117622375488, 126.89053010940552 since the start of the Manhattan code.
# Manhattan permit 103 finished at 1660132307.114233, after 1.2715799808502197, 128.16217589378357 since the start of the Manhattan code.
# Manhattan permit 104 finished at 1660132308.359819, after 1.2454969882965088, 129.40775990486145 since the start of the Manhattan code.
# Manhattan permit 105 finished at 1660132309.598181, after 1.2382900714874268, 130.64612293243408 since the start of the Manhattan code.
# Manhattan permit 106 finished at 1660132310.835872, after 1.2376182079315186, 131.88381385803223 since the start of the Manhattan code.
# Manhattan permit 107 finished at 1660132312.065773, after 1.229825735092163, 133.11371397972107 since the start of the Manhattan code.
# Manhattan permit 108 finished at 1660132313.463317, after 1.397465705871582, 134.5112669467926 since the start of the Manhattan code.
# Manhattan permit 109 finished at 1660132314.95, after 1.4862451553344727, 135.9979429244995 since the start of the Manhattan code.
# Manhattan permit 110 finished at 1660132316.2659578, after 1.3158469200134277, 137.31389904022217 since the start of the Manhattan code.
# Manhattan permit 111 finished at 1660132317.515677, after 1.2496459484100342, 138.56362295150757 since the start of the Manhattan code.
# Manhattan permit 112 finished at 1660132318.77187, after 1.256005048751831, 139.81981492042542 since the start of the Manhattan code.
# Manhattan permit 113 finished at 1660132320.0182579, after 1.2463059425354004, 141.06620001792908 since the start of the Manhattan code.
# Manhattan permit 114 finished at 1660132321.2611809, after 1.2428390979766846, 142.3091230392456 since the start of the Manhattan code.
# Manhattan permit 115 finished at 1660132322.4972749, after 1.236020803451538, 143.54521703720093 since the start of the Manhattan code.
# Manhattan permit 116 finished at 1660132323.739402, after 1.2420501708984375, 144.78734374046326 since the start of the Manhattan code.
# Manhattan permit 117 finished at 1660132324.981424, after 1.2419419288635254, 146.02936506271362 since the start of the Manhattan code.
# Manhattan permit 118 finished at 1660132326.216152, after 1.2346570491790771, 147.264093875885 since the start of the Manhattan code.
# Manhattan permit 119 finished at 1660132327.459311, after 1.243082046508789, 148.50725197792053 since the start of the Manhattan code.
# Manhattan permit 120 finished at 1660132328.692957, after 1.233553171157837, 149.74089908599854 since the start of the Manhattan code.
# Manhattan permit 121 finished at 1660132329.926356, after 1.2333228588104248, 150.97429609298706 since the start of the Manhattan code.
# Manhattan permit 122 finished at 1660132331.165654, after 1.239231824874878, 152.21359491348267 since the start of the Manhattan code.
# Manhattan permit 123 finished at 1660132332.403831, after 1.2381069660186768, 153.45177292823792 since the start of the Manhattan code.
# Manhattan permit 124 finished at 1660132333.6317282, after 1.2278110980987549, 154.67967009544373 since the start of the Manhattan code.
# Manhattan permit 125 finished at 1660132334.855107, after 1.2233028411865234, 155.9030478000641 since the start of the Manhattan code.
# Manhattan permit 126 finished at 1660132336.118548, after 1.2633790969848633, 157.16649389266968 since the start of the Manhattan code.
# Manhattan permit 127 finished at 1660132337.359798, after 1.241163969039917, 158.4077389240265 since the start of the Manhattan code.
# Manhattan permit 128 finished at 1660132338.5906072, after 1.2307419776916504, 159.63854789733887 since the start of the Manhattan code.
# Manhattan permit 129 finished at 1660132339.822764, after 1.2320892810821533, 160.87070488929749 since the start of the Manhattan code.
# Manhattan permit 130 finished at 1660132341.052783, after 1.2299308776855469, 162.10072493553162 since the start of the Manhattan code.
# Manhattan permit 131 finished at 1660132342.295836, after 1.2429828643798828, 163.34377694129944 since the start of the Manhattan code.
# Manhattan permit 132 finished at 1660132343.521624, after 1.2257118225097656, 164.56956601142883 since the start of the Manhattan code.
# Manhattan permit 133 finished at 1660132344.7461948, after 1.2244911193847656, 165.79413604736328 since the start of the Manhattan code.
# Manhattan permit 134 finished at 1660132345.984174, after 1.2379138469696045, 167.0321159362793 since the start of the Manhattan code.
# Manhattan permit 135 finished at 1660132347.218133, after 1.2338781356811523, 168.26607489585876 since the start of the Manhattan code.
# Manhattan permit 136 finished at 1660132348.446843, after 1.228632926940918, 169.4947850704193 since the start of the Manhattan code.
# Manhattan permit 137 finished at 1660132349.6765492, after 1.2296421527862549, 170.72449398040771 since the start of the Manhattan code.
# Manhattan permit 138 finished at 1660132350.9026291, after 1.225942850112915, 171.95057106018066 since the start of the Manhattan code.
# Manhattan permit 139 finished at 1660132352.1427782, after 1.2400808334350586, 173.19072008132935 since the start of the Manhattan code.
# Manhattan permit 140 finished at 1660132353.380747, after 1.237894058227539, 174.42868781089783 since the start of the Manhattan code.
# Manhattan permit 141 finished at 1660132354.623698, after 1.2428789138793945, 175.671639919281 since the start of the Manhattan code.
# Manhattan permit 142 finished at 1660132355.8943439, after 1.270552158355713, 176.94228601455688 since the start of the Manhattan code.
# Manhattan permit 143 finished at 1660132357.13055, after 1.2361111640930176, 178.1784918308258 since the start of the Manhattan code.
# Manhattan permit 144 finished at 1660132358.3563452, after 1.2257139682769775, 179.40428590774536 since the start of the Manhattan code.
# Manhattan permit 145 finished at 1660132359.5819259, after 1.2255151271820068, 180.6298689842224 since the start of the Manhattan code.
# Manhattan permit 146 finished at 1660132360.8230028, after 1.2409069538116455, 181.87094402313232 since the start of the Manhattan code.
# Manhattan permit 147 finished at 1660132362.060829, after 1.2376251220703125, 183.10876989364624 since the start of the Manhattan code.
# Manhattan permit 148 finished at 1660132363.2868211, after 1.225912094116211, 184.33476185798645 since the start of the Manhattan code.
# Manhattan permit 149 finished at 1660132364.514287, after 1.2274010181427002, 185.56222891807556 since the start of the Manhattan code.
# Manhattan permit 150 finished at 1660132365.749845, after 1.2354869842529297, 186.79778599739075 since the start of the Manhattan code.
# Manhattan permit 151 finished at 1660132366.978701, after 1.2287828922271729, 188.02664279937744 since the start of the Manhattan code.
# Manhattan permit 152 finished at 1660132368.208703, after 1.2299299240112305, 189.25664401054382 since the start of the Manhattan code.
# Manhattan permit 153 finished at 1660132369.533063, after 1.3242878913879395, 190.58100390434265 since the start of the Manhattan code.
# Manhattan permit 154 finished at 1660132370.767807, after 1.2346632480621338, 191.8157479763031 since the start of the Manhattan code.
# Manhattan permit 155 finished at 1660132372.00427, after 1.2363760471343994, 193.0522119998932 since the start of the Manhattan code.
# Manhattan permit 156 finished at 1660132373.2387998, after 1.2344560623168945, 194.2867410182953 since the start of the Manhattan code.
# Manhattan permit 157 finished at 1660132374.47283, after 1.2339599132537842, 195.52077102661133 since the start of the Manhattan code.
# Manhattan permit 158 finished at 1660132375.706895, after 1.2339940071105957, 196.75483584403992 since the start of the Manhattan code.
# Manhattan permit 159 finished at 1660132376.929564, after 1.22259521484375, 197.9775049686432 since the start of the Manhattan code.
# Manhattan permit 160 finished at 1660132378.166775, after 1.2371437549591064, 199.2147159576416 since the start of the Manhattan code.
# Manhattan permit 161 finished at 1660132379.39046, after 1.2235908508300781, 200.4384000301361 since the start of the Manhattan code.
# Manhattan permit 162 finished at 1660132380.622711, after 1.232192039489746, 201.6706509590149 since the start of the Manhattan code.
# Manhattan permit 163 finished at 1660132381.858735, after 1.235961675643921, 202.90667700767517 since the start of the Manhattan code.
# Manhattan permit 164 finished at 1660132383.094945, after 1.2361350059509277, 204.14288592338562 since the start of the Manhattan code.
# Manhattan permit 165 finished at 1660132384.330653, after 1.2356359958648682, 205.37859392166138 since the start of the Manhattan code.
# Manhattan permit 166 finished at 1660132385.559368, after 1.2286410331726074, 206.60730910301208 since the start of the Manhattan code.
# Manhattan permit 167 finished at 1660132386.7868621, after 1.2274279594421387, 207.83480381965637 since the start of the Manhattan code.
# Manhattan permit 168 finished at 1660132388.057101, after 1.2701740264892578, 209.10504484176636 since the start of the Manhattan code.
# Manhattan permit 169 finished at 1660132389.285517, after 1.228226900100708, 210.33345890045166 since the start of the Manhattan code.
# Manhattan permit 170 finished at 1660132390.528178, after 1.2425870895385742, 211.57612013816833 since the start of the Manhattan code.
# Manhattan permit 171 finished at 1660132391.761445, after 1.2331898212432861, 212.80938601493835 since the start of the Manhattan code.
# Manhattan permit 172 finished at 1660132392.988445, after 1.2269282341003418, 214.036386013031 since the start of the Manhattan code.
# Manhattan permit 173 finished at 1660132394.2156959, after 1.227180004119873, 215.26363801956177 since the start of the Manhattan code.
# Manhattan permit 174 finished at 1660132395.45325, after 1.2374749183654785, 216.50119185447693 since the start of the Manhattan code.
# Manhattan permit 175 finished at 1660132396.683912, after 1.2305819988250732, 217.73185300827026 since the start of the Manhattan code.
# Manhattan permit 176 finished at 1660132397.919381, after 1.2353851795196533, 218.9673228263855 since the start of the Manhattan code.
# Manhattan permit 177 finished at 1660132399.1633222, after 1.2438509464263916, 220.21126508712769 since the start of the Manhattan code.
# Manhattan permit 178 finished at 1660132400.398432, after 1.2350189685821533, 221.44637298583984 since the start of the Manhattan code.
# Manhattan permit 179 finished at 1660132401.626206, after 1.2277109622955322, 222.67414712905884 since the start of the Manhattan code.
# Manhattan permit 180 finished at 1660132402.86338, after 1.2369740009307861, 223.9113199710846 since the start of the Manhattan code.
# Manhattan permit 181 finished at 1660132404.094187, after 1.2307219505310059, 225.14212894439697 since the start of the Manhattan code.
# Manhattan permit 182 finished at 1660132405.340831, after 1.2465579509735107, 226.38877201080322 since the start of the Manhattan code.
# Manhattan permit 183 finished at 1660132406.581901, after 1.2409768104553223, 227.6298418045044 since the start of the Manhattan code.
# Manhattan permit 184 finished at 1660132407.813293, after 1.2313268184661865, 228.86123394966125 since the start of the Manhattan code.
# Manhattan permit 185 finished at 1660132409.0424168, after 1.2290520668029785, 230.09035897254944 since the start of the Manhattan code.
# Manhattan permit 186 finished at 1660132410.278508, after 1.2360117435455322, 231.32644987106323 since the start of the Manhattan code.
# Manhattan permit 187 finished at 1660132411.5084789, after 1.2298991680145264, 232.55642008781433 since the start of the Manhattan code.
# Manhattan permit 188 finished at 1660132412.7417789, after 1.2332191467285156, 233.78972005844116 since the start of the Manhattan code.
# Manhattan permit 189 finished at 1660132413.9752681, after 1.2334201335906982, 235.02321004867554 since the start of the Manhattan code.
# Manhattan permit 190 finished at 1660132415.2175202, after 1.2421629428863525, 236.26546096801758 since the start of the Manhattan code.
# Manhattan permit 191 finished at 1660132416.4435809, after 1.2259860038757324, 237.49152302742004 since the start of the Manhattan code.
# Manhattan permit 192 finished at 1660132417.676074, after 1.2324230670928955, 238.7240149974823 since the start of the Manhattan code.
# Manhattan permit 193 finished at 1660132418.894117, after 1.2179679870605469, 239.94205784797668 since the start of the Manhattan code.
# Manhattan permit 194 finished at 1660132420.1209311, after 1.2267470359802246, 241.16887187957764 since the start of the Manhattan code.
# Manhattan permit 195 finished at 1660132421.3546538, after 1.2336609363555908, 242.40259504318237 since the start of the Manhattan code.
# Manhattan permit 196 finished at 1660132422.5826418, after 1.2279107570648193, 243.63058304786682 since the start of the Manhattan code.
# Manhattan permit 197 finished at 1660132423.807231, after 1.2245209217071533, 244.8551721572876 since the start of the Manhattan code.
# Manhattan permit 198 finished at 1660132425.027724, after 1.220426082611084, 246.07566475868225 since the start of the Manhattan code.
# Manhattan permit 199 finished at 1660132426.26257, after 1.2347831726074219, 247.31051206588745 since the start of the Manhattan code.
# Manhattan permit 200 finished at 1660132427.490808, after 1.2281568050384521, 248.53874897956848 since the start of the Manhattan code.
# Manhattan permit 201 finished at 1660132428.720203, after 1.229316234588623, 249.76814484596252 since the start of the Manhattan code.
# Manhattan permit 202 finished at 1660132429.957809, after 1.2375280857086182, 251.0057508945465 since the start of the Manhattan code.
# Manhattan permit 203 finished at 1660132431.187587, after 1.2295806407928467, 252.23552799224854 since the start of the Manhattan code.
# Manhattan permit 204 finished at 1660132432.420033, after 1.2323780059814453, 253.46797394752502 since the start of the Manhattan code.
# Manhattan permit 205 finished at 1660132433.6558552, after 1.2357487678527832, 254.70379495620728 since the start of the Manhattan code.
# Manhattan permit 206 finished at 1660132434.8974211, after 1.2414710521697998, 255.94536185264587 since the start of the Manhattan code.
# Manhattan permit 207 finished at 1660132436.128008, after 1.230525255203247, 257.175950050354 since the start of the Manhattan code.
# Manhattan permit 208 finished at 1660132437.377957, after 1.2498779296875, 258.4258990287781 since the start of the Manhattan code.
# Manhattan permit 209 finished at 1660132438.610635, after 1.2326030731201172, 259.65857577323914 since the start of the Manhattan code.
# Manhattan permit 210 finished at 1660132439.833581, after 1.2228748798370361, 260.88152289390564 since the start of the Manhattan code.
# Manhattan permit 211 finished at 1660132441.072122, after 1.2384698390960693, 262.12006402015686 since the start of the Manhattan code.
# Manhattan permit 212 finished at 1660132442.3131258, after 1.2409226894378662, 263.3610670566559 since the start of the Manhattan code.
# Manhattan permit 213 finished at 1660132443.5528698, after 1.2396748065948486, 264.600811958313 since the start of the Manhattan code.
# Manhattan permit 214 finished at 1660132444.788169, after 1.2352209091186523, 265.8361089229584 since the start of the Manhattan code.
# Manhattan permit 215 finished at 1660132446.01747, after 1.2292389869689941, 267.06541204452515 since the start of the Manhattan code.
# Manhattan permit 216 finished at 1660132447.242729, after 1.2251811027526855, 268.2906711101532 since the start of the Manhattan code.
# Manhattan permit 217 finished at 1660132448.4839401, after 1.2411398887634277, 269.5318820476532 since the start of the Manhattan code.
# Manhattan permit 218 finished at 1660132449.724612, after 1.2405998706817627, 270.77255296707153 since the start of the Manhattan code.
# Manhattan permit 219 finished at 1660132450.9567401, after 1.2320499420166016, 272.0046808719635 since the start of the Manhattan code.
# Manhattan permit 220 finished at 1660132452.191596, after 1.2347869873046875, 273.23953676223755 since the start of the Manhattan code.
# Manhattan permit 221 finished at 1660132453.4335701, after 1.241891860961914, 274.48151087760925 since the start of the Manhattan code.
# Manhattan permit 222 finished at 1660132454.667168, after 1.2335262298583984, 275.7151098251343 since the start of the Manhattan code.
# Manhattan permit 223 finished at 1660132455.8957639, after 1.2285282611846924, 276.9437050819397 since the start of the Manhattan code.
# Manhattan permit 224 finished at 1660132457.1195562, after 1.223710060119629, 278.16749691963196 since the start of the Manhattan code.
# Manhattan permit 225 finished at 1660132458.4302201, after 1.3105838298797607, 279.4781630039215 since the start of the Manhattan code.
# Manhattan permit 226 finished at 1660132459.654824, after 1.224412202835083, 280.7027659416199 since the start of the Manhattan code.
# Manhattan permit 227 finished at 1660132460.919613, after 1.2647202014923096, 281.96755504608154 since the start of the Manhattan code.
# Manhattan permit 228 finished at 1660132462.150544, after 1.230832815170288, 283.1984860897064 since the start of the Manhattan code.
# Manhattan permit 229 finished at 1660132463.387784, after 1.2371540069580078, 284.4357249736786 since the start of the Manhattan code.
# Manhattan permit 230 finished at 1660132464.655691, after 1.2678401470184326, 285.70363187789917 since the start of the Manhattan code.
# Manhattan permit 231 finished at 1660132465.882163, after 1.22639799118042, 286.930104970932 since the start of the Manhattan code.
# Manhattan permit 232 finished at 1660132467.120337, after 1.2380990982055664, 288.1682779788971 since the start of the Manhattan code.
# Manhattan permit 233 finished at 1660132468.359627, after 1.239077091217041, 289.4075689315796 since the start of the Manhattan code.
# Manhattan permit 234 finished at 1660132469.601908, after 1.2422080039978027, 290.6498501300812 since the start of the Manhattan code.
# Manhattan permit 235 finished at 1660132470.84439, after 1.242415189743042, 291.8923308849335 since the start of the Manhattan code.
# Manhattan permit 236 finished at 1660132472.0705879, after 1.2261319160461426, 293.1185290813446 since the start of the Manhattan code.
# Manhattan permit 237 finished at 1660132473.303215, after 1.2325382232666016, 294.35115909576416 since the start of the Manhattan code.
# Manhattan permit 238 finished at 1660132474.52263, after 1.2193431854248047, 295.57057189941406 since the start of the Manhattan code.
# Manhattan permit 239 finished at 1660132475.748547, after 1.2258448600769043, 296.79648780822754 since the start of the Manhattan code.
# Manhattan permit 240 finished at 1660132476.978851, after 1.2302148342132568, 298.0267930030823 since the start of the Manhattan code.
# Manhattan permit 241 finished at 1660132478.2095082, after 1.2305867671966553, 299.2574498653412 since the start of the Manhattan code.
# Manhattan permit 242 finished at 1660132479.4317272, after 1.2221360206604004, 300.4796688556671 since the start of the Manhattan code.
# Manhattan permit 243 finished at 1660132480.6630661, after 1.2312688827514648, 301.7110068798065 since the start of the Manhattan code.
# Manhattan permit 244 finished at 1660132481.883584, after 1.2204480171203613, 302.93152594566345 since the start of the Manhattan code.
# Manhattan permit 245 finished at 1660132483.107151, after 1.2234759330749512, 304.1550929546356 since the start of the Manhattan code.
# Manhattan permit 246 finished at 1660132484.335467, after 1.228241205215454, 305.3834080696106 since the start of the Manhattan code.
# Manhattan permit 247 finished at 1660132485.5732942, after 1.2377488613128662, 306.6212339401245 since the start of the Manhattan code.
# Manhattan permit 248 finished at 1660132486.795552, after 1.2221958637237549, 307.84349298477173 since the start of the Manhattan code.
# Manhattan permit 249 finished at 1660132488.026266, after 1.230633020401001, 309.07420682907104 since the start of the Manhattan code.
# Manhattan permit 250 finished at 1660132489.260211, after 1.2338590621948242, 310.3081531524658 since the start of the Manhattan code.
# Manhattan permit 251 finished at 1660132490.485944, after 1.2256577014923096, 311.53388500213623 since the start of the Manhattan code.
# Manhattan permit 252 finished at 1660132491.719674, after 1.2336599826812744, 312.76761388778687 since the start of the Manhattan code.
# Manhattan permit 253 finished at 1660132492.9514382, after 1.231698989868164, 313.99937891960144 since the start of the Manhattan code.
# Manhattan permit 254 finished at 1660132494.176118, after 1.2246110439300537, 315.22405982017517 since the start of the Manhattan code.
# Manhattan permit 255 finished at 1660132495.400779, after 1.224592924118042, 316.44872283935547 since the start of the Manhattan code.
# Manhattan permit 256 finished at 1660132496.627271, after 1.2263219356536865, 317.675213098526 since the start of the Manhattan code.
# Manhattan permit 257 finished at 1660132497.84832, after 1.2209720611572266, 318.8962609767914 since the start of the Manhattan code.
# Manhattan permit 258 finished at 1660132499.07519, after 1.2268011569976807, 320.12313175201416 since the start of the Manhattan code.
# Manhattan permit 259 finished at 1660132500.29696, after 1.2216923236846924, 321.34490180015564 since the start of the Manhattan code.
# Manhattan permit 260 finished at 1660132501.524885, after 1.2277019023895264, 322.57282614707947 since the start of the Manhattan code.
# Manhattan permit 261 finished at 1660132502.751509, after 1.2265479564666748, 323.7994501590729 since the start of the Manhattan code.
# Manhattan permit 262 finished at 1660132503.980931, after 1.2293469905853271, 325.02887296676636 since the start of the Manhattan code.
# Manhattan permit 263 finished at 1660132505.206625, after 1.225621223449707, 326.2545669078827 since the start of the Manhattan code.
# Manhattan permit 264 finished at 1660132506.442781, after 1.2360870838165283, 327.49072194099426 since the start of the Manhattan code.
# Manhattan permit 265 finished at 1660132507.688299, after 1.2454428672790527, 328.7362401485443 since the start of the Manhattan code.
# Manhattan permit 266 finished at 1660132508.9119518, after 1.2235829830169678, 329.95989298820496 since the start of the Manhattan code.
# Manhattan permit 267 finished at 1660132510.143023, after 1.2310006618499756, 331.19096398353577 since the start of the Manhattan code.
# Manhattan permit 268 finished at 1660132511.377322, after 1.2340888977050781, 332.4252631664276 since the start of the Manhattan code.
# Manhattan permit 269 finished at 1660132512.60305, after 1.2256460189819336, 333.65099000930786 since the start of the Manhattan code.
# Manhattan permit 270 finished at 1660132513.8881621, after 1.2850449085235596, 334.936105966568 since the start of the Manhattan code.
# Manhattan permit 271 finished at 1660132515.354111, after 1.4658267498016357, 336.4020609855652 since the start of the Manhattan code.
# Manhattan permit 272 finished at 1660132516.6116512, after 1.254974126815796, 337.65959191322327 since the start of the Manhattan code.
# Manhattan permit 273 finished at 1660132517.843148, after 1.23142409324646, 338.89108991622925 since the start of the Manhattan code.
# Manhattan permit 274 finished at 1660132519.075467, after 1.2322378158569336, 340.1234087944031 since the start of the Manhattan code.
# Manhattan permit 275 finished at 1660132520.313948, after 1.2384021282196045, 341.36188888549805 since the start of the Manhattan code.
# Manhattan permit 276 finished at 1660132521.538326, after 1.2242860794067383, 342.58626675605774 since the start of the Manhattan code.
# Manhattan permit 277 finished at 1660132524.260843, after 2.722447156906128, 345.30878496170044 since the start of the Manhattan code.
# Manhattan permit 278 finished at 1660132525.4948218, after 1.233903169631958, 346.54276490211487 since the start of the Manhattan code.
# Manhattan permit 279 finished at 1660132526.731272, after 1.2362627983093262, 347.77921295166016 since the start of the Manhattan code.
#
# Time to run Manhattan: 347.7942430973053
# Processing the Bronx
# Bronx permit 0 finished at 1660132527.891582, after 1.1422791481018066, 1.1452233791351318 since the start of the Bronx code.
# Bronx permit 1 finished at 1660132529.019428, after 1.1277399063110352, 2.2730681896209717 since the start of the Bronx code.
# Bronx permit 2 finished at 1660132530.1402209, after 1.120704174041748, 3.393862247467041 since the start of the Bronx code.
# Bronx permit 3 finished at 1660132531.2575428, after 1.1172568798065186, 4.511184215545654 since the start of the Bronx code.
# Bronx permit 4 finished at 1660132532.377413, after 1.119797945022583, 5.63105320930481 since the start of the Bronx code.
# Bronx permit 5 finished at 1660132533.499062, after 1.1215732097625732, 6.752701997756958 since the start of the Bronx code.
# Bronx permit 6 finished at 1660132534.6188211, after 1.119687795639038, 7.872462272644043 since the start of the Bronx code.
# Bronx permit 7 finished at 1660132535.7463338, after 1.1274240016937256, 8.999974250793457 since the start of the Bronx code.
# Bronx permit 8 finished at 1660132536.956317, after 1.2099058628082275, 10.20995831489563 since the start of the Bronx code.
# Bronx permit 9 finished at 1660132538.069626, after 1.113236904144287, 11.323265075683594 since the start of the Bronx code.
# Bronx permit 10 finished at 1660132539.196959, after 1.1272592544555664, 12.450598239898682 since the start of the Bronx code.
# Bronx permit 11 finished at 1660132540.32027, after 1.123227834701538, 13.573909997940063 since the start of the Bronx code.
# Bronx permit 12 finished at 1660132541.443224, after 1.1228821277618408, 14.69686508178711 since the start of the Bronx code.
# Bronx permit 13 finished at 1660132542.559278, after 1.115851879119873, 15.812918186187744 since the start of the Bronx code.
# Bronx permit 14 finished at 1660132543.6888871, after 1.1295418739318848, 16.942528009414673 since the start of the Bronx code.
# Bronx permit 15 finished at 1660132544.810715, after 1.12174391746521, 18.06435513496399 since the start of the Bronx code.
# Bronx permit 16 finished at 1660132545.9352949, after 1.124507188796997, 19.18893527984619 since the start of the Bronx code.
# Bronx permit 17 finished at 1660132547.064318, after 1.128952980041504, 20.31795835494995 since the start of the Bronx code.
# Bronx permit 18 finished at 1660132548.187209, after 1.1228232383728027, 21.440850257873535 since the start of the Bronx code.
# Bronx permit 19 finished at 1660132549.31374, after 1.126452922821045, 22.56737995147705 since the start of the Bronx code.
# Bronx permit 20 finished at 1660132550.4333289, after 1.1195008754730225, 23.686970233917236 since the start of the Bronx code.
# Bronx permit 21 finished at 1660132551.559613, after 1.1262221336364746, 24.81325626373291 since the start of the Bronx code.
# Bronx permit 22 finished at 1660132552.685518, after 1.1257328987121582, 25.939159154891968 since the start of the Bronx code.
# Bronx permit 23 finished at 1660132553.821151, after 1.1355462074279785, 27.07479238510132 since the start of the Bronx code.
# Bronx permit 24 finished at 1660132554.944847, after 1.1235988140106201, 28.19848608970642 since the start of the Bronx code.
# Bronx permit 25 finished at 1660132556.078099, after 1.133188247680664, 29.331738233566284 since the start of the Bronx code.
# Bronx permit 26 finished at 1660132557.2036421, after 1.1254699230194092, 30.45728325843811 since the start of the Bronx code.
# Bronx permit 27 finished at 1660132558.323961, after 1.1202497482299805, 31.57760214805603 since the start of the Bronx code.
# Bronx permit 28 finished at 1660132559.438278, after 1.1142370700836182, 32.69191813468933 since the start of the Bronx code.
# Bronx permit 29 finished at 1660132560.553535, after 1.1151962280273438, 33.80717420578003 since the start of the Bronx code.
# Bronx permit 30 finished at 1660132561.982851, after 1.4292840957641602, 35.23651099205017 since the start of the Bronx code.
# Bronx permit 31 finished at 1660132563.212123, after 1.2285809516906738, 36.46576428413391 since the start of the Bronx code.
# Bronx permit 32 finished at 1660132564.355299, after 1.1430778503417969, 37.60894012451172 since the start of the Bronx code.
# Bronx permit 33 finished at 1660132565.478403, after 1.1230316162109375, 38.7320442199707 since the start of the Bronx code.
# Bronx permit 34 finished at 1660132566.600064, after 1.1214861869812012, 39.85370421409607 since the start of the Bronx code.
# Bronx permit 35 finished at 1660132567.728509, after 1.1282520294189453, 40.9821503162384 since the start of the Bronx code.
# Bronx permit 36 finished at 1660132568.858125, after 1.129396915435791, 42.11176609992981 since the start of the Bronx code.
# Bronx permit 37 finished at 1660132569.990771, after 1.1325712203979492, 43.24441123008728 since the start of the Bronx code.
# Bronx permit 38 finished at 1660132571.111119, after 1.1202678680419922, 44.36475920677185 since the start of the Bronx code.
# Bronx permit 39 finished at 1660132572.237587, after 1.1264088153839111, 45.491228342056274 since the start of the Bronx code.
# Bronx permit 40 finished at 1660132573.352642, after 1.1149849891662598, 46.60628318786621 since the start of the Bronx code.
# Bronx permit 41 finished at 1660132574.4962308, after 1.1435229778289795, 47.7498722076416 since the start of the Bronx code.
# Bronx permit 42 finished at 1660132575.662186, after 1.1658811569213867, 48.91582727432251 since the start of the Bronx code.
# Bronx permit 43 finished at 1660132576.7943208, after 1.1320288181304932, 50.0479621887207 since the start of the Bronx code.
# Bronx permit 44 finished at 1660132577.915633, after 1.1212348937988281, 51.16927528381348 since the start of the Bronx code.
# Bronx permit 45 finished at 1660132579.045231, after 1.1295139789581299, 52.298872232437134 since the start of the Bronx code.
# Bronx permit 46 finished at 1660132580.172013, after 1.1267037391662598, 53.42565298080444 since the start of the Bronx code.
# Bronx permit 47 finished at 1660132581.287779, after 1.1156859397888184, 54.54141807556152 since the start of the Bronx code.
# Bronx permit 48 finished at 1660132582.436532, after 1.1486871242523193, 55.69017219543457 since the start of the Bronx code.
# Bronx permit 49 finished at 1660132583.551115, after 1.1145052909851074, 56.804754972457886 since the start of the Bronx code.
# Bronx permit 50 finished at 1660132584.671552, after 1.1203560829162598, 57.92519235610962 since the start of the Bronx code.
# Bronx permit 51 finished at 1660132585.792417, after 1.120793104171753, 59.046058177948 since the start of the Bronx code.
# Bronx permit 52 finished at 1660132586.926056, after 1.1335620880126953, 60.17969512939453 since the start of the Bronx code.
# Bronx permit 53 finished at 1660132588.0530949, after 1.1269690990447998, 61.306737184524536 since the start of the Bronx code.
# Bronx permit 54 finished at 1660132589.17963, after 1.1263659000396729, 62.43327021598816 since the start of the Bronx code.
# Bronx permit 55 finished at 1660132590.301058, after 1.121356725692749, 63.554699182510376 since the start of the Bronx code.
# Bronx permit 56 finished at 1660132591.421812, after 1.1206700801849365, 64.67545223236084 since the start of the Bronx code.
# Bronx permit 57 finished at 1660132592.5462642, after 1.1242339611053467, 65.79990410804749 since the start of the Bronx code.
# Bronx permit 58 finished at 1660132593.6713269, after 1.125000238418579, 66.92496728897095 since the start of the Bronx code.
# Bronx permit 59 finished at 1660132594.79015, after 1.1187489032745361, 68.043790102005 since the start of the Bronx code.
# Bronx permit 60 finished at 1660132595.9181921, after 1.1279690265655518, 69.17183327674866 since the start of the Bronx code.
# Bronx permit 61 finished at 1660132597.056062, after 1.1376190185546875, 70.30970335006714 since the start of the Bronx code.
# Bronx permit 62 finished at 1660132598.1827881, after 1.1266529560089111, 71.43642807006836 since the start of the Bronx code.
# Bronx permit 63 finished at 1660132599.304945, after 1.1220850944519043, 72.55858516693115 since the start of the Bronx code.
# Bronx permit 64 finished at 1660132600.427412, after 1.1223971843719482, 73.68105220794678 since the start of the Bronx code.
# Bronx permit 65 finished at 1660132601.55902, after 1.1315193176269531, 74.81265997886658 since the start of the Bronx code.
# Bronx permit 66 finished at 1660132602.706775, after 1.1476836204528809, 75.9604160785675 since the start of the Bronx code.
# Bronx permit 67 finished at 1660132603.8821461, after 1.1752920150756836, 77.13579416275024 since the start of the Bronx code.
# Bronx permit 68 finished at 1660132605.016396, after 1.134150743484497, 78.27003717422485 since the start of the Bronx code.
# Bronx permit 69 finished at 1660132606.143338, after 1.1268651485443115, 79.3969783782959 since the start of the Bronx code.
# Bronx permit 70 finished at 1660132607.3621938, after 1.2187631130218506, 80.61583518981934 since the start of the Bronx code.
# Bronx permit 71 finished at 1660132608.482524, after 1.1201610565185547, 81.73616528511047 since the start of the Bronx code.
# Bronx permit 72 finished at 1660132609.611868, after 1.129276990890503, 82.86550807952881 since the start of the Bronx code.
# Bronx permit 73 finished at 1660132610.7361212, after 1.1241800785064697, 83.9897620677948 since the start of the Bronx code.
# Bronx permit 74 finished at 1660132611.864874, after 1.1286711692810059, 85.11851525306702 since the start of the Bronx code.
# Bronx permit 75 finished at 1660132613.074212, after 1.209244966506958, 86.32785201072693 since the start of the Bronx code.
# Bronx permit 76 finished at 1660132614.221302, after 1.1468231678009033, 87.47494316101074 since the start of the Bronx code.
# Bronx permit 77 finished at 1660132615.343064, after 1.1216697692871094, 88.59670615196228 since the start of the Bronx code.
# Bronx permit 78 finished at 1660132616.538603, after 1.1953482627868652, 89.79224395751953 since the start of the Bronx code.
# Bronx permit 79 finished at 1660132617.673335, after 1.134645700454712, 90.92697501182556 since the start of the Bronx code.
# ...
# Brooklyn permit 2075 finished at 1660139062.702254, after 1.4945709705352783, 3154.5725648403168 since the start of the Brooklyn code.
# Brooklyn permit 2076 finished at 1660139064.268367, after 1.5660500526428223, 3156.1386790275574 since the start of the Brooklyn code.
# Brooklyn permit 2077 finished at 1660139065.778458, after 1.5100009441375732, 3157.648770093918 since the start of the Brooklyn code.
# Brooklyn permit 2078 finished at 1660139067.294652, after 1.516124963760376, 3159.1649639606476 since the start of the Brooklyn code.
# Brooklyn permit 2079 finished at 1660139068.807828, after 1.513106107711792, 3160.6781392097473 since the start of the Brooklyn code.
# Brooklyn permit 2080 finished at 1660139070.321961, after 1.5140621662139893, 3162.1922731399536 since the start of the Brooklyn code.
# Brooklyn permit 2081 finished at 1660139071.822492, after 1.5004479885101318, 3163.6928050518036 since the start of the Brooklyn code.
# Brooklyn permit 2082 finished at 1660139073.359349, after 1.5366172790527344, 3165.229660987854 since the start of the Brooklyn code.
# Brooklyn permit 2083 finished at 1660139074.8696132, after 1.5101900100708008, 3166.73992395401 since the start of the Brooklyn code.
# Brooklyn permit 2084 finished at 1660139076.3702369, after 1.5005550384521484, 3168.24054813385 since the start of the Brooklyn code.
# Brooklyn permit 2085 finished at 1660139077.8873742, after 1.5170629024505615, 3169.7576858997345 since the start of the Brooklyn code.
# Brooklyn permit 2086 finished at 1660139079.389222, after 1.5017688274383545, 3171.259532928467 since the start of the Brooklyn code.
# Brooklyn permit 2087 finished at 1660139080.913365, after 1.5240540504455566, 3172.7836768627167 since the start of the Brooklyn code.
# Brooklyn permit 2088 finished at 1660139082.4426491, after 1.5292150974273682, 3174.312959909439 since the start of the Brooklyn code.
# Brooklyn permit 2089 finished at 1660139083.950513, after 1.507784128189087, 3175.820825099945 since the start of the Brooklyn code.
# Brooklyn permit 2090 finished at 1660139085.444902, after 1.4943208694458008, 3177.3152120113373 since the start of the Brooklyn code.
# Brooklyn permit 2091 finished at 1660139086.960086, after 1.5151257514953613, 3178.8303978443146 since the start of the Brooklyn code.
# Brooklyn permit 2092 finished at 1660139088.486552, after 1.526397943496704, 3180.3568630218506 since the start of the Brooklyn code.
# Brooklyn permit 2093 finished at 1660139089.978359, after 1.4917328357696533, 3181.8486700057983 since the start of the Brooklyn code.
# Brooklyn permit 2094 finished at 1660139091.544259, after 1.5658397674560547, 3183.4145698547363 since the start of the Brooklyn code.
# Brooklyn permit 2095 finished at 1660139093.043679, after 1.4993400573730469, 3184.913991212845 since the start of the Brooklyn code.
# Brooklyn permit 2096 finished at 1660139094.535809, after 1.4920439720153809, 3186.406119823456 since the start of the Brooklyn code.
# Brooklyn permit 2097 finished at 1660139096.0480351, after 1.5121591091156006, 3187.918345928192 since the start of the Brooklyn code.
# Brooklyn permit 2098 finished at 1660139097.590406, after 1.5423030853271484, 3189.460718154907 since the start of the Brooklyn code.
# Brooklyn permit 2099 finished at 1660139099.0992892, after 1.508814811706543, 3190.9695999622345 since the start of the Brooklyn code.
# Brooklyn permit 2100 finished at 1660139100.6608891, after 1.561532974243164, 3192.5311999320984 since the start of the Brooklyn code.
# Brooklyn permit 2101 finished at 1660139102.168122, after 1.5071637630462646, 3194.038433074951 since the start of the Brooklyn code.
# Brooklyn permit 2102 finished at 1660139103.710268, after 1.5420770645141602, 3195.5805790424347 since the start of the Brooklyn code.
# Brooklyn permit 2103 finished at 1660139105.2249432, after 1.5146079063415527, 3197.0952548980713 since the start of the Brooklyn code.
# Brooklyn permit 2104 finished at 1660139106.762613, after 1.537600040435791, 3198.632924079895 since the start of the Brooklyn code.
# Brooklyn permit 2105 finished at 1660139108.30569, after 1.543010950088501, 3200.1760020256042 since the start of the Brooklyn code.
# Brooklyn permit 2106 finished at 1660139109.867667, after 1.561894178390503, 3201.7379791736603 since the start of the Brooklyn code.
# Brooklyn permit 2107 finished at 1660139111.362396, after 1.4946401119232178, 3203.232707977295 since the start of the Brooklyn code.
# Brooklyn permit 2108 finished at 1660139112.882643, after 1.5201828479766846, 3204.752955198288 since the start of the Brooklyn code.
# Brooklyn permit 2109 finished at 1660139114.429754, after 1.5470337867736816, 3206.3000650405884 since the start of the Brooklyn code.
# Brooklyn permit 2110 finished at 1660139115.984469, after 1.5546400547027588, 3207.8547809123993 since the start of the Brooklyn code.
# Brooklyn permit 2111 finished at 1660139117.514921, after 1.5303680896759033, 3209.3852331638336 since the start of the Brooklyn code.
# Brooklyn permit 2112 finished at 1660139119.035533, after 1.5205399990081787, 3210.90584397316 since the start of the Brooklyn code.
# Brooklyn permit 2113 finished at 1660139120.5874949, after 1.551872968673706, 3212.457806110382 since the start of the Brooklyn code.
# Brooklyn permit 2114 finished at 1660139122.078846, after 1.4912781715393066, 3213.949158191681 since the start of the Brooklyn code.
# Brooklyn permit 2115 finished at 1660139123.6283362, after 1.5494201183319092, 3215.498647928238 since the start of the Brooklyn code.
# Brooklyn permit 2116 finished at 1660139125.1571698, after 1.528759241104126, 3217.0274810791016 since the start of the Brooklyn code.
# Brooklyn permit 2117 finished at 1660139126.650165, after 1.492908000946045, 3218.520476102829 since the start of the Brooklyn code.
# Brooklyn permit 2118 finished at 1660139128.172698, after 1.5224676132202148, 3220.04300904274 since the start of the Brooklyn code.
# Brooklyn permit 2119 finished at 1660139129.688876, after 1.516111135482788, 3221.559186935425 since the start of the Brooklyn code.
# Brooklyn permit 2120 finished at 1660139131.202946, after 1.5139989852905273, 3223.073257923126 since the start of the Brooklyn code.
# Brooklyn permit 2121 finished at 1660139132.699625, after 1.4965980052947998, 3224.5699360370636 since the start of the Brooklyn code.
# Brooklyn permit 2122 finished at 1660139134.2044, after 1.5047118663787842, 3226.074711084366 since the start of the Brooklyn code.
# Brooklyn permit 2123 finished at 1660139135.721334, after 1.5168569087982178, 3227.591645002365 since the start of the Brooklyn code.
# Brooklyn permit 2124 finished at 1660139137.2539039, after 1.53249192237854, 3229.1242151260376 since the start of the Brooklyn code.
# Brooklyn permit 2125 finished at 1660139138.778381, after 1.5244169235229492, 3230.648692846298 since the start of the Brooklyn code.
# Brooklyn permit 2126 finished at 1660139140.2714722, after 1.493006944656372, 3232.1417829990387 since the start of the Brooklyn code.
# Brooklyn permit 2127 finished at 1660139141.783466, after 1.5119292736053467, 3233.6537771224976 since the start of the Brooklyn code.
# Brooklyn permit 2128 finished at 1660139143.3079329, after 1.524400234222412, 3235.1782450675964 since the start of the Brooklyn code.
# Brooklyn permit 2129 finished at 1660139144.849254, after 1.5412509441375732, 3236.7195649147034 since the start of the Brooklyn code.
# Brooklyn permit 2130 finished at 1660139146.348624, after 1.4992892742156982, 3238.2189350128174 since the start of the Brooklyn code.
# Brooklyn permit 2131 finished at 1660139147.8747919, after 1.5261049270629883, 3239.745103120804 since the start of the Brooklyn code.
# Brooklyn permit 2132 finished at 1660139149.3670862, after 1.4922120571136475, 3241.23739695549 since the start of the Brooklyn code.
# Brooklyn permit 2133 finished at 1660139150.901279, after 1.5341200828552246, 3242.7715911865234 since the start of the Brooklyn code.
# Brooklyn permit 2134 finished at 1660139152.406728, after 1.5053822994232178, 3244.27704000473 since the start of the Brooklyn code.
# Brooklyn permit 2135 finished at 1660139153.9025202, after 1.495723009109497, 3245.7728309631348 since the start of the Brooklyn code.
# Brooklyn permit 2136 finished at 1660139155.430014, after 1.5274269580841064, 3247.300325155258 since the start of the Brooklyn code.
# Brooklyn permit 2137 finished at 1660139156.962722, after 1.5326428413391113, 3248.8330340385437 since the start of the Brooklyn code.
# Brooklyn permit 2138 finished at 1660139158.504477, after 1.5416829586029053, 3250.3747889995575 since the start of the Brooklyn code.
# Brooklyn permit 2139 finished at 1660139160.019234, after 1.5146889686584473, 3251.889545917511 since the start of the Brooklyn code.
# Brooklyn permit 2140 finished at 1660139161.5840268, after 1.5647218227386475, 3253.454339981079 since the start of the Brooklyn code.
# Brooklyn permit 2141 finished at 1660139163.371403, after 1.7872838973999023, 3255.2417199611664 since the start of the Brooklyn code.
# Brooklyn permit 2142 finished at 1660139164.9283352, after 1.5560698509216309, 3256.79864692688 since the start of the Brooklyn code.
# Brooklyn permit 2143 finished at 1660139166.533397, after 1.6049799919128418, 3258.403708219528 since the start of the Brooklyn code.
# Brooklyn permit 2144 finished at 1660139168.080968, after 1.5474879741668701, 3259.9512810707092 since the start of the Brooklyn code.
# Brooklyn permit 2145 finished at 1660139169.6909509, after 1.6098999977111816, 3261.5612621307373 since the start of the Brooklyn code.
# Brooklyn permit 2146 finished at 1660139171.223507, after 1.5324900150299072, 3263.093820810318 since the start of the Brooklyn code.
# Brooklyn permit 2147 finished at 1660139172.722167, after 1.4982008934020996, 3264.592478990555 since the start of the Brooklyn code.
# Brooklyn permit 2148 finished at 1660139174.267342, after 1.5451078414916992, 3266.137652873993 since the start of the Brooklyn code.
# Brooklyn permit 2149 finished at 1660139175.8367941, after 1.5693659782409668, 3267.707106113434 since the start of the Brooklyn code.
# Brooklyn permit 2150 finished at 1660139177.424769, after 1.5877408981323242, 3269.2950830459595 since the start of the Brooklyn code.
# Brooklyn permit 2151 finished at 1660139178.9871948, after 1.5623552799224854, 3270.8575100898743 since the start of the Brooklyn code.
# Brooklyn permit 2152 finished at 1660139180.515523, after 1.528244972229004, 3272.385833978653 since the start of the Brooklyn code.
# Brooklyn permit 2153 finished at 1660139182.009058, after 1.4934520721435547, 3273.879373073578 since the start of the Brooklyn code.
# Brooklyn permit 2154 finished at 1660139183.5460968, after 1.5368070602416992, 3275.4164090156555 since the start of the Brooklyn code.
# Brooklyn permit 2155 finished at 1660139185.065181, after 1.5190050601959229, 3276.935492038727 since the start of the Brooklyn code.
# Brooklyn permit 2156 finished at 1660139186.565247, after 1.4999899864196777, 3278.435558080673 since the start of the Brooklyn code.
# Brooklyn permit 2157 finished at 1660139188.090399, after 1.5250790119171143, 3279.9607112407684 since the start of the Brooklyn code.
# Brooklyn permit 2158 finished at 1660139189.616787, after 1.5263049602508545, 3281.487097978592 since the start of the Brooklyn code.
# Brooklyn permit 2159 finished at 1660139191.12186, after 1.5050058364868164, 3282.992171049118 since the start of the Brooklyn code.
# Brooklyn permit 2160 finished at 1660139192.61936, after 1.4974310398101807, 3284.4896700382233 since the start of the Brooklyn code.
# Brooklyn permit 2161 finished at 1660139194.138162, after 1.5187339782714844, 3286.0084731578827 since the start of the Brooklyn code.
# Brooklyn permit 2162 finished at 1660139195.710617, after 1.572389841079712, 3287.580927848816 since the start of the Brooklyn code.
# Brooklyn permit 2163 finished at 1660139197.243001, after 1.532311201095581, 3289.1133120059967 since the start of the Brooklyn code.
# Brooklyn permit 2164 finished at 1660139198.772458, after 1.5293831825256348, 3290.642770051956 since the start of the Brooklyn code.
# Brooklyn permit 2165 finished at 1660139200.309572, after 1.5370371341705322, 3292.179883003235 since the start of the Brooklyn code.
# Brooklyn permit 2166 finished at 1660139201.802633, after 1.4929962158203125, 3293.6729431152344 since the start of the Brooklyn code.
# Brooklyn permit 2167 finished at 1660139203.35332, after 1.5506260395050049, 3295.22363114357 since the start of the Brooklyn code.
# Brooklyn permit 2168 finished at 1660139204.89447, after 1.5410590171813965, 3296.7647819519043 since the start of the Brooklyn code.
# Brooklyn permit 2169 finished at 1660139206.43402, after 1.539480209350586, 3298.3043320178986 since the start of the Brooklyn code.
# Brooklyn permit 2170 finished at 1660139208.002599, after 1.568485975265503, 3299.87291097641 since the start of the Brooklyn code.
# Brooklyn permit 2171 finished at 1660139209.5140421, after 1.5113646984100342, 3301.3843541145325 since the start of the Brooklyn code.
# Brooklyn permit 2172 finished at 1660139211.0119839, after 1.497859001159668, 3302.8822948932648 since the start of the Brooklyn code.
# Brooklyn permit 2173 finished at 1660139212.537704, after 1.5256569385528564, 3304.408016204834 since the start of the Brooklyn code.
# Brooklyn permit 2174 finished at 1660139214.044152, after 1.5063707828521729, 3305.914463043213 since the start of the Brooklyn code.
# Brooklyn permit 2175 finished at 1660139215.55231, after 1.5080931186676025, 3307.422621011734 since the start of the Brooklyn code.
# Brooklyn permit 2176 finished at 1660139217.1118112, after 1.5594251155853271, 3308.982122898102 since the start of the Brooklyn code.
# Brooklyn permit 2177 finished at 1660139218.6371148, after 1.525221824645996, 3310.5074269771576 since the start of the Brooklyn code.
# Brooklyn permit 2178 finished at 1660139220.18225, after 1.5450670719146729, 3312.052562236786 since the start of the Brooklyn code.
# Brooklyn permit 2179 finished at 1660139221.7099872, after 1.5276696681976318, 3313.58029794693 since the start of the Brooklyn code.
# Brooklyn permit 2180 finished at 1660139223.202539, after 1.4924771785736084, 3315.072850227356 since the start of the Brooklyn code.
# Brooklyn permit 2181 finished at 1660139224.726096, after 1.523488998413086, 3316.5964081287384 since the start of the Brooklyn code.
# Brooklyn permit 2182 finished at 1660139226.259404, after 1.5320258140563965, 3318.1297149658203 since the start of the Brooklyn code.
# Brooklyn permit 2183 finished at 1660139227.793461, after 1.5339839458465576, 3319.6637721061707 since the start of the Brooklyn code.
# Brooklyn permit 2184 finished at 1660139229.337331, after 1.5438032150268555, 3321.207643032074 since the start of the Brooklyn code.
# Brooklyn permit 2185 finished at 1660139230.85662, after 1.5192103385925293, 3322.7269308567047 since the start of the Brooklyn code.
# Brooklyn permit 2186 finished at 1660139232.348578, after 1.4918880462646484, 3324.218889951706 since the start of the Brooklyn code.
# Brooklyn permit 2187 finished at 1660139233.904299, after 1.5556530952453613, 3325.7746109962463 since the start of the Brooklyn code.
# Brooklyn permit 2188 finished at 1660139235.400631, after 1.4962520599365234, 3327.270943880081 since the start of the Brooklyn code.
# Brooklyn permit 2189 finished at 1660139236.9143932, after 1.5136511325836182, 3328.7847049236298 since the start of the Brooklyn code.
# Brooklyn permit 2190 finished at 1660139238.441173, after 1.5267131328582764, 3330.31148481369 since the start of the Brooklyn code.
# Brooklyn permit 2191 finished at 1660139239.9861188, after 1.5448570251464844, 3331.8564310073853 since the start of the Brooklyn code.
# Brooklyn permit 2192 finished at 1660139241.487398, after 1.5012140274047852, 3333.357710123062 since the start of the Brooklyn code.
#
# Time to run Brooklyn: 3333.3871669769287

# %% [markdown]
# # 2018

# %%
#Note: I didn't run this with the reset permits dfs, so I got an output with columns for both
#years run in this notebook.
permits_man = pd.read_csv('../data_permits_by_boro/permits_man.csv')
permits_bx = pd.read_csv('../data_permits_by_boro/permits_bx.csv')
permits_si = pd.read_csv('../data_permits_by_boro/permits_si.csv')
permits_qn = pd.read_csv('../data_permits_by_boro/permits_qn.csv')
permits_bk = pd.read_csv('../data_permits_by_boro/permits_bk.csv')

nypd_man = pd.read_csv('../data_nypd_by_year/2018/nypd2018_man.csv') #CHANGE YEAR
nypd_bx = pd.read_csv('../data_nypd_by_year/2018/nypd2018_bx.csv') #CHANGE YEAR
nypd_si = pd.read_csv('../data_nypd_by_year/2018/nypd2018_si.csv') #CHANGE YEAR
nypd_qn = pd.read_csv('../data_nypd_by_year/2018/nypd2018_qn.csv') #CHANGE YEAR
nypd_bk = pd.read_csv('../data_nypd_by_year/2018/nypd2018_bk.csv') #CHANGE YEAR

# %%
# MANHATTAN (MAN)
t0 = time.time()
print('Processing Manhattan')
permits_man.loc[0, 'complaints2018_19'] = 0 #CHANGE YEAR
for i in permits_man.index:
    t1 = time.time()
    lat = permits_man.loc[i, 'latitude']
    long = permits_man.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_man.index:
        n_lat = nypd_man.loc[n, 'latitude']
        n_long = nypd_man.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_man.loc[i, 'complaints2018_19'] = complaint_count #CHANGE YEAR
    print(f"Manhattan permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Manhattan code.")

permits_man.to_csv('../data_permits_w_nypd/permits_complaints2018_man.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Manhattan:", time.time()-t0) #


# THE BRONX (BX)
t0 = time.time()
print('Processing the Bronx')
permits_bx.loc[0, 'complaints2018_19'] = 0 #CHANGE YEAR
for i in permits_bx.index:
    t1 = time.time()
    lat = permits_bx.loc[i, 'latitude']
    long = permits_bx.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_bx.index:
        n_lat = nypd_bx.loc[n, 'latitude']
        n_long = nypd_bx.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_bx.loc[i, 'complaints2018_19'] = complaint_count #CHANGE YEAR
    print(f"Bronx permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Bronx code.")

permits_bx.to_csv('../data_permits_w_nypd/permits_complaints2018_bx.csv', index = False) #CHANGE YEAR

print('')
print("Time to run the Bronx:", time.time()-t0) #CHANGE BOROUGH


# STATEN ISLAND (SI)
t0 = time.time()
print('Processing Staten Island')
permits_si.loc[0, 'complaints2018_19'] = 0 #CHANGE YEAR
for i in permits_si.index:
    t1 = time.time()
    lat = permits_si.loc[i, 'latitude']
    long = permits_si.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_si.index:
        n_lat = nypd_si.loc[n, 'latitude']
        n_long = nypd_si.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_si.loc[i, 'complaints2018_19'] = complaint_count #CHANGE YEAR
    print(f"Staten Island permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Staten Island code.")

permits_si.to_csv('../data_permits_w_nypd/permits_complaints2018_si.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Staten Island:", time.time()-t0)


# QUEENS (QN)
t0 = time.time()
print('Processing Queens')
permits_qn.loc[0, 'complaints2018_19'] = 0 #CHANGE YEAR
for i in permits_qn.index:
    t1 = time.time()
    lat = permits_qn.loc[i, 'latitude']
    long = permits_qn.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_qn.index:
        n_lat = nypd_qn.loc[n, 'latitude']
        n_long = nypd_qn.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_qn.loc[i, 'complaints2018_19'] = complaint_count #CHANGE YEAR
    print(f"Queens permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Queens code.")

permits_qn.to_csv('../data_permits_w_nypd/permits_complaints2018_qn.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Queens:", time.time()-t0)


# BROOKLYN (BK)
t0 = time.time()
print('Processing Brooklyn')
permits_bk.loc[0, 'complaints2018_19'] = 0 #CHANGE YEAR
for i in permits_bk.index:
    t1 = time.time()
    lat = permits_bk.loc[i, 'latitude']
    long = permits_bk.loc[i, 'longitude']
    point1 = [lat, long]
    complaint_count = 0
    for n in nypd_bk.index:
        n_lat = nypd_bk.loc[n, 'latitude']
        n_long = nypd_bk.loc[n, 'longitude']
        if (abs(lat - n_lat)<= 1/690) or (abs(lat - n_long)<= 1/400):
            point2 = [n_lat, n_long]
            distance = get_distance(point1, point2)
            if distance <= .1:
                complaint_count += 1
    permits_bk.loc[i, 'complaints2018_19'] = complaint_count #CHANGE YEAR
    print(f"Brooklyn permit {i} finished at {time.time()}, after {time.time()-t1}, {time.time()-t0} since the start of the Brooklyn code.")


permits_bk.to_csv('../data_permits_w_nypd/permits_complaints2018_bk.csv', index = False) #CHANGE YEAR

print('')
print("Time to run Brooklyn:", time.time()-t0)
# Out:
# Processing Manhattan
# Manhattan permit 0 finished at 1660149801.653505, after 1.2249791622161865, 1.2308580875396729 since the start of the Manhattan code.
# Manhattan permit 1 finished at 1660149802.872133, after 1.2185547351837158, 2.4494762420654297 since the start of the Manhattan code.
# Manhattan permit 2 finished at 1660149804.1014552, after 1.2292401790618896, 3.678798198699951 since the start of the Manhattan code.
# Manhattan permit 3 finished at 1660149805.345972, after 1.2444441318511963, 4.923316240310669 since the start of the Manhattan code.
# Manhattan permit 4 finished at 1660149806.578885, after 1.232820987701416, 6.156229257583618 since the start of the Manhattan code.
# Manhattan permit 5 finished at 1660149807.803274, after 1.2241740226745605, 7.380618095397949 since the start of the Manhattan code.
# Manhattan permit 6 finished at 1660149809.014804, after 1.211449146270752, 8.59214735031128 since the start of the Manhattan code.
# Manhattan permit 7 finished at 1660149810.2461288, after 1.2312450408935547, 9.823472261428833 since the start of the Manhattan code.
# Manhattan permit 8 finished at 1660149811.469536, after 1.2233281135559082, 11.046880006790161 since the start of the Manhattan code.
# Manhattan permit 9 finished at 1660149812.691293, after 1.2216808795928955, 12.268635272979736 since the start of the Manhattan code.
# Manhattan permit 10 finished at 1660149813.9081511, after 1.2167890071868896, 13.48549509048462 since the start of the Manhattan code.
# Manhattan permit 11 finished at 1660149815.109907, after 1.2016589641571045, 14.687251329421997 since the start of the Manhattan code.
# Manhattan permit 12 finished at 1660149816.329521, after 1.2195489406585693, 15.906865358352661 since the start of the Manhattan code.
# Manhattan permit 13 finished at 1660149817.5672588, after 1.2376587390899658, 17.14460325241089 since the start of the Manhattan code.
# Manhattan permit 14 finished at 1660149818.795559, after 1.228234052658081, 18.372902154922485 since the start of the Manhattan code.
# Manhattan permit 15 finished at 1660149820.0236201, after 1.2279889583587646, 19.60096311569214 since the start of the Manhattan code.
# Manhattan permit 16 finished at 1660149821.350718, after 1.3270351886749268, 20.928062200546265 since the start of the Manhattan code.
# Manhattan permit 17 finished at 1660149822.587452, after 1.2365529537200928, 22.16479516029358 since the start of the Manhattan code.
# Manhattan permit 18 finished at 1660149823.8299189, after 1.2424020767211914, 23.40726327896118 since the start of the Manhattan code.
# Manhattan permit 19 finished at 1660149825.0596611, after 1.2296667098999023, 24.637003183364868 since the start of the Manhattan code.
# Manhattan permit 20 finished at 1660149826.290894, after 1.2311699390411377, 25.868237257003784 since the start of the Manhattan code.
# Manhattan permit 21 finished at 1660149827.516809, after 1.2258338928222656, 27.09415340423584 since the start of the Manhattan code.
# Manhattan permit 22 finished at 1660149828.7487738, after 1.2319080829620361, 28.326118230819702 since the start of the Manhattan code.
# Manhattan permit 23 finished at 1660149829.974445, after 1.225597858428955, 29.551788091659546 since the start of the Manhattan code.
# Manhattan permit 24 finished at 1660149831.199391, after 1.2247438430786133, 30.776734352111816 since the start of the Manhattan code.
# Manhattan permit 25 finished at 1660149832.432864, after 1.2334098815917969, 32.010207414627075 since the start of the Manhattan code.
# Manhattan permit 26 finished at 1660149833.658732, after 1.2258100509643555, 33.23607611656189 since the start of the Manhattan code.
# Manhattan permit 27 finished at 1660149834.886291, after 1.2274680137634277, 34.46363425254822 since the start of the Manhattan code.
# Manhattan permit 28 finished at 1660149836.11679, after 1.2304291725158691, 35.69413232803345 since the start of the Manhattan code.
# Manhattan permit 29 finished at 1660149837.347852, after 1.2309937477111816, 36.92519521713257 since the start of the Manhattan code.
# Manhattan permit 30 finished at 1660149838.587756, after 1.2398393154144287, 38.16510009765625 since the start of the Manhattan code.
# Manhattan permit 31 finished at 1660149839.819099, after 1.2312560081481934, 39.3964421749115 since the start of the Manhattan code.
# Manhattan permit 32 finished at 1660149841.0483918, after 1.229229211807251, 40.62573528289795 since the start of the Manhattan code.
# Manhattan permit 33 finished at 1660149842.280183, after 1.2317121028900146, 41.85752606391907 since the start of the Manhattan code.
# Manhattan permit 34 finished at 1660149843.511034, after 1.2307820320129395, 43.08837819099426 since the start of the Manhattan code.
# Manhattan permit 35 finished at 1660149844.739586, after 1.2284870147705078, 44.31692910194397 since the start of the Manhattan code.
# Manhattan permit 36 finished at 1660149845.964564, after 1.2249131202697754, 45.54190731048584 since the start of the Manhattan code.
# Manhattan permit 37 finished at 1660149847.202163, after 1.2375340461730957, 46.779505252838135 since the start of the Manhattan code.
# Manhattan permit 38 finished at 1660149848.455157, after 1.2528111934661865, 48.03250026702881 since the start of the Manhattan code.
# Manhattan permit 39 finished at 1660149849.685392, after 1.2301559448242188, 49.26273512840271 since the start of the Manhattan code.
# Manhattan permit 40 finished at 1660149850.9139771, after 1.228524923324585, 50.49131917953491 since the start of the Manhattan code.
# Manhattan permit 41 finished at 1660149852.1445918, after 1.230541706085205, 51.7219340801239 since the start of the Manhattan code.
# Manhattan permit 42 finished at 1660149853.370613, after 1.2259540557861328, 52.94795632362366 since the start of the Manhattan code.
# Manhattan permit 43 finished at 1660149854.5960388, after 1.2253670692443848, 54.17338228225708 since the start of the Manhattan code.
# Manhattan permit 44 finished at 1660149855.823594, after 1.2274863719940186, 55.40093731880188 since the start of the Manhattan code.
# Manhattan permit 45 finished at 1660149857.051597, after 1.2279419898986816, 56.62894010543823 since the start of the Manhattan code.
# Manhattan permit 46 finished at 1660149858.285408, after 1.2337350845336914, 57.86275124549866 since the start of the Manhattan code.
# Manhattan permit 47 finished at 1660149859.5323148, after 1.2468202114105225, 59.10965824127197 since the start of the Manhattan code.
# Manhattan permit 48 finished at 1660149860.766319, after 1.2339248657226562, 60.34366226196289 since the start of the Manhattan code.
# Manhattan permit 49 finished at 1660149861.994438, after 1.228046178817749, 61.571781158447266 since the start of the Manhattan code.
# Manhattan permit 50 finished at 1660149863.224092, after 1.2295758724212646, 62.80143427848816 since the start of the Manhattan code.
# Manhattan permit 51 finished at 1660149864.509156, after 1.2850000858306885, 64.08650016784668 since the start of the Manhattan code.
# Manhattan permit 52 finished at 1660149865.750876, after 1.241642951965332, 65.32822036743164 since the start of the Manhattan code.
# Manhattan permit 53 finished at 1660149866.990547, after 1.2395830154418945, 66.56788921356201 since the start of the Manhattan code.
# Manhattan permit 54 finished at 1660149868.224774, after 1.234158992767334, 67.8021171092987 since the start of the Manhattan code.
# Manhattan permit 55 finished at 1660149869.451576, after 1.226722240447998, 69.02892017364502 since the start of the Manhattan code.
# Manhattan permit 56 finished at 1660149870.688789, after 1.2371392250061035, 70.26613235473633 since the start of the Manhattan code.
# Manhattan permit 57 finished at 1660149871.93184, after 1.2429592609405518, 71.50918412208557 since the start of the Manhattan code.
# Manhattan permit 58 finished at 1660149873.1715798, after 1.239659070968628, 72.7489242553711 since the start of the Manhattan code.
# Manhattan permit 59 finished at 1660149874.3979342, after 1.226200819015503, 73.97527813911438 since the start of the Manhattan code.
# Manhattan permit 60 finished at 1660149875.633101, after 1.2350997924804688, 75.21044421195984 since the start of the Manhattan code.
# Manhattan permit 61 finished at 1660149876.86187, after 1.2286958694458008, 76.43921208381653 since the start of the Manhattan code.
# Manhattan permit 62 finished at 1660149878.0964758, after 1.2345430850982666, 77.67381930351257 since the start of the Manhattan code.
# Manhattan permit 63 finished at 1660149879.334198, after 1.237652063369751, 78.91154098510742 since the start of the Manhattan code.
# Manhattan permit 64 finished at 1660149880.562803, after 1.2285239696502686, 80.14014720916748 since the start of the Manhattan code.
# Manhattan permit 65 finished at 1660149881.7955341, after 1.232651948928833, 81.37287712097168 since the start of the Manhattan code.
# Manhattan permit 66 finished at 1660149883.0240269, after 1.228423833847046, 82.60137033462524 since the start of the Manhattan code.
# Manhattan permit 67 finished at 1660149884.252799, after 1.2286961078643799, 83.83014225959778 since the start of the Manhattan code.
# Manhattan permit 68 finished at 1660149885.4785762, after 1.2257118225097656, 85.05591917037964 since the start of the Manhattan code.
# Manhattan permit 69 finished at 1660149886.717695, after 1.2390530109405518, 86.29503726959229 since the start of the Manhattan code.
# Manhattan permit 70 finished at 1660149887.943656, after 1.2258989810943604, 87.52099919319153 since the start of the Manhattan code.
# Manhattan permit 71 finished at 1660149889.17628, after 1.2325456142425537, 88.75362420082092 since the start of the Manhattan code.
# Manhattan permit 72 finished at 1660149890.406641, after 1.230295181274414, 89.98398518562317 since the start of the Manhattan code.
# Manhattan permit 73 finished at 1660149891.6379142, after 1.2311899662017822, 91.21525716781616 since the start of the Manhattan code.
# Manhattan permit 74 finished at 1660149892.8817239, after 1.2437238693237305, 92.45906734466553 since the start of the Manhattan code.
# Manhattan permit 75 finished at 1660149894.107508, after 1.225714921951294, 93.68485140800476 since the start of the Manhattan code.
# Manhattan permit 76 finished at 1660149895.333678, after 1.2261018753051758, 94.91102123260498 since the start of the Manhattan code.
# Manhattan permit 77 finished at 1660149896.557624, after 1.2238810062408447, 96.13496828079224 since the start of the Manhattan code.
# Manhattan permit 78 finished at 1660149897.786679, after 1.2289867401123047, 97.36402201652527 since the start of the Manhattan code.
# Manhattan permit 79 finished at 1660149899.014773, after 1.2280242443084717, 98.592116355896 since the start of the Manhattan code.
# Manhattan permit 80 finished at 1660149900.24761, after 1.2327558994293213, 99.82495307922363 since the start of the Manhattan code.
# Manhattan permit 81 finished at 1660149901.484096, after 1.2364141941070557, 101.06143927574158 since the start of the Manhattan code.
# Manhattan permit 82 finished at 1660149902.70958, after 1.2254128456115723, 102.28692317008972 since the start of the Manhattan code.
# Manhattan permit 83 finished at 1660149903.937941, after 1.2282752990722656, 103.51528429985046 since the start of the Manhattan code.
# Manhattan permit 84 finished at 1660149905.1736388, after 1.2356340885162354, 104.7509822845459 since the start of the Manhattan code.
# Manhattan permit 85 finished at 1660149906.407485, after 1.233776330947876, 105.98482728004456 since the start of the Manhattan code.
# Manhattan permit 86 finished at 1660149907.6421251, after 1.2345690727233887, 107.21946811676025 since the start of the Manhattan code.
# Manhattan permit 87 finished at 1660149908.871372, after 1.2291839122772217, 108.44871520996094 since the start of the Manhattan code.
# Manhattan permit 88 finished at 1660149910.107311, after 1.235853672027588, 109.68465423583984 since the start of the Manhattan code.
# Manhattan permit 89 finished at 1660149911.3334541, after 1.2260758876800537, 110.91079711914062 since the start of the Manhattan code.
# Manhattan permit 90 finished at 1660149912.563691, after 1.2301759719848633, 112.14103436470032 since the start of the Manhattan code.
# Manhattan permit 91 finished at 1660149913.792695, after 1.2289361953735352, 113.37003707885742 since the start of the Manhattan code.
# Manhattan permit 92 finished at 1660149915.0233002, after 1.2305359840393066, 114.60064315795898 since the start of the Manhattan code.
# Manhattan permit 93 finished at 1660149916.2624488, after 1.2390899658203125, 115.83979320526123 since the start of the Manhattan code.
# Manhattan permit 94 finished at 1660149917.4907331, after 1.2282121181488037, 117.06807708740234 since the start of the Manhattan code.
# Manhattan permit 95 finished at 1660149918.71873, after 1.2279269695281982, 118.29607343673706 since the start of the Manhattan code.
# Manhattan permit 96 finished at 1660149919.963532, after 1.244715690612793, 119.54087519645691 since the start of the Manhattan code.
# Manhattan permit 97 finished at 1660149921.2080278, after 1.2444279193878174, 120.78537011146545 since the start of the Manhattan code.
# Manhattan permit 98 finished at 1660149922.441138, after 1.2330470085144043, 122.01848125457764 since the start of the Manhattan code.
# Manhattan permit 99 finished at 1660149923.6893299, after 1.2481248378753662, 123.26667332649231 since the start of the Manhattan code.
# Manhattan permit 100 finished at 1660149924.917988, after 1.2285797595977783, 124.49533009529114 since the start of the Manhattan code.
# Manhattan permit 101 finished at 1660149926.1455538, after 1.2274911403656006, 125.72289729118347 since the start of the Manhattan code.
# Manhattan permit 102 finished at 1660149927.370068, after 1.224440097808838, 126.94741129875183 since the start of the Manhattan code.
# Manhattan permit 103 finished at 1660149928.609062, after 1.2389190196990967, 128.18640518188477 since the start of the Manhattan code.
# Manhattan permit 104 finished at 1660149929.841203, after 1.2320680618286133, 129.41854619979858 since the start of the Manhattan code.
# Manhattan permit 105 finished at 1660149931.0687318, after 1.2274560928344727, 130.64607524871826 since the start of the Manhattan code.
# Manhattan permit 106 finished at 1660149932.29516, after 1.22636079788208, 131.87250304222107 since the start of the Manhattan code.
# Manhattan permit 107 finished at 1660149933.5265448, after 1.2313191890716553, 133.10388827323914 since the start of the Manhattan code.
# Manhattan permit 108 finished at 1660149934.768824, after 1.2421886920928955, 134.34616827964783 since the start of the Manhattan code.
# Manhattan permit 109 finished at 1660149935.997813, after 1.2289159297943115, 135.57515621185303 since the start of the Manhattan code.
# Manhattan permit 110 finished at 1660149937.2326488, after 1.234771966934204, 136.809992313385 since the start of the Manhattan code.
# Manhattan permit 111 finished at 1660149938.4687371, after 1.235888957977295, 138.0460810661316 since the start of the Manhattan code.
# Manhattan permit 112 finished at 1660149939.703948, after 1.235137701034546, 139.2812910079956 since the start of the Manhattan code.
# Manhattan permit 113 finished at 1660149941.032108, after 1.328092098236084, 140.60945320129395 since the start of the Manhattan code.
# Manhattan permit 114 finished at 1660149942.2688582, after 1.2366271018981934, 141.84620118141174 since the start of the Manhattan code.
# Manhattan permit 115 finished at 1660149943.492063, after 1.223142147064209, 143.06940627098083 since the start of the Manhattan code.
# Manhattan permit 116 finished at 1660149944.733859, after 1.241731882095337, 144.31120204925537 since the start of the Manhattan code.
# Manhattan permit 117 finished at 1660149945.9757981, after 1.2418479919433594, 145.55314111709595 since the start of the Manhattan code.
# Manhattan permit 118 finished at 1660149947.20668, after 1.2308118343353271, 146.78402304649353 since the start of the Manhattan code.
# Manhattan permit 119 finished at 1660149948.443224, after 1.2364780902862549, 148.0205671787262 since the start of the Manhattan code.
# Manhattan permit 120 finished at 1660149949.687534, after 1.2442188262939453, 149.26487708091736 since the start of the Manhattan code.
# Manhattan permit 121 finished at 1660149950.9422998, after 1.2546899318695068, 150.51964330673218 since the start of the Manhattan code.
# Manhattan permit 122 finished at 1660149952.172012, after 1.2296247482299805, 151.74935603141785 since the start of the Manhattan code.
# Manhattan permit 123 finished at 1660149953.406731, after 1.2346444129943848, 152.9840750694275 since the start of the Manhattan code.
# Manhattan permit 124 finished at 1660149954.635347, after 1.2285280227661133, 154.21269035339355 since the start of the Manhattan code.
# Manhattan permit 125 finished at 1660149955.874391, after 1.2389788627624512, 155.45173406600952 since the start of the Manhattan code.
# Manhattan permit 126 finished at 1660149957.1075552, after 1.2330939769744873, 156.68489909172058 since the start of the Manhattan code.
# Manhattan permit 127 finished at 1660149958.3459818, after 1.238353967666626, 157.92332530021667 since the start of the Manhattan code.
# Manhattan permit 128 finished at 1660149959.5864089, after 1.2403481006622314, 159.1637544631958 since the start of the Manhattan code.
# Manhattan permit 129 finished at 1660149960.8225112, after 1.2360119819641113, 160.39985513687134 since the start of the Manhattan code.
# Manhattan permit 130 finished at 1660149962.050984, after 1.2284011840820312, 161.62832736968994 since the start of the Manhattan code.
# Manhattan permit 131 finished at 1660149963.2798998, after 1.2288439273834229, 162.85724329948425 since the start of the Manhattan code.
# Manhattan permit 132 finished at 1660149964.518201, after 1.2382268905639648, 164.09554409980774 since the start of the Manhattan code.
# Manhattan permit 133 finished at 1660149965.75003, after 1.2317419052124023, 165.3273732662201 since the start of the Manhattan code.
# Manhattan permit 134 finished at 1660149966.981544, after 1.2314491271972656, 166.5588881969452 since the start of the Manhattan code.
# Manhattan permit 135 finished at 1660149968.221854, after 1.2402420043945312, 167.79919838905334 since the start of the Manhattan code.
# Manhattan permit 136 finished at 1660149969.448513, after 1.2265691757202148, 169.0258560180664 since the start of the Manhattan code.
# Manhattan permit 137 finished at 1660149970.6850848, after 1.2365071773529053, 170.26242923736572 since the start of the Manhattan code.
# Manhattan permit 138 finished at 1660149971.915162, after 1.230003833770752, 171.49250531196594 since the start of the Manhattan code.
# Manhattan permit 139 finished at 1660149973.14608, after 1.2307190895080566, 172.7234241962433 since the start of the Manhattan code.
# Manhattan permit 140 finished at 1660149974.379101, after 1.2329552173614502, 173.95644426345825 since the start of the Manhattan code.
# Manhattan permit 141 finished at 1660149975.618114, after 1.2389202117919922, 175.19545722007751 since the start of the Manhattan code.
# Manhattan permit 142 finished at 1660149976.85419, after 1.236008882522583, 176.43153309822083 since the start of the Manhattan code.
# Manhattan permit 143 finished at 1660149978.088938, after 1.234679937362671, 177.66628122329712 since the start of the Manhattan code.
# Manhattan permit 144 finished at 1660149979.3182578, after 1.2292327880859375, 178.8956003189087 since the start of the Manhattan code.
# Manhattan permit 145 finished at 1660149980.560622, after 1.2422997951507568, 180.13796424865723 since the start of the Manhattan code.
# Manhattan permit 146 finished at 1660149981.7884061, after 1.2277071475982666, 181.3657500743866 since the start of the Manhattan code.
# Manhattan permit 147 finished at 1660149983.040732, after 1.252262830734253, 182.61807513237 since the start of the Manhattan code.
# Manhattan permit 148 finished at 1660149984.264113, after 1.2233128547668457, 183.84145617485046 since the start of the Manhattan code.
# Manhattan permit 149 finished at 1660149985.502044, after 1.2378520965576172, 185.07938623428345 since the start of the Manhattan code.
# Manhattan permit 150 finished at 1660149986.739349, after 1.237239122390747, 186.31669306755066 since the start of the Manhattan code.
# Manhattan permit 151 finished at 1660149987.978703, after 1.2392807006835938, 187.55604720115662 since the start of the Manhattan code.
# Manhattan permit 152 finished at 1660149989.210716, after 1.2319412231445312, 188.78805923461914 since the start of the Manhattan code.
# Manhattan permit 153 finished at 1660149990.456471, after 1.2456729412078857, 190.03381514549255 since the start of the Manhattan code.
# Manhattan permit 154 finished at 1660149991.686823, after 1.2302799224853516, 191.26416516304016 since the start of the Manhattan code.
# Manhattan permit 155 finished at 1660149992.925947, after 1.2390611171722412, 192.5032901763916 since the start of the Manhattan code.
# Manhattan permit 156 finished at 1660149994.159699, after 1.2336711883544922, 193.7370421886444 since the start of the Manhattan code.
# Manhattan permit 157 finished at 1660149995.4007108, after 1.2409179210662842, 194.97805333137512 since the start of the Manhattan code.
# Manhattan permit 158 finished at 1660149996.63055, after 1.2297451496124268, 196.20789408683777 since the start of the Manhattan code.
# Manhattan permit 159 finished at 1660149997.859491, after 1.2288689613342285, 197.43683409690857 since the start of the Manhattan code.
# Manhattan permit 160 finished at 1660149999.093089, after 1.2335360050201416, 198.67043209075928 since the start of the Manhattan code.
# Manhattan permit 161 finished at 1660150000.432836, after 1.339684009552002, 200.01018524169922 since the start of the Manhattan code.
# Manhattan permit 162 finished at 1660150001.685662, after 1.2523670196533203, 201.26300621032715 since the start of the Manhattan code.
# Manhattan permit 163 finished at 1660150002.9478028, after 1.262066125869751, 202.52514624595642 since the start of the Manhattan code.
# Manhattan permit 164 finished at 1660150004.209023, after 1.2611238956451416, 203.78637313842773 since the start of the Manhattan code.
# Manhattan permit 165 finished at 1660150005.460194, after 1.2510359287261963, 205.03753805160522 since the start of the Manhattan code.
# Manhattan permit 166 finished at 1660150006.7150521, after 1.2547950744628906, 206.292396068573 since the start of the Manhattan code.
# Manhattan permit 167 finished at 1660150007.969072, after 1.2539498805999756, 207.5464153289795 since the start of the Manhattan code.
# Manhattan permit 168 finished at 1660150009.224263, after 1.255129098892212, 208.8016061782837 since the start of the Manhattan code.
# Manhattan permit 169 finished at 1660150010.4670541, after 1.242717981338501, 210.0443971157074 since the start of the Manhattan code.
# Manhattan permit 170 finished at 1660150011.713758, after 1.2466340065002441, 211.2911012172699 since the start of the Manhattan code.
# Manhattan permit 171 finished at 1660150012.971138, after 1.2573177814483643, 212.5484812259674 since the start of the Manhattan code.
# Manhattan permit 172 finished at 1660150014.225375, after 1.2541639804840088, 213.8027184009552 since the start of the Manhattan code.
# Manhattan permit 173 finished at 1660150015.471887, after 1.2464590072631836, 215.0492343902588 since the start of the Manhattan code.
# Manhattan permit 174 finished at 1660150016.7246048, after 1.2526500225067139, 216.3019483089447 since the start of the Manhattan code.
# Manhattan permit 175 finished at 1660150017.9723918, after 1.2477171421051025, 217.5497362613678 since the start of the Manhattan code.
# Manhattan permit 176 finished at 1660150019.209667, after 1.2372076511383057, 218.78700923919678 since the start of the Manhattan code.
# Manhattan permit 177 finished at 1660150020.4518368, after 1.2420952320098877, 220.02918028831482 since the start of the Manhattan code.
# Manhattan permit 178 finished at 1660150021.683279, after 1.231367826461792, 221.2606222629547 since the start of the Manhattan code.
# Manhattan permit 179 finished at 1660150022.9161978, after 1.2328357696533203, 222.49354124069214 since the start of the Manhattan code.
# Manhattan permit 180 finished at 1660150024.1461802, after 1.2299110889434814, 223.7235231399536 since the start of the Manhattan code.
# Manhattan permit 181 finished at 1660150025.392601, after 1.2462236881256104, 224.96994519233704 since the start of the Manhattan code.
# Manhattan permit 182 finished at 1660150026.65287, after 1.2601571083068848, 226.23021626472473 since the start of the Manhattan code.
# Manhattan permit 183 finished at 1660150027.894638, after 1.2416839599609375, 227.47198104858398 since the start of the Manhattan code.
# Manhattan permit 184 finished at 1660150029.121055, after 1.2263460159301758, 228.6983962059021 since the start of the Manhattan code.
# Manhattan permit 185 finished at 1660150030.3516889, after 1.2305951118469238, 229.92903327941895 since the start of the Manhattan code.
# Manhattan permit 186 finished at 1660150031.578586, after 1.226815938949585, 231.1559281349182 since the start of the Manhattan code.
# Manhattan permit 187 finished at 1660150032.8025112, after 1.223862886428833, 232.3798520565033 since the start of the Manhattan code.
# Manhattan permit 188 finished at 1660150034.035306, after 1.2327489852905273, 233.6126503944397 since the start of the Manhattan code.
# Manhattan permit 189 finished at 1660150035.2673972, after 1.23201584815979, 234.844740152359 since the start of the Manhattan code.
# Manhattan permit 190 finished at 1660150036.508546, after 1.2410869598388672, 236.08589005470276 since the start of the Manhattan code.
# Manhattan permit 191 finished at 1660150037.733901, after 1.2252748012542725, 237.3112452030182 since the start of the Manhattan code.
# Manhattan permit 192 finished at 1660150038.9637382, after 1.2297711372375488, 238.54108119010925 since the start of the Manhattan code.
# Manhattan permit 193 finished at 1660150040.203358, after 1.239560842514038, 239.7807013988495 since the start of the Manhattan code.
# Manhattan permit 194 finished at 1660150041.439659, after 1.2362279891967773, 241.0170030593872 since the start of the Manhattan code.
# Manhattan permit 195 finished at 1660150042.6642969, after 1.224431037902832, 242.24163937568665 since the start of the Manhattan code.
# Manhattan permit 196 finished at 1660150043.890966, after 1.2265980243682861, 243.4683084487915 since the start of the Manhattan code.
# Manhattan permit 197 finished at 1660150045.119821, after 1.2288029193878174, 244.6971640586853 since the start of the Manhattan code.
# Manhattan permit 198 finished at 1660150046.345837, after 1.225952386856079, 245.92317914962769 since the start of the Manhattan code.
# Manhattan permit 199 finished at 1660150047.573508, after 1.227607011795044, 247.15085124969482 since the start of the Manhattan code.
# Manhattan permit 200 finished at 1660150048.798462, after 1.22489595413208, 248.3758053779602 since the start of the Manhattan code.
# Manhattan permit 201 finished at 1660150050.025043, after 1.226518154144287, 249.60238528251648 since the start of the Manhattan code.
# Manhattan permit 202 finished at 1660150051.25399, after 1.228883981704712, 250.83133125305176 since the start of the Manhattan code.
# Manhattan permit 203 finished at 1660150052.4927628, after 1.2387309074401855, 252.07010626792908 since the start of the Manhattan code.
# Manhattan permit 204 finished at 1660150053.725868, after 1.2330000400543213, 253.3032112121582 since the start of the Manhattan code.
# Manhattan permit 205 finished at 1660150054.9567292, after 1.2308008670806885, 254.53407216072083 since the start of the Manhattan code.
# Manhattan permit 206 finished at 1660150056.1865878, after 1.2296719551086426, 255.76393222808838 since the start of the Manhattan code.
# Manhattan permit 207 finished at 1660150057.4122722, after 1.2256267070770264, 256.98961424827576 since the start of the Manhattan code.
# Manhattan permit 208 finished at 1660150058.641245, after 1.2289271354675293, 258.21858620643616 since the start of the Manhattan code.
# Manhattan permit 209 finished at 1660150059.869457, after 1.22816801071167, 259.4468011856079 since the start of the Manhattan code.
# Manhattan permit 210 finished at 1660150061.0984871, after 1.228950023651123, 260.67583107948303 since the start of the Manhattan code.
# Manhattan permit 211 finished at 1660150062.419799, after 1.3212463855743408, 261.9971420764923 since the start of the Manhattan code.
# Manhattan permit 212 finished at 1660150063.651996, after 1.2320261001586914, 263.2293403148651 since the start of the Manhattan code.
# Manhattan permit 213 finished at 1660150064.879766, after 1.22770094871521, 264.45710730552673 since the start of the Manhattan code.
# Manhattan permit 214 finished at 1660150066.105394, after 1.2255747318267822, 265.68273425102234 since the start of the Manhattan code.
# Manhattan permit 215 finished at 1660150067.34108, after 1.2356441020965576, 266.91842317581177 since the start of the Manhattan code.
# Manhattan permit 216 finished at 1660150068.573835, after 1.232668161392212, 268.15117621421814 since the start of the Manhattan code.
# Manhattan permit 217 finished at 1660150069.7998111, after 1.2259280681610107, 269.3771550655365 since the start of the Manhattan code.
# Manhattan permit 218 finished at 1660150071.0286562, after 1.2287790775299072, 270.6060013771057 since the start of the Manhattan code.
# Manhattan permit 219 finished at 1660150072.257986, after 1.2291932106018066, 271.8353281021118 since the start of the Manhattan code.
# Manhattan permit 220 finished at 1660150073.483504, after 1.2254629135131836, 273.06084513664246 since the start of the Manhattan code.
# Manhattan permit 221 finished at 1660150074.715009, after 1.231459140777588, 274.2923512458801 since the start of the Manhattan code.
# Manhattan permit 222 finished at 1660150075.939935, after 1.2248799800872803, 275.51727843284607 since the start of the Manhattan code.
# Manhattan permit 223 finished at 1660150077.166833, after 1.2268338203430176, 276.74417424201965 since the start of the Manhattan code.
# Manhattan permit 224 finished at 1660150078.393425, after 1.2265398502349854, 277.9707672595978 since the start of the Manhattan code.
# Manhattan permit 225 finished at 1660150079.632931, after 1.2394442558288574, 279.2102720737457 since the start of the Manhattan code.
# Manhattan permit 226 finished at 1660150080.862232, after 1.2292561531066895, 280.4395730495453 since the start of the Manhattan code.
# Manhattan permit 227 finished at 1660150082.091583, after 1.2293119430541992, 281.6689262390137 since the start of the Manhattan code.
# Manhattan permit 228 finished at 1660150083.317709, after 1.226058006286621, 282.89505100250244 since the start of the Manhattan code.
# Manhattan permit 229 finished at 1660150084.544637, after 1.2268760204315186, 284.1219792366028 since the start of the Manhattan code.
# Manhattan permit 230 finished at 1660150085.773228, after 1.228520154953003, 285.35056924819946 since the start of the Manhattan code.
# Manhattan permit 231 finished at 1660150086.995039, after 1.2217719554901123, 286.57237935066223 since the start of the Manhattan code.
# Manhattan permit 232 finished at 1660150088.219512, after 1.2244317531585693, 287.79685401916504 since the start of the Manhattan code.
# Manhattan permit 233 finished at 1660150089.447707, after 1.228140115737915, 289.02505016326904 since the start of the Manhattan code.
# Manhattan permit 234 finished at 1660150090.673677, after 1.22590970993042, 290.2510190010071 since the start of the Manhattan code.
# Manhattan permit 235 finished at 1660150091.9010649, after 1.2273201942443848, 291.4784083366394 since the start of the Manhattan code.
# Manhattan permit 236 finished at 1660150093.139189, after 1.2380542755126953, 292.7165312767029 since the start of the Manhattan code.
# Manhattan permit 237 finished at 1660150094.3652039, after 1.225951910018921, 293.94254636764526 since the start of the Manhattan code.
# Manhattan permit 238 finished at 1660150095.5847502, after 1.219491720199585, 295.1620922088623 since the start of the Manhattan code.
# Manhattan permit 239 finished at 1660150096.830764, after 1.2459602355957031, 296.4081070423126 since the start of the Manhattan code.
# Manhattan permit 240 finished at 1660150098.056565, after 1.225724220275879, 297.63390731811523 since the start of the Manhattan code.
# Manhattan permit 241 finished at 1660150099.278114, after 1.2215020656585693, 298.85545539855957 since the start of the Manhattan code.
# Manhattan permit 242 finished at 1660150100.508773, after 1.2306160926818848, 300.0861163139343 since the start of the Manhattan code.
# Manhattan permit 243 finished at 1660150101.737282, after 1.228445291519165, 301.3146240711212 since the start of the Manhattan code.
# Manhattan permit 244 finished at 1660150102.9593248, after 1.2219908237457275, 302.53666734695435 since the start of the Manhattan code.
# Manhattan permit 245 finished at 1660150104.191911, after 1.2325260639190674, 303.7692542076111 since the start of the Manhattan code.
# Manhattan permit 246 finished at 1660150105.421081, after 1.229097843170166, 304.99842405319214 since the start of the Manhattan code.
# Manhattan permit 247 finished at 1660150106.649236, after 1.228081226348877, 306.2265782356262 since the start of the Manhattan code.
# Manhattan permit 248 finished at 1660150107.877602, after 1.2283082008361816, 307.45494413375854 since the start of the Manhattan code.
# Manhattan permit 249 finished at 1660150109.135745, after 1.2580981254577637, 308.7130880355835 since the start of the Manhattan code.
# Manhattan permit 250 finished at 1660150110.360947, after 1.2249929904937744, 309.9382891654968 since the start of the Manhattan code.
# Manhattan permit 251 finished at 1660150111.585946, after 1.2249500751495361, 311.1632881164551 since the start of the Manhattan code.
# Manhattan permit 252 finished at 1660150112.8101308, after 1.2241098880767822, 312.38747334480286 since the start of the Manhattan code.
# Manhattan permit 253 finished at 1660150114.0371578, after 1.2269840240478516, 313.61449813842773 since the start of the Manhattan code.
# Manhattan permit 254 finished at 1660150115.273115, after 1.235921859741211, 314.8504581451416 since the start of the Manhattan code.
# Manhattan permit 255 finished at 1660150116.5044749, after 1.2312819957733154, 316.08181715011597 since the start of the Manhattan code.
# Manhattan permit 256 finished at 1660150117.73946, after 1.2349298000335693, 317.3168022632599 since the start of the Manhattan code.
# Manhattan permit 257 finished at 1660150118.965253, after 1.225728988647461, 318.54259610176086 since the start of the Manhattan code.
# Manhattan permit 258 finished at 1660150120.197053, after 1.2317309379577637, 319.77439618110657 since the start of the Manhattan code.
# Manhattan permit 259 finished at 1660150121.4190981, after 1.221980094909668, 320.99644017219543 since the start of the Manhattan code.
# Manhattan permit 260 finished at 1660150122.6446788, after 1.22552490234375, 322.22202134132385 since the start of the Manhattan code.
# Manhattan permit 261 finished at 1660150123.877847, after 1.2331206798553467, 323.4551901817322 since the start of the Manhattan code.
# Manhattan permit 262 finished at 1660150125.116896, after 1.238983392715454, 324.69423937797546 since the start of the Manhattan code.
# Manhattan permit 263 finished at 1660150126.342956, after 1.225996732711792, 325.92030024528503 since the start of the Manhattan code.
# Manhattan permit 264 finished at 1660150127.5683389, after 1.225316047668457, 327.1456792354584 since the start of the Manhattan code.
# Manhattan permit 265 finished at 1660150128.7912881, after 1.2229030132293701, 328.3686282634735 since the start of the Manhattan code.
# Manhattan permit 266 finished at 1660150130.032502, after 1.241164207458496, 329.609845161438 since the start of the Manhattan code.
# Manhattan permit 267 finished at 1660150131.255323, after 1.2226240634918213, 330.83266520500183 since the start of the Manhattan code.
# Manhattan permit 268 finished at 1660150132.4749749, after 1.2195980548858643, 332.05231738090515 since the start of the Manhattan code.
# Manhattan permit 269 finished at 1660150133.717161, after 1.2421329021453857, 333.294504404068 since the start of the Manhattan code.
# Manhattan permit 270 finished at 1660150134.9474292, after 1.230187177658081, 334.5247712135315 since the start of the Manhattan code.
# Manhattan permit 271 finished at 1660150136.178412, after 1.2309291362762451, 335.75575518608093 since the start of the Manhattan code.
# Manhattan permit 272 finished at 1660150137.4038131, after 1.2253341674804688, 336.98115515708923 since the start of the Manhattan code.
# Manhattan permit 273 finished at 1660150138.640158, after 1.2362821102142334, 338.21750140190125 since the start of the Manhattan code.
# Manhattan permit 274 finished at 1660150139.8709419, after 1.230705976486206, 339.4482831954956 since the start of the Manhattan code.
# Manhattan permit 275 finished at 1660150141.1044962, after 1.2335069179534912, 340.6818392276764 since the start of the Manhattan code.
# Manhattan permit 276 finished at 1660150142.338013, after 1.233445167541504, 341.9153542518616 since the start of the Manhattan code.
# Manhattan permit 277 finished at 1660150143.563422, after 1.2253601551055908, 343.1407651901245 since the start of the Manhattan code.
# Manhattan permit 278 finished at 1660150144.792934, after 1.2294542789459229, 344.3702771663666 since the start of the Manhattan code.
# Manhattan permit 279 finished at 1660150146.018381, after 1.2253742218017578, 345.5957221984863 since the start of the Manhattan code.
#
# Time to run Manhattan: 345.60723209381104
# Processing the Bronx
# Bronx permit 0 finished at 1660150147.108618, after 1.077254056930542, 1.0786468982696533 since the start of the Bronx code.
# Bronx permit 1 finished at 1660150148.1839051, after 1.0752372741699219, 2.1539337635040283 since the start of the Bronx code.
# Bronx permit 2 finished at 1660150149.268455, after 1.0844781398773193, 3.2384839057922363 since the start of the Bronx code.
# Bronx permit 3 finished at 1660150150.3473961, after 1.078887939453125, 4.317425966262817 since the start of the Bronx code.
# Bronx permit 4 finished at 1660150151.430521, after 1.0829980373382568, 5.400548696517944 since the start of the Bronx code.
# Bronx permit 5 finished at 1660150152.504519, after 1.0739400386810303, 6.4745447635650635 since the start of the Bronx code.
# Bronx permit 6 finished at 1660150153.5804522, after 1.0758857727050781, 7.550479888916016 since the start of the Bronx code.
# Bronx permit 7 finished at 1660150154.6574578, after 1.076927900314331, 8.627486944198608 since the start of the Bronx code.
# Bronx permit 8 finished at 1660150155.739378, after 1.0818490982055664, 9.709404945373535 since the start of the Bronx code.
# Bronx permit 9 finished at 1660150156.817385, after 1.0779600143432617, 10.787412881851196 since the start of the Bronx code.
# Bronx permit 10 finished at 1660150157.8941598, after 1.0767078399658203, 11.864186763763428 since the start of the Bronx code.
# Bronx permit 11 finished at 1660150158.975478, after 1.0812749862670898, 12.94550609588623 since the start of the Bronx code.
# Bronx permit 12 finished at 1660150160.061739, after 1.086198091506958, 14.031766891479492 since the start of the Bronx code.
# Bronx permit 13 finished at 1660150161.145387, after 1.0835909843444824, 15.115416765213013 since the start of the Bronx code.
# Bronx permit 14 finished at 1660150162.228241, after 1.0827789306640625, 16.198269844055176 since the start of the Bronx code.
# Bronx permit 15 finished at 1660150163.310268, after 1.0819621086120605, 17.28029489517212 since the start of the Bronx code.
# Bronx permit 16 finished at 1660150164.3994749, after 1.0891551971435547, 18.369504928588867 since the start of the Bronx code.
# Bronx permit 17 finished at 1660150165.478029, after 1.0784757137298584, 19.448057889938354 since the start of the Bronx code.
# Bronx permit 18 finished at 1660150166.5635269, after 1.085439920425415, 20.53355598449707 since the start of the Bronx code.
# Bronx permit 19 finished at 1660150167.658634, after 1.0950398445129395, 21.628663778305054 since the start of the Bronx code.
# Bronx permit 20 finished at 1660150168.743623, after 1.0849149227142334, 22.713652849197388 since the start of the Bronx code.
# Bronx permit 21 finished at 1660150169.820332, after 1.0766289234161377, 23.790360689163208 since the start of the Bronx code.
# Bronx permit 22 finished at 1660150170.900435, after 1.0800549983978271, 24.870463848114014 since the start of the Bronx code.
# Bronx permit 23 finished at 1660150171.99375, after 1.0932540893554688, 25.96377968788147 since the start of the Bronx code.
# Bronx permit 24 finished at 1660150173.093778, after 1.099944829940796, 27.063807010650635 since the start of the Bronx code.
# Bronx permit 25 finished at 1660150174.175543, after 1.0816848278045654, 28.145570039749146 since the start of the Bronx code.
# Bronx permit 26 finished at 1660150175.257094, after 1.0815050601959229, 29.22712278366089 since the start of the Bronx code.
# Bronx permit 27 finished at 1660150176.336732, after 1.0795719623565674, 30.30675983428955 since the start of the Bronx code.
# Bronx permit 28 finished at 1660150177.409806, after 1.0730278491973877, 31.379833698272705 since the start of the Bronx code.
# Bronx permit 29 finished at 1660150178.488873, after 1.0790221691131592, 32.458900928497314 since the start of the Bronx code.
# Bronx permit 30 finished at 1660150179.571486, after 1.0825653076171875, 33.54151487350464 since the start of the Bronx code.
# Bronx permit 31 finished at 1660150180.657206, after 1.0856530666351318, 34.62723469734192 since the start of the Bronx code.
# Bronx permit 32 finished at 1660150181.738789, after 1.0815019607543945, 35.70881676673889 since the start of the Bronx code.
# Bronx permit 33 finished at 1660150182.915838, after 1.176983118057251, 36.88586688041687 since the start of the Bronx code.
# Bronx permit 34 finished at 1660150183.998615, after 1.0827007293701172, 37.968644857406616 since the start of the Bronx code.
# Bronx permit 35 finished at 1660150185.077714, after 1.0790331363677979, 39.04774284362793 since the start of the Bronx code.
# Bronx permit 36 finished at 1660150186.159564, after 1.0817911624908447, 40.12959170341492 since the start of the Bronx code.
# Bronx permit 37 finished at 1660150187.2412019, after 1.0815889835357666, 41.211230993270874 since the start of the Bronx code.
# Bronx permit 38 finished at 1660150188.3207638, after 1.079495906829834, 42.2907919883728 since the start of the Bronx code.
# Bronx permit 39 finished at 1660150189.405337, after 1.0845258235931396, 43.375364780426025 since the start of the Bronx code.
# Bronx permit 40 finished at 1660150190.4860318, after 1.0806379318237305, 44.45606088638306 since the start of the Bronx code.
# Bronx permit 41 finished at 1660150191.56596, after 1.0798640251159668, 45.535987854003906 since the start of the Bronx code.
# Bronx permit 42 finished at 1660150192.6543, after 1.0882837772369385, 46.624329805374146 since the start of the Bronx code.
# Bronx permit 43 finished at 1660150193.7377422, after 1.0833511352539062, 47.70777177810669 since the start of the Bronx code.
# Bronx permit 44 finished at 1660150194.8158028, after 1.0779879093170166, 48.785831928253174 since the start of the Bronx code.
# Bronx permit 45 finished at 1660150195.892242, after 1.0763649940490723, 49.86226773262024 since the start of the Bronx code.
# Bronx permit 46 finished at 1660150196.9684858, after 1.0762050151824951, 50.93851280212402 since the start of the Bronx code.
# Bronx permit 47 finished at 1660150198.044617, after 1.0760891437530518, 52.01464486122131 since the start of the Bronx code.
# Bronx permit 48 finished at 1660150199.124245, after 1.0794339179992676, 53.09427285194397 since the start of the Bronx code.
# Bronx permit 49 finished at 1660150200.2025669, after 1.0782718658447266, 54.1725959777832 since the start of the Bronx code.
# Bronx permit 50 finished at 1660150201.326685, after 1.124053955078125, 55.29671502113342 since the start of the Bronx code.
# Bronx permit 51 finished at 1660150202.407082, after 1.0802931785583496, 56.377110958099365 since the start of the Bronx code.
# Bronx permit 52 finished at 1660150203.503679, after 1.0965380668640137, 57.47370910644531 since the start of the Bronx code.
# Bronx permit 53 finished at 1660150204.603381, after 1.0996286869049072, 58.57341289520264 since the start of the Bronx code.
# Bronx permit 54 finished at 1660150205.702677, after 1.0991222858428955, 59.67270493507385 since the start of the Bronx code.
# Bronx permit 55 finished at 1660150206.801722, after 1.0989949703216553, 60.77174973487854 since the start of the Bronx code.
# Bronx permit 56 finished at 1660150207.902262, after 1.1004929542541504, 61.87228989601135 since the start of the Bronx code.
# Bronx permit 57 finished at 1660150208.996785, after 1.0944619178771973, 62.966813802719116 since the start of the Bronx code.
# Bronx permit 58 finished at 1660150210.100039, after 1.1032021045684814, 64.07006573677063 since the start of the Bronx code.
# Bronx permit 59 finished at 1660150211.192318, after 1.0922319889068604, 65.16234803199768 since the start of the Bronx code.
# Bronx permit 60 finished at 1660150212.286401, after 1.0939009189605713, 66.25642967224121 since the start of the Bronx code.
# Bronx permit 61 finished at 1660150213.3839018, after 1.0974340438842773, 67.35392999649048 since the start of the Bronx code.
# Bronx permit 62 finished at 1660150214.482711, after 1.0987651348114014, 68.45273876190186 since the start of the Bronx code.
# Bronx permit 63 finished at 1660150215.577149, after 1.0943920612335205, 69.54717803001404 since the start of the Bronx code.
# Bronx permit 64 finished at 1660150216.673855, after 1.096623182296753, 70.64388394355774 since the start of the Bronx code.
# Bronx permit 65 finished at 1660150217.7776608, after 1.1037399768829346, 71.74768996238708 since the start of the Bronx code.
# Bronx permit 66 finished at 1660150218.8682811, after 1.0905499458312988, 72.83830976486206 since the start of the Bronx code.
# Bronx permit 67 finished at 1660150219.942288, after 1.0739448070526123, 73.91231489181519 since the start of the Bronx code.
# Bronx permit 68 finished at 1660150221.019684, after 1.0773487091064453, 74.98971271514893 since the start of the Bronx code.
# Bronx permit 69 finished at 1660150222.099464, after 1.0797240734100342, 76.06949281692505 since the start of the Bronx code.
# Bronx permit 70 finished at 1660150223.1862452, after 1.0867090225219727, 77.15627384185791 since the start of the Bronx code.
# Bronx permit 71 finished at 1660150224.2633002, after 1.076995849609375, 78.23332786560059 since the start of the Bronx code.
# Bronx permit 72 finished at 1660150225.342707, after 1.0793609619140625, 79.31273484230042 since the start of the Bronx code.
# Bronx permit 73 finished at 1660150226.43998, after 1.0972280502319336, 80.41000866889954 since the start of the Bronx code.
# Bronx permit 74 finished at 1660150227.530981, after 1.0909340381622314, 81.50100994110107 since the start of the Bronx code.
# Bronx permit 75 finished at 1660150228.6092129, after 1.0781891345977783, 82.57924294471741 since the start of the Bronx code.
# Bronx permit 76 finished at 1660150229.698411, after 1.0891270637512207, 83.66844010353088 since the start of the Bronx code.
# Bronx permit 77 finished at 1660150230.799078, after 1.1006059646606445, 84.7691068649292 since the start of the Bronx code.
# Bronx permit 78 finished at 1660150231.901814, after 1.1026830673217773, 85.87184286117554 since the start of the Bronx code.
# Bronx permit 79 finished at 1660150232.998357, after 1.0964739322662354, 86.96838402748108 since the start of the Bronx code.
# ...
# Brooklyn permit 2075 finished at 1660156857.341929, after 1.506485939025879, 3170.360071182251 since the start of the Brooklyn code.
# Brooklyn permit 2076 finished at 1660156858.880346, after 1.538318157196045, 3171.8984880447388 since the start of the Brooklyn code.
# Brooklyn permit 2077 finished at 1660156860.4111192, after 1.5306940078735352, 3173.4292590618134 since the start of the Brooklyn code.
# Brooklyn permit 2078 finished at 1660156861.877902, after 1.4666988849639893, 3174.8960421085358 since the start of the Brooklyn code.
# Brooklyn permit 2079 finished at 1660156863.380955, after 1.5029771327972412, 3176.3990960121155 since the start of the Brooklyn code.
# Brooklyn permit 2080 finished at 1660156864.830008, after 1.4489638805389404, 3177.8481481075287 since the start of the Brooklyn code.
# Brooklyn permit 2081 finished at 1660156866.389143, after 1.5590648651123047, 3179.4072840213776 since the start of the Brooklyn code.
# Brooklyn permit 2082 finished at 1660156867.979437, after 1.5902140140533447, 3180.9975769519806 since the start of the Brooklyn code.
# Brooklyn permit 2083 finished at 1660156869.5165892, after 1.5370829105377197, 3182.5347299575806 since the start of the Brooklyn code.
# Brooklyn permit 2084 finished at 1660156870.9746492, after 1.4579658508300781, 3183.992789030075 since the start of the Brooklyn code.
# Brooklyn permit 2085 finished at 1660156872.50979, after 1.5350770950317383, 3185.5279302597046 since the start of the Brooklyn code.
# Brooklyn permit 2086 finished at 1660156873.980248, after 1.4703917503356934, 3186.998389005661 since the start of the Brooklyn code.
# Brooklyn permit 2087 finished at 1660156875.517445, after 1.5371267795562744, 3188.535585165024 since the start of the Brooklyn code.
# Brooklyn permit 2088 finished at 1660156877.0055308, after 1.4880101680755615, 3190.023672103882 since the start of the Brooklyn code.
# Brooklyn permit 2089 finished at 1660156878.543941, after 1.5383450984954834, 3191.5620810985565 since the start of the Brooklyn code.
# Brooklyn permit 2090 finished at 1660156880.083331, after 1.5393028259277344, 3193.1014721393585 since the start of the Brooklyn code.
# Brooklyn permit 2091 finished at 1660156881.619295, after 1.535871982574463, 3194.63743519783 since the start of the Brooklyn code.
# Brooklyn permit 2092 finished at 1660156883.167647, after 1.5482642650604248, 3196.1857872009277 since the start of the Brooklyn code.
# Brooklyn permit 2093 finished at 1660156884.669356, after 1.501633882522583, 3197.6874969005585 since the start of the Brooklyn code.
# Brooklyn permit 2094 finished at 1660156886.1732092, after 1.5037639141082764, 3199.191349029541 since the start of the Brooklyn code.
# Brooklyn permit 2095 finished at 1660156887.761068, after 1.587770938873291, 3200.7792088985443 since the start of the Brooklyn code.
# Brooklyn permit 2096 finished at 1660156889.323671, after 1.5625197887420654, 3202.3418118953705 since the start of the Brooklyn code.
# Brooklyn permit 2097 finished at 1660156890.796164, after 1.4724137783050537, 3203.814304113388 since the start of the Brooklyn code.
# Brooklyn permit 2098 finished at 1660156892.271206, after 1.474970817565918, 3205.2893459796906 since the start of the Brooklyn code.
# Brooklyn permit 2099 finished at 1660156893.780009, after 1.508734941482544, 3206.7981491088867 since the start of the Brooklyn code.
# Brooklyn permit 2100 finished at 1660156895.3338351, after 1.55375075340271, 3208.351977109909 since the start of the Brooklyn code.
# Brooklyn permit 2101 finished at 1660156896.971843, after 1.6379036903381348, 3209.989984035492 since the start of the Brooklyn code.
# Brooklyn permit 2102 finished at 1660156898.523693, after 1.5517566204071045, 3211.5418350696564 since the start of the Brooklyn code.
# Brooklyn permit 2103 finished at 1660156900.126626, after 1.6027426719665527, 3213.1447660923004 since the start of the Brooklyn code.
# Brooklyn permit 2104 finished at 1660156901.616252, after 1.4895401000976562, 3214.6343932151794 since the start of the Brooklyn code.
# Brooklyn permit 2105 finished at 1660156903.075107, after 1.4587700366973877, 3216.093248128891 since the start of the Brooklyn code.
# Brooklyn permit 2106 finished at 1660156904.558997, after 1.4838051795959473, 3217.577137231827 since the start of the Brooklyn code.
# Brooklyn permit 2107 finished at 1660156906.091858, after 1.5327849388122559, 3219.10999917984 since the start of the Brooklyn code.
# Brooklyn permit 2108 finished at 1660156907.618582, after 1.5266268253326416, 3220.6367230415344 since the start of the Brooklyn code.
# Brooklyn permit 2109 finished at 1660156909.24723, after 1.628572940826416, 3222.2653710842133 since the start of the Brooklyn code.
# Brooklyn permit 2110 finished at 1660156910.794438, after 1.54709792137146, 3223.8125791549683 since the start of the Brooklyn code.
# Brooklyn permit 2111 finished at 1660156912.3493462, after 1.5548198223114014, 3225.367486000061 since the start of the Brooklyn code.
# Brooklyn permit 2112 finished at 1660156913.8312871, after 1.4818649291992188, 3226.8494279384613 since the start of the Brooklyn code.
# Brooklyn permit 2113 finished at 1660156915.344175, after 1.5128169059753418, 3228.362316131592 since the start of the Brooklyn code.
# Brooklyn permit 2114 finished at 1660156916.905833, after 1.561579942703247, 3229.923973083496 since the start of the Brooklyn code.
# Brooklyn permit 2115 finished at 1660156918.487454, after 1.5815448760986328, 3231.50559425354 since the start of the Brooklyn code.
# Brooklyn permit 2116 finished at 1660156920.0413399, after 1.5538051128387451, 3233.0594811439514 since the start of the Brooklyn code.
# Brooklyn permit 2117 finished at 1660156921.599356, after 1.5578360557556152, 3234.6174960136414 since the start of the Brooklyn code.
# Brooklyn permit 2118 finished at 1660156923.100965, after 1.501399040222168, 3236.119106054306 since the start of the Brooklyn code.
# Brooklyn permit 2119 finished at 1660156924.637738, after 1.5367000102996826, 3237.6558780670166 since the start of the Brooklyn code.
# Brooklyn permit 2120 finished at 1660156926.1943512, after 1.5565428733825684, 3239.2124919891357 since the start of the Brooklyn code.
# Brooklyn permit 2121 finished at 1660156927.6945012, after 1.5000598430633545, 3240.7126421928406 since the start of the Brooklyn code.
# Brooklyn permit 2122 finished at 1660156929.3172648, after 1.622694969177246, 3242.335406064987 since the start of the Brooklyn code.
# Brooklyn permit 2123 finished at 1660156930.8016372, after 1.4842700958251953, 3243.8197770118713 since the start of the Brooklyn code.
# Brooklyn permit 2124 finished at 1660156932.304299, after 1.5025842189788818, 3245.3224391937256 since the start of the Brooklyn code.
# Brooklyn permit 2125 finished at 1660156933.857837, after 1.5534610748291016, 3246.875977039337 since the start of the Brooklyn code.
# Brooklyn permit 2126 finished at 1660156935.429068, after 1.5711638927459717, 3248.447208881378 since the start of the Brooklyn code.
# Brooklyn permit 2127 finished at 1660156936.9445682, after 1.5154240131378174, 3249.9627089500427 since the start of the Brooklyn code.
# Brooklyn permit 2128 finished at 1660156938.4280682, after 1.483428716659546, 3251.4462101459503 since the start of the Brooklyn code.
# Brooklyn permit 2129 finished at 1660156939.9749298, after 1.546302080154419, 3252.99307012558 since the start of the Brooklyn code.
# Brooklyn permit 2130 finished at 1660156941.463079, after 1.4880731105804443, 3254.4812190532684 since the start of the Brooklyn code.
# Brooklyn permit 2131 finished at 1660156943.0238788, after 1.560716152191162, 3256.0420191287994 since the start of the Brooklyn code.
# Brooklyn permit 2132 finished at 1660156944.6123421, after 1.5883867740631104, 3257.6304829120636 since the start of the Brooklyn code.
# Brooklyn permit 2133 finished at 1660156946.139255, after 1.526827096939087, 3259.1573960781097 since the start of the Brooklyn code.
# Brooklyn permit 2134 finished at 1660156947.675942, after 1.5366179943084717, 3260.6940820217133 since the start of the Brooklyn code.
# Brooklyn permit 2135 finished at 1660156949.167812, after 1.491783857345581, 3262.185953140259 since the start of the Brooklyn code.
# Brooklyn permit 2136 finished at 1660156950.732436, after 1.56455397605896, 3263.75057721138 since the start of the Brooklyn code.
# Brooklyn permit 2137 finished at 1660156952.274675, after 1.5421481132507324, 3265.2928161621094 since the start of the Brooklyn code.
# Brooklyn permit 2138 finished at 1660156953.766032, after 1.491288185119629, 3266.7841720581055 since the start of the Brooklyn code.
# Brooklyn permit 2139 finished at 1660156955.2910879, after 1.524979829788208, 3268.309228181839 since the start of the Brooklyn code.
# Brooklyn permit 2140 finished at 1660156956.884199, after 1.5930359363555908, 3269.9023401737213 since the start of the Brooklyn code.
# Brooklyn permit 2141 finished at 1660156958.384352, after 1.5000691413879395, 3271.402492284775 since the start of the Brooklyn code.
# Brooklyn permit 2142 finished at 1660156959.839922, after 1.4554989337921143, 3272.858062028885 since the start of the Brooklyn code.
# Brooklyn permit 2143 finished at 1660156961.369458, after 1.5294651985168457, 3274.3875980377197 since the start of the Brooklyn code.
# Brooklyn permit 2144 finished at 1660156962.851265, after 1.4817430973052979, 3275.869405031204 since the start of the Brooklyn code.
# Brooklyn permit 2145 finished at 1660156964.325077, after 1.4737420082092285, 3277.3432171344757 since the start of the Brooklyn code.
# Brooklyn permit 2146 finished at 1660156965.917978, after 1.5928268432617188, 3278.93611907959 since the start of the Brooklyn code.
# Brooklyn permit 2147 finished at 1660156967.401806, after 1.4837517738342285, 3280.4199471473694 since the start of the Brooklyn code.
# Brooklyn permit 2148 finished at 1660156968.8964748, after 1.4946019649505615, 3281.9146161079407 since the start of the Brooklyn code.
# Brooklyn permit 2149 finished at 1660156970.429482, after 1.5329389572143555, 3283.4476220607758 since the start of the Brooklyn code.
# Brooklyn permit 2150 finished at 1660156971.946313, after 1.5167548656463623, 3284.9644532203674 since the start of the Brooklyn code.
# Brooklyn permit 2151 finished at 1660156973.410769, after 1.4643781185150146, 3286.4289090633392 since the start of the Brooklyn code.
# Brooklyn permit 2152 finished at 1660156974.981704, after 1.5708551406860352, 3287.999845266342 since the start of the Brooklyn code.
# Brooklyn permit 2153 finished at 1660156976.515758, after 1.5339710712432861, 3289.5338990688324 since the start of the Brooklyn code.
# Brooklyn permit 2154 finished at 1660156977.998971, after 1.4831418991088867, 3291.017112016678 since the start of the Brooklyn code.
# Brooklyn permit 2155 finished at 1660156979.4816482, after 1.4826009273529053, 3292.499788045883 since the start of the Brooklyn code.
# Brooklyn permit 2156 finished at 1660156980.9859352, after 1.5041899681091309, 3294.0040760040283 since the start of the Brooklyn code.
# Brooklyn permit 2157 finished at 1660156982.500832, after 1.5148169994354248, 3295.518972158432 since the start of the Brooklyn code.
# Brooklyn permit 2158 finished at 1660156984.046418, after 1.545516014099121, 3297.0645592212677 since the start of the Brooklyn code.
# Brooklyn permit 2159 finished at 1660156985.555915, after 1.5094196796417236, 3298.5740580558777 since the start of the Brooklyn code.
# Brooklyn permit 2160 finished at 1660156987.0447922, after 1.4887797832489014, 3300.0629329681396 since the start of the Brooklyn code.
# Brooklyn permit 2161 finished at 1660156988.6179368, after 1.573051929473877, 3301.636078119278 since the start of the Brooklyn code.
# Brooklyn permit 2162 finished at 1660156990.2150211, after 1.5970089435577393, 3303.233160972595 since the start of the Brooklyn code.
# Brooklyn permit 2163 finished at 1660156991.7214022, after 1.5063040256500244, 3304.7395429611206 since the start of the Brooklyn code.
# Brooklyn permit 2164 finished at 1660156993.189142, after 1.4676730632781982, 3306.2072830200195 since the start of the Brooklyn code.
# Brooklyn permit 2165 finished at 1660156994.73389, after 1.5446820259094238, 3307.7520310878754 since the start of the Brooklyn code.
# Brooklyn permit 2166 finished at 1660156996.315884, after 1.5819063186645508, 3309.334023952484 since the start of the Brooklyn code.
# Brooklyn permit 2167 finished at 1660156997.789279, after 1.4733219146728516, 3310.8074181079865 since the start of the Brooklyn code.
# Brooklyn permit 2168 finished at 1660156999.2574148, after 1.4680750370025635, 3312.275556087494 since the start of the Brooklyn code.
# Brooklyn permit 2169 finished at 1660157000.730208, after 1.4727232456207275, 3313.7483489513397 since the start of the Brooklyn code.
# Brooklyn permit 2170 finished at 1660157002.181605, after 1.451326847076416, 3315.199744939804 since the start of the Brooklyn code.
# Brooklyn permit 2171 finished at 1660157003.7412999, after 1.5596251487731934, 3316.759441137314 since the start of the Brooklyn code.
# Brooklyn permit 2172 finished at 1660157005.254931, after 1.5135600566864014, 3318.273072242737 since the start of the Brooklyn code.
# Brooklyn permit 2173 finished at 1660157006.779669, after 1.524665117263794, 3319.7978098392487 since the start of the Brooklyn code.
# Brooklyn permit 2174 finished at 1660157008.4022772, after 1.622532844543457, 3321.420418024063 since the start of the Brooklyn code.
# Brooklyn permit 2175 finished at 1660157009.869577, after 1.4672341346740723, 3322.8877182006836 since the start of the Brooklyn code.
# Brooklyn permit 2176 finished at 1660157011.439455, after 1.5698051452636719, 3324.4575951099396 since the start of the Brooklyn code.
# Brooklyn permit 2177 finished at 1660157013.067586, after 1.6280629634857178, 3326.085727930069 since the start of the Brooklyn code.
# Brooklyn permit 2178 finished at 1660157014.6119192, after 1.544238805770874, 3327.6300599575043 since the start of the Brooklyn code.
# Brooklyn permit 2179 finished at 1660157016.111306, after 1.4993200302124023, 3329.1294462680817 since the start of the Brooklyn code.
# Brooklyn permit 2180 finished at 1660157017.584936, after 1.4735479354858398, 3330.6030762195587 since the start of the Brooklyn code.
# Brooklyn permit 2181 finished at 1660157019.041043, after 1.4560351371765137, 3332.059184074402 since the start of the Brooklyn code.
# Brooklyn permit 2182 finished at 1660157020.5961092, after 1.5550038814544678, 3333.614249944687 since the start of the Brooklyn code.
# Brooklyn permit 2183 finished at 1660157022.086642, after 1.4904530048370361, 3335.104782104492 since the start of the Brooklyn code.
# Brooklyn permit 2184 finished at 1660157023.649867, after 1.563155174255371, 3336.668007850647 since the start of the Brooklyn code.
# Brooklyn permit 2185 finished at 1660157025.1275232, after 1.477585792541504, 3338.1456620693207 since the start of the Brooklyn code.
# Brooklyn permit 2186 finished at 1660157026.6059148, after 1.4783289432525635, 3339.624055147171 since the start of the Brooklyn code.
# Brooklyn permit 2187 finished at 1660157028.148855, after 1.5428557395935059, 3341.1669960021973 since the start of the Brooklyn code.
# Brooklyn permit 2188 finished at 1660157029.719664, after 1.570741891860962, 3342.737804174423 since the start of the Brooklyn code.
# Brooklyn permit 2189 finished at 1660157031.237293, after 1.5175628662109375, 3344.255434036255 since the start of the Brooklyn code.
# Brooklyn permit 2190 finished at 1660157032.6734772, after 1.4361090660095215, 3345.6916179656982 since the start of the Brooklyn code.
# Brooklyn permit 2191 finished at 1660157034.16199, after 1.4884369373321533, 3347.180130004883 since the start of the Brooklyn code.
# Brooklyn permit 2192 finished at 1660157035.6240199, after 1.4619560241699219, 3348.642161130905 since the start of the Brooklyn code.
#
# Time to run Brooklyn: 3348.6731350421906

# %%
nypd2019_man = nypd2019_20[nypd2019_20['boro_nm'] == 'MANHATTAN']
nypd2019_bx = nypd2019_20[nypd2019_20['boro_nm'] == 'BRONX']
nypd2019_si = nypd2019_20[nypd2019_20['boro_nm'] == 'STATEN ISLAND']
nypd2019_qn = nypd2019_20[nypd2019_20['boro_nm'] == 'QUEENS']
nypd2019_bk = nypd2019_20[nypd2019_20['boro_nm'] == 'BROOKLYN']

nypd2019_man.to_csv('../data_nypd_by_year/2019/nypd2019_man.csv', index = False)
nypd2019_bx.to_csv('../data_nypd_by_year/2019/nypd2019_bx.csv', index = False)
nypd2019_si.to_csv('../data_nypd_by_year/2019/nypd2019_si.csv', index = False)
nypd2019_qn.to_csv('../data_nypd_by_year/2019/nypd2019_qn.csv', index = False)
nypd2019_bk.to_csv('../data_nypd_by_year/2019/nypd2019_bk.csv', index = False)
